# %%
with open('../Dataset/StudentHandbookDataset.txt', 'r', encoding='utf-8') as f:
    dataset = f.read()

print(f"Dataset loaded: {len(dataset):,} characters")
print(f"Estimated pages: ~{len(dataset) // 2000}")
# Out:
# Dataset loaded: 171,284 characters
# Estimated pages: ~85

# %%
import torch
from langchain_experimental.text_splitter import SemanticChunker
from langchain_community.embeddings import HuggingFaceEmbeddings
import faiss
import numpy as np
import pickle
import os
import warnings
warnings.filterwarnings('ignore')

# %%
import json

# Load your custom chunks from Chunks.json
with open('../Dataset/Chunks.json', 'r', encoding='utf-8') as f:
    chunks_data = json.load(f)

print(f"[SUCCESS] Loaded {len(chunks_data)} custom chunks from Chunks.json")

# Convert your custom chunks to the format expected by the code
# Your chunks need to be converted to objects with .page_content attribute
from langchain.schema import Document

chunks = []
for chunk_item in chunks_data:
    # Create a Document object with the content and metadata
    doc = Document(
        page_content=chunk_item['content'],
        metadata={
            'chunk_id': chunk_item['chunk_id'],
            'source_document': chunk_item['metadata'].get('source_document', 'Student Handbook'),
            'section_hierarchy': chunk_item['metadata'].get('section_hierarchy', '')
        }
    )
    chunks.append(doc)

print(f"[SUCCESS] Converted to {len(chunks)} Document objects")
print(f"\nSample chunk preview:")
print(f"   ID: {chunks[0].metadata['chunk_id']}")
print(f"   Content length: {len(chunks[0].page_content)} characters")
print(f"   First 150 chars: {chunks[0].page_content[:150]}...")
# Out:
# [SUCCESS] Loaded 125 custom chunks from Chunks.json
# [SUCCESS] Converted to 125 Document objects
#
# Sample chunk preview:
#    ID: handbook_chunk_001
#    Content length: 2588 characters
#    First 150 chars: HISTORY OF EARIST
#
# The Eulogio "Amang" Rodriguez Institute of Science and Technology (EARIST) was established after the liberation of Manila in 1945. ...

# %%
def check_chunks_exist():
    """Check if chunks have been saved"""
    return os.path.exists("saved_chunks/chunks.pkl")

def save_chunks(chunks, filename="saved_chunks/chunks.pkl"):
    """Save chunks to disk"""
    os.makedirs("saved_chunks", exist_ok=True)
    with open(filename, 'wb') as f:
        pickle.dump(chunks, f)
    print(f"[SUCCESS] Saved {len(chunks)} chunks to {filename}")

def load_chunks(filename="saved_chunks/chunks.pkl"):
    """Load chunks from disk"""
    try:
        with open(filename, 'rb') as f:
            chunks = pickle.load(f)
        print(f"[SUCCESS] Loaded {len(chunks)} chunks from {filename}")
        return chunks
    except FileNotFoundError:
        print(f"[ERROR] Chunks file not found: {filename}")
        return None

# Check if chunks already exist
if check_chunks_exist():
    print("[SUCCESS] Chunks file found! You can skip to Step 2 (Embedding Experiments)")
    print("[INFO] To reload chunks, run: chunks = load_chunks()")
else:
    print("[INFO] No saved chunks found. Run the chunking cells below.")
# Out:
# [INFO] No saved chunks found. Run the chunking cells below.

# %%
# ========================================
# EXPERIMENT PARAMETER: CHUNKING STRATEGY
# ========================================
# Change these values to experiment with different chunking!

CHUNKING_STRATEGY = "semantic"  # Options: "semantic", "fixed" (future)
PERCENTILE_THRESHOLD = 50       # Try: 70, 75, 80, 85, 90 (higher = fewer, larger chunks)
BUFFER_SIZE = 1                 # Sentences to merge around breakpoints

# ========================================

# ONLY RUN THIS IF CHUNKS DON'T EXIST OR YOU WANT TO RE-CHUNK
print(f"Loading embedding model for {CHUNKING_STRATEGY} chunking...")
print("   Using CPU for stable performance")

chunking_embed_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2",
    model_kwargs={'device': 'cuda' if torch.cuda.is_available() else 'cpu'},
    encode_kwargs={'normalize_embeddings': True}
)

print(f"Setting up semantic chunker with PERCENTILE={PERCENTILE_THRESHOLD}...")
text_splitter = SemanticChunker(
    embeddings=chunking_embed_model,
    breakpoint_threshold_type="percentile",
    breakpoint_threshold_amount=PERCENTILE_THRESHOLD,
    buffer_size=BUFFER_SIZE,
    add_start_index=True
)
print(f"[SUCCESS] Chunker ready (Percentile: {PERCENTILE_THRESHOLD}, Buffer: {BUFFER_SIZE})!")

# ONLY RUN THIS IF CHUNKS DON'T EXIST OR YOU WANT TO RE-CHUNK
print("Creating semantic chunks from raw text...")
print(f"Configuration: Percentile={PERCENTILE_THRESHOLD}, Buffer={BUFFER_SIZE}")
chunks = text_splitter.create_documents([dataset])
print(f"[SUCCESS] Created {len(chunks)} semantic chunks")

# Analyze chunk quality
chunk_sizes = [len(chunk.page_content) for chunk in chunks]
print(f"\nChunk Analysis:")
print(f"   Average size: {np.mean(chunk_sizes):.0f} characters")
print(f"   Size range: {min(chunk_sizes)} - {max(chunk_sizes)} characters")
print(f"   Total chunks: {len(chunks)}")

# Show sample chunks
print("\nSample chunks:")
for i in range(min(3, len(chunks))):
    chunk_preview = chunks[i].page_content[:150].replace('\n', ' ')
    print(f"   Chunk {i+1}: {chunk_preview}...")

# SAVE THE CHUNKS with configuration in filename
chunk_filename = f"saved_chunks/chunks_p{PERCENTILE_THRESHOLD}_b{BUFFER_SIZE}.pkl"
save_chunks(chunks, filename=chunk_filename)
print(f"\n[SUCCESS] Chunking complete and saved to {chunk_filename}!")
print(f"[INFO] Configuration: Percentile={PERCENTILE_THRESHOLD}, Buffer={BUFFER_SIZE}")

# Load saved chunks - automatically detect the correct file based on parameters
chunk_filename = f"saved_chunks/chunks_p{PERCENTILE_THRESHOLD}_b{BUFFER_SIZE}.pkl"

print(f"Looking for chunks: {chunk_filename}")
chunks = load_chunks(filename=chunk_filename)

if chunks is None:
    print(f"[ERROR] Chunks not found for P={PERCENTILE_THRESHOLD}, B={BUFFER_SIZE}")
    print("[INFO] Please run Step 1 (Chunking) cells first with these parameters!")
else:
    print(f"[SUCCESS] Ready to experiment with {len(chunks)} chunks!")
    print(f"[INFO] Loaded configuration: Percentile={PERCENTILE_THRESHOLD}, Buffer={BUFFER_SIZE}")
# Out:
# Loading embedding model for semantic chunking...
#    Using CPU for stable performance
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 16
#      13 print(f"Loading embedding model for {CHUNKING_STRATEGY} chunking...")
#      14 print("   Using CPU for stable performance")
# ---> 16 chunking_embed_model = HuggingFaceEmbeddings(
#      17     model_name="sentence-transformers/all-MiniLM-L6-v2",
#      18     model_kwargs={'device': 'cuda' if torch.cuda.is_available() else 'cpu'},
#      19     encode_kwargs={'normalize_embeddings': True}
#      20 )
#      22 print(f"Setting up semantic chunker with PERCENTILE={PERCENTILE_THRESHOLD}...")
#      23 text_splitter = SemanticChunker(
#      24     embeddings=chunking_embed_model,
#      25     breakpoint_threshold_type="percentile",
#    (...)     28     add_start_index=True
#      29 )
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\_api\deprecation.py:226, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     224     warned = True
#     225     emit_warning()
# --> 226 return wrapped(self, *args, **kwargs)
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_community\embeddings\huggingface.py:92, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      86 except ImportError as exc:
#      87     raise ImportError(
#      88         "Could not import sentence_transformers python package. "
#      89         "Please install it with `pip install sentence-transformers`."
#      90     ) from exc
# ---> 92 self.client = sentence_transformers.SentenceTransformer(
#      93     self.model_name, cache_folder=self.cache_folder, **self.model_kwargs
#      94 )
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\sentence_transformers\SentenceTransformer.py:327, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, similarity_fn_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, truncate_dim, model_kwargs, tokenizer_kwargs, config_kwargs, model_card_data, backend)
#     309 has_modules = is_sentence_transformer_model(
#     310     model_name_or_path,
#     311     token,
#    (...)    314     local_files_only=local_files_only,
#     315 )
#     316 if (
#     317     has_modules
#     318     and self._get_model_type(
#    (...)    325     == self._model_config["model_type"]
#     326 ):
# --> 327     modules, self.module_kwargs = self._load_sbert_model(
#     328         model_name_or_path,
#     329         token=token,
#     330         cache_folder=cache_folder,
#     331         revision=revision,
#     332         trust_remote_code=trust_remote_code,
#     333         local_files_only=local_files_only,
#     334         model_kwargs=model_kwargs,
#     335         tokenizer_kwargs=tokenizer_kwargs,
#     336         config_kwargs=config_kwargs,
#     337     )
#     338 else:
#     339     modules = self._load_auto_model(
#     340         model_name_or_path,
#     341         token=token,
#    (...)    349         has_modules=has_modules,
#     350     )
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\sentence_transformers\SentenceTransformer.py:2305, in SentenceTransformer._load_sbert_model(self, model_name_or_path, token, cache_folder, revision, trust_remote_code, local_files_only, model_kwargs, tokenizer_kwargs, config_kwargs)
#    2300         module = module_class.load(local_path)
#    2302 else:
#    2303     # Newer modules that support the new loading method are loaded with the new style
#    2304     # i.e. with many keyword arguments that can optionally be used by the modules
# -> 2305     module = module_class.load(
#    2306         model_name_or_path,
#    2307         # Loading-specific keyword arguments
#    2308         subfolder=module_config["path"],
#    2309         token=token,
#    2310         cache_folder=cache_folder,
#    2311         revision=revision,
#    2312         local_files_only=local_files_only,
#    2313         # Module-specific keyword arguments
#    2314         trust_remote_code=trust_remote_code,
#    2315         model_kwargs=model_kwargs,
#    2316         tokenizer_kwargs=tokenizer_kwargs,
#    2317         config_kwargs=config_kwargs,
#    2318         backend=self.backend,
#    2319     )
#    2321 modules[module_config["name"]] = module
#    2322 module_kwargs[module_config["name"]] = module_config.get("kwargs", [])
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\sentence_transformers\models\Transformer.py:365, in Transformer.load(cls, model_name_or_path, subfolder, token, cache_folder, revision, local_files_only, trust_remote_code, model_kwargs, tokenizer_kwargs, config_kwargs, backend, **kwargs)
#     334 @classmethod
#     335 def load(
#     336     cls,
#    (...)    350     **kwargs,
#     351 ) -> Self:
#     352     init_kwargs = cls._load_init_kwargs(
#     353         model_name_or_path=model_name_or_path,
#     354         subfolder=subfolder,
#    (...)    363         backend=backend,
#     364     )
# --> 365     return cls(model_name_or_path=model_name_or_path, **init_kwargs)
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\sentence_transformers\models\Transformer.py:102, in Transformer.__init__(self, model_name_or_path, max_seq_length, model_args, tokenizer_args, config_args, cache_dir, do_lower_case, tokenizer_name_or_path, backend)
#     100 if max_seq_length is not None and "model_max_length" not in tokenizer_args:
#     101     tokenizer_args["model_max_length"] = max_seq_length
# --> 102 self.tokenizer = AutoTokenizer.from_pretrained(
#     103     tokenizer_name_or_path if tokenizer_name_or_path is not None else model_name_or_path,
#     104     cache_dir=cache_dir,
#     105     **tokenizer_args,
#     106 )
#     108 # No max_seq_length set. Try to infer from model
#     109 if max_seq_length is None:
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\auto\tokenization_auto.py:1073, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#    1070     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#    1072 # Next, let's try to use the tokenizer_config file to get the tokenizer class.
# -> 1073 tokenizer_config = get_tokenizer_config(pretrained_model_name_or_path, **kwargs)
#    1074 if "_commit_hash" in tokenizer_config:
#    1075     kwargs["_commit_hash"] = tokenizer_config["_commit_hash"]
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\auto\tokenization_auto.py:905, in get_tokenizer_config(pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, **kwargs)
#     902     token = use_auth_token
#     904 commit_hash = kwargs.get("_commit_hash")
# --> 905 resolved_config_file = cached_file(
#     906     pretrained_model_name_or_path,
#     907     TOKENIZER_CONFIG_FILE,
#     908     cache_dir=cache_dir,
#     909     force_download=force_download,
#     910     resume_download=resume_download,
#     911     proxies=proxies,
#     912     token=token,
#     913     revision=revision,
#     914     local_files_only=local_files_only,
#     915     subfolder=subfolder,
#     916     _raise_exceptions_for_gated_repo=False,
#     917     _raise_exceptions_for_missing_entries=False,
#     918     _raise_exceptions_for_connection_errors=False,
#     919     _commit_hash=commit_hash,
#     920 )
#     921 if resolved_config_file is None:
#     922     logger.info("Could not locate the tokenizer configuration file, will try to use the model config instead.")
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\hub.py:322, in cached_file(path_or_repo_id, filename, **kwargs)
#     264 def cached_file(
#     265     path_or_repo_id: Union[str, os.PathLike],
#     266     filename: str,
#     267     **kwargs,
#     268 ) -> Optional[str]:
#     269     """
#     270     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     271
#    (...)    320     ```
#     321     """
# --> 322     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     323     file = file[0] if file is not None else file
#     324     return file
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\hub.py:479, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     476 try:
#     477     if len(full_filenames) == 1:
#     478         # This is slightly better for only 1 file
# --> 479         hf_hub_download(
#     480             path_or_repo_id,
#     481             filenames[0],
#     482             subfolder=None if len(subfolder) == 0 else subfolder,
#     483             repo_type=repo_type,
#     484             revision=revision,
#     485             cache_dir=cache_dir,
#     486             user_agent=user_agent,
#     487             force_download=force_download,
#     488             proxies=proxies,
#     489             resume_download=resume_download,
#     490             token=token,
#     491             local_files_only=local_files_only,
#     492         )
#     493     else:
#     494         snapshot_download(
#     495             path_or_repo_id,
#     496             allow_patterns=full_filenames,
#    (...)    505             local_files_only=local_files_only,
#     506         )
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1010, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     990     return _hf_hub_download_to_local_dir(
#     991         # Destination
#     992         local_dir=local_dir,
#    (...)   1007         local_files_only=local_files_only,
#    1008     )
#    1009 else:
# -> 1010     return _hf_hub_download_to_cache_dir(
#    1011         # Destination
#    1012         cache_dir=cache_dir,
#    1013         # File info
#    1014         repo_id=repo_id,
#    1015         filename=filename,
#    1016         repo_type=repo_type,
#    1017         revision=revision,
#    1018         # HTTP info
#    1019         endpoint=endpoint,
#    1020         etag_timeout=etag_timeout,
#    1021         headers=hf_headers,
#    1022         proxies=proxies,
#    1023         token=token,
#    1024         # Additional options
#    1025         local_files_only=local_files_only,
#    1026         force_download=force_download,
#    1027     )
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1073, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1069         return pointer_path
#    1071 # Try to get metadata (etag, commit_hash, url, size) from the server.
#    1072 # If we can't, a HEAD request error is returned.
# -> 1073 (url_to_download, etag, commit_hash, expected_size, xet_file_data, head_call_error) = _get_metadata_or_catch_error(
#    1074     repo_id=repo_id,
#    1075     filename=filename,
#    1076     repo_type=repo_type,
#    1077     revision=revision,
#    1078     endpoint=endpoint,
#    1079     proxies=proxies,
#    1080     etag_timeout=etag_timeout,
#    1081     headers=headers,
#    1082     token=token,
#    1083     local_files_only=local_files_only,
#    1084     storage_folder=storage_folder,
#    1085     relative_filename=relative_filename,
#    1086 )
#    1088 # etag can be None for several reasons:
#    1089 # 1. we passed local_files_only.
#    1090 # 2. we don't have a connection
#    (...)   1096 # If the specified revision is a commit hash, look inside "snapshots".
#    1097 # If the specified revision is a branch or tag, look inside "refs".
#    1098 if head_call_error is not None:
#    1099     # Couldn't make a HEAD call => let's try to find a local file
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1546, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder)
#    1544 try:
#    1545     try:
# -> 1546         metadata = get_hf_file_metadata(
#    1547             url=url, proxies=proxies, timeout=etag_timeout, headers=headers, token=token, endpoint=endpoint
#    1548         )
#    1549     except EntryNotFoundError as http_error:
#    1550         if storage_folder is not None and relative_filename is not None:
#    1551             # Cache the non-existence of the file
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1463, in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers, endpoint)
#    1460 hf_headers["Accept-Encoding"] = "identity"  # prevent any compression => we want to know the real size of the file
#    1462 # Retrieve metadata
# -> 1463 r = _request_wrapper(
#    1464     method="HEAD",
#    1465     url=url,
#    1466     headers=hf_headers,
#    1467     allow_redirects=False,
#    1468     follow_relative_redirects=True,
#    1469     proxies=proxies,
#    1470     timeout=timeout,
#    1471 )
#    1472 hf_raise_for_status(r)
#    1474 # Return
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:286, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     284 # Recursively follow relative redirects
#     285 if follow_relative_redirects:
# --> 286     response = _request_wrapper(
#     287         method=method,
#     288         url=url,
#     289         follow_relative_redirects=False,
#     290         **params,
#     291     )
#     293     # If redirection, we redirect only relative paths.
#     294     # This is useful in case of a renamed repository.
#     295     if 300 <= response.status_code <= 399:
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:309, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     306     return response
#     308 # Perform request and return if status_code is not in the retry list.
# --> 309 response = http_backoff(method=method, url=url, **params)
#     310 hf_raise_for_status(response)
#     311 return response
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\utils\_http.py:308, in http_backoff(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, **kwargs)
#     305     kwargs["data"].seek(io_obj_initial_pos)
#     307 # Perform request and return if status_code is not in the retry list.
# --> 308 response = session.request(method=method, url=url, **kwargs)
#     309 if response.status_code not in retry_on_status_codes:
#     310     return response
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\utils\_http.py:95, in UniqueRequestIdAdapter.send(self, request, *args, **kwargs)
#      93     logger.debug(f"Send: {_curlify(request)}")
#      94 try:
# ---> 95     return super().send(request, *args, **kwargs)
#      96 except requests.RequestException as e:
#      97     request_id = request.headers.get(X_AMZN_TRACE_ID)
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\tebats\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# ========================================
# EXPERIMENT PARAMETER: EMBEDDING MODEL
# ========================================
# Change MODEL_NAME to experiment with different embeddings!

# Current options (uncomment one):
# MODEL_NAME = "sentence-transformers/all-mpnet-base-v2"  # Best quality, 768 dim
# MODEL_NAME = "sentence-transformers/all-MiniLM-L6-v2"  # Fast, 384 dim
MODEL_NAME = "sentence-transformers/multi-qa-mpnet-base-dot-v1"  # Q&A optimized
# MODEL_NAME = "sentence-transformers/paraphrase-multilingual-mpnet-base-v2"  # Multilingual

# ========================================

print(f"\n{'='*70}")
print(f"EMBEDDING MODEL CONFIGURATION")
print(f"{'='*70}")
print(f"Model: {MODEL_NAME}")
print("   Using CPU for stable performance")

embedding_model = HuggingFaceEmbeddings(
    model_name=MODEL_NAME,
    model_kwargs={
        'device': 'cuda',
        'trust_remote_code': True
    },
    encode_kwargs={'normalize_embeddings': True}
)

# Get embedding dimension
test_embed = embedding_model.embed_query("test")

print(f"[SUCCESS] Embedding model loaded!")
print(f"   Model: {MODEL_NAME.split('/')[-1]}")
print(f"   Embedding dimension: {len(test_embed)}")
print(f"   Device: CPU")
print(f"{'='*70}\n")

print("\nGenerating embeddings for all chunks with current model...")
chunk_texts = [chunk.page_content for chunk in chunks]

# Process embeddings in batches to avoid memory issues
batch_size = 32
all_embeddings = []

import time
start_time = time.time()

for i in range(0, len(chunk_texts), batch_size):
    batch = chunk_texts[i:i+batch_size]
    batch_embeddings = embedding_model.embed_documents(batch)
    all_embeddings.extend(batch_embeddings)
    print(f"   Processed batch {i//batch_size + 1}/{(len(chunk_texts) + batch_size - 1)//batch_size}")

elapsed_time = time.time() - start_time
print(f"\n[SUCCESS] Generated {len(all_embeddings)} embeddings in {elapsed_time:.2f}s")
print(f"Average: {elapsed_time/len(all_embeddings):.3f}s per chunk")


# Build FAISS vector store for fast similarity search
print("\nBuilding FAISS vector database...")
dimension = len(all_embeddings[0])
index = faiss.IndexFlatIP(dimension)  # Inner Product for cosine similarity

# Normalize embeddings for proper cosine similarity
embeddings_array = np.array(all_embeddings).astype('float32')
faiss.normalize_L2(embeddings_array)
index.add(embeddings_array)

print(f"[SUCCESS] FAISS index ready: {index.ntotal:,} vectors ({dimension} dimensions)")
print(f"Model: {MODEL_NAME.split('/')[-1]}")
# Out:
# ======================================================================
# EMBEDDING MODEL CONFIGURATION
# ======================================================================
# Model: sentence-transformers/multi-qa-mpnet-base-dot-v1
#    Using CPU for stable performance
# [SUCCESS] Embedding model loaded!
#    Model: multi-qa-mpnet-base-dot-v1
#    Embedding dimension: 768
#    Device: CPU
# ======================================================================
#
#
# Generating embeddings for all chunks with current model...
#    Processed batch 1/4
#    Processed batch 2/4
#    Processed batch 3/4
#    Processed batch 4/4
#
# [SUCCESS] Generated 125 embeddings in 2.55s
# Average: 0.020s per chunk
#
# Building FAISS vector database...
# [SUCCESS] FAISS index ready: 125 vectors (768 dimensions)
# Model: multi-qa-mpnet-base-dot-v1

# %%
def retrieve_relevant_chunks(query, top_k=5):
    """Find most relevant chunks for the query"""
    print(f"\nSearching for: '{query}'")
    print(f"Model: {MODEL_NAME.split('/')[-1]}")
    print("=" * 50)

    # Embed the query
    query_embedding = embedding_model.embed_query(query)
    query_vector = np.array([query_embedding]).astype('float32')
    faiss.normalize_L2(query_vector)

    # Search FAISS index
    scores, indices = index.search(query_vector, top_k)

    # Return results with metadata
    results = []
    for idx, score in zip(indices[0], scores[0]):
        if idx < len(chunks):  # Safety check
            chunk = chunks[idx]
            results.append({
                'text': chunk.page_content,
                'score': float(score),
                'chunk_id': int(idx),
                'start_pos': chunk.metadata.get('start_index', 0) if hasattr(chunk, 'metadata') else 0
            })

    return results

def display_retrieval_results(query, results):
    """Display comprehensive retrieval results"""
    print(f"Found {len(results)} relevant chunks for: '{query}'")
    print("=" * 70)

    for i, result in enumerate(results, 1):
        print(f"\nChunk {i} (ID: {result['chunk_id']})")
        print(f"Relevance Score: {result['score']:.4f}")
        print(f"Position in Document: Character {result['start_pos']:,}")
        print(f"Length: {len(result['text'])} characters")
        print(f"Content Preview (first 200 chars):")
        print(f"   {result['text'][:200].replace(chr(10), ' ').replace(chr(13), '')}...")

        # Show full content if it's short enough
        if len(result['text']) <= 500:
            print(f"Full Content:")
            print(f"   {result['text']}")

        print("-" * 40)

    return results

print("[SUCCESS] Retrieval functions ready!")
# Out:
# [SUCCESS] Retrieval functions ready!

# %%
import json
# Load questions from Questions.json
with open('Questions.json', 'r', encoding='utf-8') as f:
    questions_data = json.load(f)

# Count total questions
total_questions = sum(len(questions) for questions in questions_data.values())
print(f"[SUCCESS] Loaded {total_questions} questions across {len(questions_data)} categories")
print("\nCategories:")
for category, questions in questions_data.items():
    print(f"   • {category}: {len(questions)} questions")
# Out:
# [SUCCESS] Loaded 50 questions across 8 categories
#
# Categories:
#    • Admissions: 8 questions
#    • Enrollment and Registration: 8 questions
#    • Fees, Payments and Scholarships: 6 questions
#    • Academic Policies and Grading: 8 questions
#    • Attendance and Conduct: 6 questions
#    • Student Services and Organizations: 6 questions
#    • Graduation and Academic Completion: 5 questions
#    • General and Miscellaneous Information: 3 questions

# %%
def test_category_questions(category_name, top_k=3, show_full_results=False):
    """Test all questions from a specific category"""
    if category_name not in questions_data:
        print(f"[ERROR] Category '{category_name}' not found!")
        print(f"Available categories: {', '.join(questions_data.keys())}")
        return

    questions = questions_data[category_name]
    print(f"\n{'='*70}")
    print(f"Testing Category: {category_name}")
    print(f"Total Questions: {len(questions)}")
    print(f"Model: {MODEL_NAME.split('/')[-1]}")
    print(f"Retrieving top {top_k} chunks per question")
    print(f"{'='*70}")

    all_results = []

    for i, q_item in enumerate(questions, 1):
        question = q_item['question']
        expected_ref = q_item['expected_reference']

        print(f"\n{'─'*70}")
        print(f"Question {i}/{len(questions)}")
        print(f"Q: {question}")
        print(f"Expected Reference: {expected_ref}")
        print(f"{'─'*70}")

        # Retrieve relevant chunks
        results = retrieve_relevant_chunks(question, top_k=top_k)

        # Store results for analysis
        all_results.append({
            'question': question,
            'expected_reference': expected_ref,
            'results': results,
            'top_score': results[0]['score'] if results else 0
        })

        if show_full_results:
            display_retrieval_results(question, results)
        else:
            # Show compact summary
            print(f"\nTop {min(top_k, len(results))} Results:")
            for j, result in enumerate(results[:top_k], 1):
                preview = result['text'][:150].replace('\n', ' ').replace('\r', '')
                print(f"   {j}. Score: {result['score']:.4f} | {preview}...")

    # Summary statistics
    print(f"\n{'='*70}")
    print(f"CATEGORY SUMMARY: {category_name}")
    print(f"{'='*70}")
    avg_top_score = np.mean([r['top_score'] for r in all_results])
    print(f"Average Top Score: {avg_top_score:.4f}")
    print(f"Score Range: {min([r['top_score'] for r in all_results]):.4f} - {max([r['top_score'] for r in all_results]):.4f}")

    # Score distribution
    high_confidence = sum(1 for r in all_results if r['top_score'] > 0.7)
    medium_confidence = sum(1 for r in all_results if 0.5 <= r['top_score'] <= 0.7)
    low_confidence = sum(1 for r in all_results if r['top_score'] < 0.5)

    print(f"\nConfidence Distribution:")
    print(f"   High (>0.7):   {high_confidence}/{len(all_results)} questions ({high_confidence/len(all_results)*100:.1f}%)")
    print(f"   Medium (0.5-0.7): {medium_confidence}/{len(all_results)} questions ({medium_confidence/len(all_results)*100:.1f}%)")
    print(f"   Low (<0.5):    {low_confidence}/{len(all_results)} questions ({low_confidence/len(all_results)*100:.1f}%)")

    return all_results

print("[SUCCESS] Category testing function ready!")


def test_all_questions(top_k=3, show_detailed=False):
    """Test all questions from all categories"""
    print(f"\n{'='*70}")
    print(f"COMPREHENSIVE RETRIEVAL TEST")
    print(f"{'='*70}")
    print(f"Model: {MODEL_NAME.split('/')[-1]}")
    print(f"Total Categories: {len(questions_data)}")
    print(f"Total Questions: {sum(len(q) for q in questions_data.values())}")
    print(f"Top-K per question: {top_k}")
    print(f"{'='*70}")

    all_category_results = {}

    for category_name in questions_data.keys():
        print(f"\n\n{'█'*70}")
        print(f"CATEGORY: {category_name}")
        print(f"{'█'*70}")

        category_results = test_category_questions(
            category_name,
            top_k=top_k,
            show_full_results=show_detailed
        )
        all_category_results[category_name] = category_results

    # Overall summary
    print(f"\n\n{'='*70}")
    print(f"OVERALL PERFORMANCE SUMMARY")
    print(f"{'='*70}")

    all_scores = []
    for category, results in all_category_results.items():
        scores = [r['top_score'] for r in results]
        all_scores.extend(scores)
        avg = np.mean(scores)
        print(f"\n{category}:")
        print(f"   Questions: {len(results)}")
        print(f"   Avg Score: {avg:.4f}")
        print(f"   Range: {min(scores):.4f} - {max(scores):.4f}")

    # Global statistics
    print(f"\n{'─'*70}")
    print(f"GLOBAL STATISTICS:")
    print(f"   Total Questions Tested: {len(all_scores)}")
    print(f"   Overall Average Score: {np.mean(all_scores):.4f}")
    print(f"   Median Score: {np.median(all_scores):.4f}")
    print(f"   Std Deviation: {np.std(all_scores):.4f}")

    # Overall confidence distribution
    high = sum(1 for s in all_scores if s > 0.7)
    medium = sum(1 for s in all_scores if 0.5 <= s <= 0.7)
    low = sum(1 for s in all_scores if s < 0.5)

    print(f"\n   Overall Confidence Distribution:")
    print(f"      High (>0.7):   {high}/{len(all_scores)} ({high/len(all_scores)*100:.1f}%)")
    print(f"      Medium (0.5-0.7): {medium}/{len(all_scores)} ({medium/len(all_scores)*100:.1f}%)")
    print(f"      Low (<0.5):    {low}/{len(all_scores)} ({low/len(all_scores)*100:.1f}%)")

    return all_category_results

print("[SUCCESS] Comprehensive testing function ready!")




# Create experiment tracking system
experiment_results = []

def save_experiment_results(filename="experiment_results.json"):
    """Save all experiment results to file"""
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(experiment_results, f, indent=2)
    print(f"[SUCCESS] Saved {len(experiment_results)} experiments to {filename}")

def load_experiment_results(filename="experiment_results.json"):
    """Load previous experiment results"""
    global experiment_results
    try:
        with open(filename, 'r', encoding='utf-8') as f:
            experiment_results = json.load(f)
        print(f"[SUCCESS] Loaded {len(experiment_results)} previous experiments")
        return experiment_results
    except FileNotFoundError:
        print(f"[INFO] No previous results found. Starting fresh!")
        return []

# Try to load previous results
load_experiment_results()

print("[SUCCESS] Experiment tracking system ready!")
print(f"Current experiments tracked: {len(experiment_results)}")


def run_full_experiment(experiment_name, chunking_config, embedding_model_name, top_k=3):
    """
    Run a complete experiment with specific chunking and embedding configuration

    Args:
        experiment_name: Descriptive name for this experiment
        chunking_config: Dict with keys 'strategy', 'params' (e.g., percentile, overlap)
        embedding_model_name: HuggingFace model name
        top_k: Number of chunks to retrieve per query
    """
    start_time = time.time()

    print(f"\n{'█'*70}")
    print(f"RUNNING EXPERIMENT: {experiment_name}")
    print(f"{'█'*70}")
    print(f"Chunking: {chunking_config}")
    print(f"Embedding: {embedding_model_name}")
    print(f"Top-K: {top_k}")
    print(f"{'█'*70}\n")

    # Test with all questions
    category_results = test_all_questions(top_k=top_k, show_detailed=False)

    # Calculate metrics
    all_scores = []
    category_scores = {}

    for category, results in category_results.items():
        scores = [r['top_score'] for r in results]
        all_scores.extend(scores)
        category_scores[category] = {
            'avg_score': float(np.mean(scores)),
            'min_score': float(min(scores)),
            'max_score': float(max(scores)),
            'num_questions': len(scores)
        }

    # Compute overall metrics
    elapsed_time = time.time() - start_time

    experiment_data = {
        'experiment_name': experiment_name,
        'timestamp': time.strftime('%Y-%m-%d %H:%M:%S'),
        'chunking_config': chunking_config,
        'embedding_model': embedding_model_name,
        'top_k': top_k,
        'metrics': {
            'overall_avg_score': float(np.mean(all_scores)),
            'overall_median_score': float(np.median(all_scores)),
            'overall_std': float(np.std(all_scores)),
            'min_score': float(min(all_scores)),
            'max_score': float(max(all_scores)),
            'high_confidence_pct': float(sum(1 for s in all_scores if s > 0.7) / len(all_scores) * 100),
            'medium_confidence_pct': float(sum(1 for s in all_scores if 0.5 <= s <= 0.7) / len(all_scores) * 100),
            'low_confidence_pct': float(sum(1 for s in all_scores if s < 0.5) / len(all_scores) * 100),
            'total_questions': len(all_scores),
            'execution_time_seconds': elapsed_time
        },
        'category_metrics': category_scores
    }

    # Save to tracking
    experiment_results.append(experiment_data)
    save_experiment_results()

    print(f"\n{'='*70}")
    print(f"EXPERIMENT COMPLETE: {experiment_name}")
    print(f"{'='*70}")
    print(f"Overall Avg Score: {experiment_data['metrics']['overall_avg_score']:.4f}")
    print(f"High Confidence: {experiment_data['metrics']['high_confidence_pct']:.1f}%")
    print(f"Execution Time: {elapsed_time:.1f}s")
    print(f"{'='*70}\n")

    return experiment_data

print("[SUCCESS] Experiment runner ready!")


def compare_experiments():
    """Compare all tracked experiments and show rankings"""
    if not experiment_results:
        print("[INFO] No experiments to compare yet. Run some experiments first!")
        return

    print(f"\n{'='*80}")
    print(f"EXPERIMENT COMPARISON DASHBOARD")
    print(f"{'='*80}")
    print(f"Total Experiments: {len(experiment_results)}\n")

    # Sort by overall average score
    sorted_experiments = sorted(
        experiment_results,
        key=lambda x: x['metrics']['overall_avg_score'],
        reverse=True
    )

    # Display ranking table
    print(f"{'Rank':<6} {'Experiment Name':<35} {'Avg Score':<12} {'High Conf %':<12} {'Time (s)':<10}")
    print(f"{'─'*80}")

    for i, exp in enumerate(sorted_experiments, 1):
        name = exp['experiment_name'][:33]
        avg_score = exp['metrics']['overall_avg_score']
        high_conf = exp['metrics']['high_confidence_pct']
        exec_time = exp['metrics']['execution_time_seconds']

        print(f"{i:<6} {name:<35} {avg_score:<12.4f} {high_conf:<12.1f} {exec_time:<10.1f}")

    # Show best experiment details
    print(f"\n{'='*80}")
    print(f"🏆 BEST EXPERIMENT: {sorted_experiments[0]['experiment_name']}")
    print(f"{'='*80}")
    best = sorted_experiments[0]

    print(f"\nConfiguration:")
    print(f"   Chunking: {best['chunking_config']}")
    print(f"   Embedding Model: {best['embedding_model']}")
    print(f"   Top-K: {best['top_k']}")

    print(f"\nPerformance Metrics:")
    print(f"   Average Score: {best['metrics']['overall_avg_score']:.4f}")
    print(f"   Median Score: {best['metrics']['overall_median_score']:.4f}")
    print(f"   Std Deviation: {best['metrics']['overall_std']:.4f}")
    print(f"   Score Range: {best['metrics']['min_score']:.4f} - {best['metrics']['max_score']:.4f}")

    print(f"\nConfidence Distribution:")
    print(f"   High (>0.7):   {best['metrics']['high_confidence_pct']:.1f}%")
    print(f"   Medium (0.5-0.7): {best['metrics']['medium_confidence_pct']:.1f}%")
    print(f"   Low (<0.5):    {best['metrics']['low_confidence_pct']:.1f}%")

    print(f"\nCategory Performance:")
    for category, metrics in best['category_metrics'].items():
        print(f"   {category}: {metrics['avg_score']:.4f}")

    # Show comparison with worst
    if len(sorted_experiments) > 1:
        worst = sorted_experiments[-1]
        improvement = ((best['metrics']['overall_avg_score'] - worst['metrics']['overall_avg_score'])
                      / worst['metrics']['overall_avg_score'] * 100)
        print(f"\n📈 Improvement over worst: {improvement:.1f}%")

    print(f"\n{'='*80}\n")

    return sorted_experiments

print("[SUCCESS] Comparison function ready!")


# Quick visualization of experiment results
def plot_experiment_comparison():
    """Create a simple text-based comparison chart"""
    if not experiment_results:
        print("[INFO] No experiments to visualize yet.")
        return

    sorted_exp = sorted(experiment_results, key=lambda x: x['metrics']['overall_avg_score'], reverse=True)

    print(f"\n{'='*70}")
    print(f"EXPERIMENT PERFORMANCE VISUALIZATION")
    print(f"{'='*70}\n")

    # Bar chart of average scores
    print("Average Score Comparison:")
    print("-" * 70)
    max_score = max(e['metrics']['overall_avg_score'] for e in sorted_exp)

    for exp in sorted_exp:
        name = exp['experiment_name'][:30]
        score = exp['metrics']['overall_avg_score']
        bar_length = int((score / max_score) * 40)
        bar = '█' * bar_length
        print(f"{name:<30} {score:.4f} {bar}")

    print()

    # High confidence percentage comparison
    print("High Confidence (>0.7) Percentage:")
    print("-" * 70)
    max_conf = max(e['metrics']['high_confidence_pct'] for e in sorted_exp)

    for exp in sorted_exp:
        name = exp['experiment_name'][:30]
        conf = exp['metrics']['high_confidence_pct']
        bar_length = int((conf / max_conf) * 40) if max_conf > 0 else 0
        bar = '█' * bar_length
        print(f"{name:<30} {conf:>6.1f}% {bar}")

    print(f"\n{'='*70}\n")

print("[SUCCESS] Visualization function ready!")
# Out:
# [SUCCESS] Category testing function ready!
# [SUCCESS] Comprehensive testing function ready!
# [SUCCESS] Loaded 16 previous experiments
# [SUCCESS] Experiment tracking system ready!
# Current experiments tracked: 16
# [SUCCESS] Experiment runner ready!
# [SUCCESS] Comparison function ready!
# [SUCCESS] Visualization function ready!

# %%
# ========================================
# RUN CURRENT EXPERIMENT
# ========================================
# This will test your current chunking + embedding configuration
# against all questions from Questions.json

# Automatically detect current configuration
current_chunking = {
    "strategy": "customchunk",
    # "percentile": PERCENTILE_THRESHOLD if 'PERCENTILE_THRESHOLD' in dir() else 80,
    "percentile": "NA",
    # "buffer_size": BUFFER_SIZE if 'BUFFER_SIZE' in dir() else 1
    "buffer_size": "NA"
}

current_model = MODEL_NAME.split('/')[-1] if 'MODEL_NAME' in dir() else "unknown"

# Generate experiment name
experiment_name = f"CustomChunk + {current_model}"

print(f"Ready to run experiment: {experiment_name}")
print(f"Chunking: {current_chunking}")
print(f"Embedding: {MODEL_NAME if 'MODEL_NAME' in dir() else 'Not set'}")
print("\n🚀 Uncomment the line below to run the experiment:")
print("# run_full_experiment(experiment_name, current_chunking, MODEL_NAME, top_k=5)")

# Uncomment to run:
run_full_experiment(experiment_name, current_chunking, MODEL_NAME, top_k=5)
# Out:
# Ready to run experiment: CustomChunk + multi-qa-mpnet-base-dot-v1
# Chunking: {'strategy': 'customchunk', 'percentile': 'NA', 'buffer_size': 'NA'}
# Embedding: sentence-transformers/multi-qa-mpnet-base-dot-v1
#
# 🚀 Uncomment the line below to run the experiment:
# # run_full_experiment(experiment_name, current_chunking, MODEL_NAME, top_k=5)
#
# ██████████████████████████████████████████████████████████████████████
# RUNNING EXPERIMENT: CustomChunk + multi-qa-mpnet-base-dot-v1
# ██████████████████████████████████████████████████████████████████████
# Chunking: {'strategy': 'customchunk', 'percentile': 'NA', 'buffer_size': 'NA'}
# Embedding: sentence-transformers/multi-qa-mpnet-base-dot-v1
# Top-K: 5
# ██████████████████████████████████████████████████████████████████████
#
#
# ======================================================================
# COMPREHENSIVE RETRIEVAL TEST
# ======================================================================
# Model: multi-qa-mpnet-base-dot-v1
# Total Categories: 8
# Total Questions: 50
# Top-K per question: 5
# ======================================================================
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: Admissions
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: Admissions
# Total Questions: 8
# Model: multi-qa-mpnet-base-dot-v1
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/8
# Q: What are the requirements for new freshmen applying to EARIST?
# Expected Reference: Admission Requirements section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What are the requirements for new freshmen applying to EARIST?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6220 | - Transferees preferably with no grade/s of "Dropped", "Incomplete", and "Failed" may be admitted depending on the availability of slots by the chosen...
#    2. Score: 0.6008 | - Food Technology     - Drafting Technology   ## ARTICLE I ### ADMISSION POLICY  Admission of all students shall be primarily based on academic prepar...
#    3. Score: 0.6002 | - A notarized affidavit of support and proof of adequate financial support - Equivalent High School Diploma   SCREENING PROCESS  There shall be three ...
#    4. Score: 0.5849 | 4. Must have finished the course being taken within the specified years as indicated in the prescribed curriculum. Otherwise, discontinuance of this s...
#    5. Score: 0.5745 | No failed grades in his/her previous semester (for old students)   ##### 4.11.2 Benefits of Student-Athletes  A student-athlete shall be eligible for ...
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/8
# Q: How can I apply for admission as a transferee student?
# Expected Reference: Admission Procedures section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How can I apply for admission as a transferee student?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7043 | - Transferees preferably with no grade/s of "Dropped", "Incomplete", and "Failed" may be admitted depending on the availability of slots by the chosen...
#    2. Score: 0.5962 | Students who did not meet the score requirements of their first-choice program will be advised to apply for admission in his/her second choice of prog...
#    3. Score: 0.5479 | ##### 4.1.4.1 From EARIST Cavite Campus to Manila vice versa—Students may be admitted as transferees upon the recommendation of the EARIST Cavite Camp...
#    4. Score: 0.5416 | #### 8.2.9 Upon his/her return, a student is covered by the curriculum currently in effect.  #### 8.2.10 In case a student loses his/her status as a s...
#    5. Score: 0.5402 | ARTICLE II ACADEMIC POLICIES  Section 1. REGISTRATION AND CROSS ENROLLMENT PROCEDURE  1.1 A student must be officially registered in order to receive ...
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/8
# Q: Does EARIST accept students from other schools?
# Expected Reference: Transfer Student Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Does EARIST accept students from other schools?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5706 | - Transferees preferably with no grade/s of "Dropped", "Incomplete", and "Failed" may be admitted depending on the availability of slots by the chosen...
#    2. Score: 0.5458 | 4. Must have finished the course being taken within the specified years as indicated in the prescribed curriculum. Otherwise, discontinuance of this s...
#    3. Score: 0.5347 | - Food Technology     - Drafting Technology   ## ARTICLE I ### ADMISSION POLICY  Admission of all students shall be primarily based on academic prepar...
#    4. Score: 0.5248 | Through the EARIST Cultural Affairs Division (ECAD), the Institute generates interest and participation in cultural/artistic activities by designing w...
#    5. Score: 0.5205 | 3.6 A student may drop a course by filling out SARRMS Form No. 007 (APPENDIX B, Page 77) and be endorsed by the College Dean/Campus Administration for...
#
# ──────────────────────────────────────────────────────────────────────
# Question 4/8
# Q: Where can I submit my admission documents?
# Expected Reference: Office of Admissions section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Where can I submit my admission documents?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.4983 | - Transferees preferably with no grade/s of "Dropped", "Incomplete", and "Failed" may be admitted depending on the availability of slots by the chosen...
#    2. Score: 0.4768 | ARTICLE II ACADEMIC POLICIES  Section 1. REGISTRATION AND CROSS ENROLLMENT PROCEDURE  1.1 A student must be officially registered in order to receive ...
#    3. Score: 0.4680 | ##### 3.2 For Tertiary, Graduate Programs, and Secondary Laboratory Department  ## ARTICLE IV ### SCHOLARSHIP AND FINANCIAL ASSISTANCE  The UniFAST, t...
#    4. Score: 0.4628 | 13.1 Posters and notices shall be posted only on freedom boards or any other location as may be duly authorized by the Director, OSAS. Such proponents...
#    5. Score: 0.4625 | 15.1 All announcements of Student Affairs and Services are posted on the official social media account (Email/Facebook).  15.2 The documents for appli...
#
# ──────────────────────────────────────────────────────────────────────
# Question 5/8
# Q: When does EARIST usually start accepting new enrollees?
# Expected Reference: Admission Schedule section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'When does EARIST usually start accepting new enrollees?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.4893 | Provided, further, that the Institute shall formulate or adopt such mechanisms related to online payment of fees and charges subject to the requiremen...
#    2. Score: 0.4887 | 4. Must have finished the course being taken within the specified years as indicated in the prescribed curriculum. Otherwise, discontinuance of this s...
#    3. Score: 0.4847 | Through the EARIST Cultural Affairs Division (ECAD), the Institute generates interest and participation in cultural/artistic activities by designing w...
#    4. Score: 0.4723 | - Food Technology     - Drafting Technology   ## ARTICLE I ### ADMISSION POLICY  Admission of all students shall be primarily based on academic prepar...
#    5. Score: 0.4595 | 3.6 A student may drop a course by filling out SARRMS Form No. 007 (APPENDIX B, Page 77) and be endorsed by the College Dean/Campus Administration for...
#
# ──────────────────────────────────────────────────────────────────────
# Question 6/8
# Q: Are there entrance exams required for admission?
# Expected Reference: Entrance Examination section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Are there entrance exams required for admission?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5543 | The evaluation of the interviewer is final and unappealable.  ### Screening Level 3: Program Preparedness Test Program Preparedness Tests are placemen...
#    2. Score: 0.5293 | - Transferees preferably with no grade/s of "Dropped", "Incomplete", and "Failed" may be admitted depending on the availability of slots by the chosen...
#    3. Score: 0.5066 | - A notarized affidavit of support and proof of adequate financial support - Equivalent High School Diploma   SCREENING PROCESS  There shall be three ...
#    4. Score: 0.4940 | ARTICLE II ACADEMIC POLICIES  Section 1. REGISTRATION AND CROSS ENROLLMENT PROCEDURE  1.1 A student must be officially registered in order to receive ...
#    5. Score: 0.4900 | ### 9.4 A candidate for graduation shall have his/her deficiencies made up his record cleared not later than the date specified in the academic calend...
#
# ──────────────────────────────────────────────────────────────────────
# Question 7/8
# Q: Can foreign students apply to EARIST?
# Expected Reference: Foreign Student Admission section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Can foreign students apply to EARIST?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6123 | - Transferees preferably with no grade/s of "Dropped", "Incomplete", and "Failed" may be admitted depending on the availability of slots by the chosen...
#    2. Score: 0.5459 | - Food Technology     - Drafting Technology   ## ARTICLE I ### ADMISSION POLICY  Admission of all students shall be primarily based on academic prepar...
#    3. Score: 0.5323 | 4. Must have finished the course being taken within the specified years as indicated in the prescribed curriculum. Otherwise, discontinuance of this s...
#    4. Score: 0.5206 | - A notarized affidavit of support and proof of adequate financial support - Equivalent High School Diploma   SCREENING PROCESS  There shall be three ...
#    5. Score: 0.5154 | Through the EARIST Cultural Affairs Division (ECAD), the Institute generates interest and participation in cultural/artistic activities by designing w...
#
# ──────────────────────────────────────────────────────────────────────
# Question 8/8
# Q: What documents are needed for returning students to be readmitted?
# Expected Reference: Re-admission Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What documents are needed for returning students to be readmitted?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5688 | #### 8.2.9 Upon his/her return, a student is covered by the curriculum currently in effect.  #### 8.2.10 In case a student loses his/her status as a s...
#    2. Score: 0.5500 | If the new curriculum will be followed by the student, he/she shall be required to enroll and pass the additional general education subjects identifie...
#    3. Score: 0.5204 | - Transferees preferably with no grade/s of "Dropped", "Incomplete", and "Failed" may be admitted depending on the availability of slots by the chosen...
#    4. Score: 0.5016 | No failed grades in his/her previous semester (for old students)   ##### 4.11.2 Benefits of Student-Athletes  A student-athlete shall be eligible for ...
#    5. Score: 0.5011 | 3.7 Failure of a student organization to seek recognition for one (1) school year without justifiable cause shall mean the loss of interest in getting...
#
# ======================================================================
# CATEGORY SUMMARY: Admissions
# ======================================================================
# Average Top Score: 0.5775
# Score Range: 0.4893 - 0.7043
#
# Confidence Distribution:
#    High (>0.7):   1/8 questions (12.5%)
#    Medium (0.5-0.7): 5/8 questions (62.5%)
#    Low (<0.5):    2/8 questions (25.0%)
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: Enrollment and Registration
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: Enrollment and Registration
# Total Questions: 8
# Model: multi-qa-mpnet-base-dot-v1
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/8
# Q: How do I enroll in EARIST after being admitted?
# Expected Reference: Enrollment Procedures section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How do I enroll in EARIST after being admitted?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5921 | 4. Must have finished the course being taken within the specified years as indicated in the prescribed curriculum. Otherwise, discontinuance of this s...
#    2. Score: 0.5615 | 3.6 A student may drop a course by filling out SARRMS Form No. 007 (APPENDIX B, Page 77) and be endorsed by the College Dean/Campus Administration for...
#    3. Score: 0.5378 | - A notarized affidavit of support and proof of adequate financial support - Equivalent High School Diploma   SCREENING PROCESS  There shall be three ...
#    4. Score: 0.5367 | - Transferees preferably with no grade/s of "Dropped", "Incomplete", and "Failed" may be admitted depending on the availability of slots by the chosen...
#    5. Score: 0.5356 | Provided, further, that the Institute shall formulate or adopt such mechanisms related to online payment of fees and charges subject to the requiremen...
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/8
# Q: What is the process for online registration of classes?
# Expected Reference: Registration Process section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What is the process for online registration of classes?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5803 | ARTICLE II ACADEMIC POLICIES  Section 1. REGISTRATION AND CROSS ENROLLMENT PROCEDURE  1.1 A student must be officially registered in order to receive ...
#    2. Score: 0.4901 | 1.4 No student shall be enrolled in more than one college to earn more than one academic degree at the same time.  1.5 No student will be allowed to a...
#    3. Score: 0.4827 | ## ARTICLE III ### PAYMENTS AND REFUND OF FEES  #### Section 1. GENERAL PROVISION  Subject to the provisions of R.A. No. 8292 and its IRR, R.A. No. 10...
#    4. Score: 0.4795 | 2.4 For the intersession class, the regular academic load is 6 units. A student may be allowed to enroll additional three (3) units under the followin...
#    5. Score: 0.4619 | Provided, further, that the Institute shall formulate or adopt such mechanisms related to online payment of fees and charges subject to the requiremen...
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/8
# Q: Can I still enroll if I missed the enrollment period?
# Expected Reference: Late Enrollment Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Can I still enroll if I missed the enrollment period?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.4827 | ARTICLE II ACADEMIC POLICIES  Section 1. REGISTRATION AND CROSS ENROLLMENT PROCEDURE  1.1 A student must be officially registered in order to receive ...
#    2. Score: 0.4557 | 3.7 Failure of a student organization to seek recognition for one (1) school year without justifiable cause shall mean the loss of interest in getting...
#    3. Score: 0.4554 | Students who did not meet the score requirements of their first-choice program will be advised to apply for admission in his/her second choice of prog...
#    4. Score: 0.4527 | Students who have been placed on probation for two successive semesters shall be dropped from the rolls of the College in which he/she is enrolled. Ho...
#    5. Score: 0.4408 | ### 7.5 Students can only be on probation twice. Inability to lift the second probation, a student will be ineligible to enroll for the succeeding sem...
#
# ──────────────────────────────────────────────────────────────────────
# Question 4/8
# Q: How do I change or drop a subject after enrollment?
# Expected Reference: Adding and Dropping of Subjects section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How do I change or drop a subject after enrollment?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5663 | 2.4 For the intersession class, the regular academic load is 6 units. A student may be allowed to enroll additional three (3) units under the followin...
#    2. Score: 0.5556 | 3.6 A student may drop a course by filling out SARRMS Form No. 007 (APPENDIX B, Page 77) and be endorsed by the College Dean/Campus Administration for...
#    3. Score: 0.5123 | Students who did not meet the score requirements of their first-choice program will be advised to apply for admission in his/her second choice of prog...
#    4. Score: 0.4948 | Students who have been placed on probation for two successive semesters shall be dropped from the rolls of the College in which he/she is enrolled. Ho...
#    5. Score: 0.4934 | CURRICULAR OFFERINGS (Approved Changes in Nomenclature)  ### MAIN CAMPUS  #### A. COLLEGE OF ARCHITECTURE AND FINE ARTS (CAFA) - Bachelor of Science i...
#
# ──────────────────────────────────────────────────────────────────────
# Question 5/8
# Q: What should I do if my class schedule conflicts with another subject?
# Expected Reference: Schedule Adjustment Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What should I do if my class schedule conflicts with another subject?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.4830 | 2.4 For the intersession class, the regular academic load is 6 units. A student may be allowed to enroll additional three (3) units under the followin...
#    2. Score: 0.4213 | CURRICULAR OFFERINGS (Approved Changes in Nomenclature)  ### MAIN CAMPUS  #### A. COLLEGE OF ARCHITECTURE AND FINE ARTS (CAFA) - Bachelor of Science i...
#    3. Score: 0.4143 | 3.3.7.1. Students are prohibited from creating unnecessary noise and loitering during class hours. 3.3.7.2. Students must refrain from using gadgets d...
#    4. Score: 0.4093 | Students who still have additional academic subjects currently enrolled (i.e., major and minor courses) are not allowed to have their training outside...
#    5. Score: 0.4064 | ARTICLE II ACADEMIC POLICIES  Section 1. REGISTRATION AND CROSS ENROLLMENT PROCEDURE  1.1 A student must be officially registered in order to receive ...
#
# ──────────────────────────────────────────────────────────────────────
# Question 6/8
# Q: Where can I see the list of courses offered by EARIST?
# Expected Reference: Curriculum Offerings section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Where can I see the list of courses offered by EARIST?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5750 | Through the EARIST Cultural Affairs Division (ECAD), the Institute generates interest and participation in cultural/artistic activities by designing w...
#    2. Score: 0.5506 | Provided, further, that the Institute shall formulate or adopt such mechanisms related to online payment of fees and charges subject to the requiremen...
#    3. Score: 0.5437 | 4. Must have finished the course being taken within the specified years as indicated in the prescribed curriculum. Otherwise, discontinuance of this s...
#    4. Score: 0.5128 | - A notarized affidavit of support and proof of adequate financial support - Equivalent High School Diploma   SCREENING PROCESS  There shall be three ...
#    5. Score: 0.5089 | ##### 4.7.1 The OSAS assists in the accreditation of religious student organizations and its activities inside the Institute.   #### 4.8 Foreign/Inter...
#
# ──────────────────────────────────────────────────────────────────────
# Question 7/8
# Q: Can I enroll in overload subjects this semester?
# Expected Reference: Overload Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Can I enroll in overload subjects this semester?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5550 | 2.4 For the intersession class, the regular academic load is 6 units. A student may be allowed to enroll additional three (3) units under the followin...
#    2. Score: 0.5504 | 1.7 No cross enrollee from another institution shall be admitted into the Institute without the written permission from the Registrar's Office of the ...
#    3. Score: 0.4739 | 1.4 No student shall be enrolled in more than one college to earn more than one academic degree at the same time.  1.5 No student will be allowed to a...
#    4. Score: 0.4691 | Students who still have additional academic subjects currently enrolled (i.e., major and minor courses) are not allowed to have their training outside...
#    5. Score: 0.4504 | ### 7.5 Students can only be on probation twice. Inability to lift the second probation, a student will be ineligible to enroll for the succeeding sem...
#
# ──────────────────────────────────────────────────────────────────────
# Question 8/8
# Q: What are the steps to enroll as a cross-enrollee from another school?
# Expected Reference: Cross-Enrollment section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What are the steps to enroll as a cross-enrollee from another school?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6308 | - Transferees preferably with no grade/s of "Dropped", "Incomplete", and "Failed" may be admitted depending on the availability of slots by the chosen...
#    2. Score: 0.6108 | ARTICLE II ACADEMIC POLICIES  Section 1. REGISTRATION AND CROSS ENROLLMENT PROCEDURE  1.1 A student must be officially registered in order to receive ...
#    3. Score: 0.5971 | Students who did not meet the score requirements of their first-choice program will be advised to apply for admission in his/her second choice of prog...
#    4. Score: 0.5948 | 1.4 No student shall be enrolled in more than one college to earn more than one academic degree at the same time.  1.5 No student will be allowed to a...
#    5. Score: 0.5346 | If the new curriculum will be followed by the student, he/she shall be required to enroll and pass the additional general education subjects identifie...
#
# ======================================================================
# CATEGORY SUMMARY: Enrollment and Registration
# ======================================================================
# Average Top Score: 0.5581
# Score Range: 0.4827 - 0.6308
#
# Confidence Distribution:
#    High (>0.7):   0/8 questions (0.0%)
#    Medium (0.5-0.7): 6/8 questions (75.0%)
#    Low (<0.5):    2/8 questions (25.0%)
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: Fees, Payments and Scholarships
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: Fees, Payments and Scholarships
# Total Questions: 6
# Model: multi-qa-mpnet-base-dot-v1
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/6
# Q: How much is the tuition fee per unit at EARIST?
# Expected Reference: Tuition Fees section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How much is the tuition fee per unit at EARIST?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6621 | Provided, further, that the Institute shall formulate or adopt such mechanisms related to online payment of fees and charges subject to the requiremen...
#    2. Score: 0.5207 | 4. Must have finished the course being taken within the specified years as indicated in the prescribed curriculum. Otherwise, discontinuance of this s...
#    3. Score: 0.5187 | ## ARTICLE III ### PAYMENTS AND REFUND OF FEES  #### Section 1. GENERAL PROVISION  Subject to the provisions of R.A. No. 8292 and its IRR, R.A. No. 10...
#    4. Score: 0.5132 | ##### 3.2 For Tertiary, Graduate Programs, and Secondary Laboratory Department  ## ARTICLE IV ### SCHOLARSHIP AND FINANCIAL ASSISTANCE  The UniFAST, t...
#    5. Score: 0.5125 | ## ARTICLE V ### RIGHTS AND RESPONSIBILITIES OF STUDENTS  #### Section 1. STUDENT RIGHTS  Bonafide students of EARIST shall enjoy the following rights...
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/6
# Q: Are there any miscellaneous fees aside from tuition?
# Expected Reference: Miscellaneous Fees section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Are there any miscellaneous fees aside from tuition?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5878 | Provided, further, that the Institute shall formulate or adopt such mechanisms related to online payment of fees and charges subject to the requiremen...
#    2. Score: 0.5416 | ## ARTICLE III ### PAYMENTS AND REFUND OF FEES  #### Section 1. GENERAL PROVISION  Subject to the provisions of R.A. No. 8292 and its IRR, R.A. No. 10...
#    3. Score: 0.5205 | ###### 2.2.2 Matriculation fees may be paid in cash or installment basis, which term shall be determined by Financial Management Services.  #### Secti...
#    4. Score: 0.4713 | ##### 3.2 For Tertiary, Graduate Programs, and Secondary Laboratory Department  ## ARTICLE IV ### SCHOLARSHIP AND FINANCIAL ASSISTANCE  The UniFAST, t...
#    5. Score: 0.4613 | Subscription fees, savings, donations, grants, and other funds collected from other sources for the Student Publication shall be for its exclusive use...
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/6
# Q: Where can I pay my tuition fees?
# Expected Reference: Payment Procedures section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Where can I pay my tuition fees?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5609 | ## ARTICLE III ### PAYMENTS AND REFUND OF FEES  #### Section 1. GENERAL PROVISION  Subject to the provisions of R.A. No. 8292 and its IRR, R.A. No. 10...
#    2. Score: 0.5296 | ##### 3.2 For Tertiary, Graduate Programs, and Secondary Laboratory Department  ## ARTICLE IV ### SCHOLARSHIP AND FINANCIAL ASSISTANCE  The UniFAST, t...
#    3. Score: 0.4854 | ###### 2.2.2 Matriculation fees may be paid in cash or installment basis, which term shall be determined by Financial Management Services.  #### Secti...
#    4. Score: 0.4717 | Provided, further, that the Institute shall formulate or adopt such mechanisms related to online payment of fees and charges subject to the requiremen...
#    5. Score: 0.4155 | Subscription fees, savings, donations, grants, and other funds collected from other sources for the Student Publication shall be for its exclusive use...
#
# ──────────────────────────────────────────────────────────────────────
# Question 4/6
# Q: Does EARIST offer scholarships or financial aid programs?
# Expected Reference: Scholarships and Grants section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Does EARIST offer scholarships or financial aid programs?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5960 | 4. Must have finished the course being taken within the specified years as indicated in the prescribed curriculum. Otherwise, discontinuance of this s...
#    2. Score: 0.5887 | ##### 3.2 For Tertiary, Graduate Programs, and Secondary Laboratory Department  ## ARTICLE IV ### SCHOLARSHIP AND FINANCIAL ASSISTANCE  The UniFAST, t...
#    3. Score: 0.5545 | Provided, further, that the Institute shall formulate or adopt such mechanisms related to online payment of fees and charges subject to the requiremen...
#    4. Score: 0.5220 | 4. Must have finished the course being taken within the specified years as indicated in the prescribed curriculum. Otherwise, discontinuance of this s...
#    5. Score: 0.5219 | #### 4.2 Scholarship and Financial Assistance The Institute provides scholarships and financial assistance to qualified and deserving students through...
#
# ──────────────────────────────────────────────────────────────────────
# Question 5/6
# Q: How can I apply for an academic scholarship?
# Expected Reference: Academic Scholarship Requirements section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How can I apply for an academic scholarship?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5929 | ##### 3.2 For Tertiary, Graduate Programs, and Secondary Laboratory Department  ## ARTICLE IV ### SCHOLARSHIP AND FINANCIAL ASSISTANCE  The UniFAST, t...
#    2. Score: 0.5413 | 4. Must have finished the course being taken within the specified years as indicated in the prescribed curriculum. Otherwise, discontinuance of this s...
#    3. Score: 0.4974 | 4. Must have finished the course being taken within the specified years as indicated in the prescribed curriculum. Otherwise, discontinuance of this s...
#    4. Score: 0.4738 | - Transferees preferably with no grade/s of "Dropped", "Incomplete", and "Failed" may be admitted depending on the availability of slots by the chosen...
#    5. Score: 0.4382 | CURRICULAR OFFERINGS (Approved Changes in Nomenclature)  ### MAIN CAMPUS  #### A. COLLEGE OF ARCHITECTURE AND FINE ARTS (CAFA) - Bachelor of Science i...
#
# ──────────────────────────────────────────────────────────────────────
# Question 6/6
# Q: What happens if I fail to pay my fees on time?
# Expected Reference: Late Payment Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What happens if I fail to pay my fees on time?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.4774 | ## ARTICLE III ### PAYMENTS AND REFUND OF FEES  #### Section 1. GENERAL PROVISION  Subject to the provisions of R.A. No. 8292 and its IRR, R.A. No. 10...
#    2. Score: 0.4423 | ###### 2.2.2 Matriculation fees may be paid in cash or installment basis, which term shall be determined by Financial Management Services.  #### Secti...
#    3. Score: 0.4220 | Students who have been placed on probation for two successive semesters shall be dropped from the rolls of the College in which he/she is enrolled. Ho...
#    4. Score: 0.3884 | Provided, further, that the Institute shall formulate or adopt such mechanisms related to online payment of fees and charges subject to the requiremen...
#    5. Score: 0.3799 | ### 11.2 Probation  Students who previously have a failing grade and still accumulate one in the succeeding semester in at least one (1) of his/her su...
#
# ======================================================================
# CATEGORY SUMMARY: Fees, Payments and Scholarships
# ======================================================================
# Average Top Score: 0.5795
# Score Range: 0.4774 - 0.6621
#
# Confidence Distribution:
#    High (>0.7):   0/6 questions (0.0%)
#    Medium (0.5-0.7): 5/6 questions (83.3%)
#    Low (<0.5):    1/6 questions (16.7%)
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: Academic Policies and Grading
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: Academic Policies and Grading
# Total Questions: 8
# Model: multi-qa-mpnet-base-dot-v1
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/8
# Q: How is the grading system computed in EARIST?
# Expected Reference: Grading System section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How is the grading system computed in EARIST?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6832 | ## SECTION 6. GRADING SYSTEM  6.1 The students’ academic performance shall be graded in accordance with the following numerical system:  Grade: 1.00 P...
#    2. Score: 0.6105 | - A notarized affidavit of support and proof of adequate financial support - Equivalent High School Diploma   SCREENING PROCESS  There shall be three ...
#    3. Score: 0.5534 | 6.2 At the end of the Semester, only the Faculty Member assigned to a particular subject can give grades to the students listed in the particular clas...
#    4. Score: 0.5452 | The cut-off score in the Program Preparedness Tests, the enhancement courses to be taken by conditionally admitted students, and the equivalent units ...
#    5. Score: 0.5308 | ##### 4.1.4.1 From EARIST Cavite Campus to Manila vice versa—Students may be admitted as transferees upon the recommendation of the EARIST Cavite Camp...
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/8
# Q: What is the passing grade for college students?
# Expected Reference: Academic Standards section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What is the passing grade for college students?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6123 | ## SECTION 6. GRADING SYSTEM  6.1 The students’ academic performance shall be graded in accordance with the following numerical system:  Grade: 1.00 P...
#    2. Score: 0.5860 | ### 9.4 A candidate for graduation shall have his/her deficiencies made up his record cleared not later than the date specified in the academic calend...
#    3. Score: 0.5749 | The cut-off score in the Program Preparedness Tests, the enhancement courses to be taken by conditionally admitted students, and the equivalent units ...
#    4. Score: 0.5512 | ##### 1.9 To seek justification on contested grades imposed by any faculty. In such a case, a student may file a re-computation/rectification in writi...
#    5. Score: 0.5318 | SECTION 11. SCHOLASTIC DELINQUENCY  ### 11.1 Warning  Any student who at the end of the semester obtains final grades of “5.00” in three (3) courses, ...
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/8
# Q: Can I request for grade reconsideration if I believe there was an error?
# Expected Reference: Grade Re-evaluation Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Can I request for grade reconsideration if I believe there was an error?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5427 | 6.6 The No Credit (NC) grade shall only be given to the following: - 6.6.1 OJT/Internship/Practicum of Graduating students; - 6.6.2 Thesis writing of ...
#    2. Score: 0.5308 | #### 6.9 The following are the composition of the Committee on Rectification of Grades: - Chair : Director, Instruction Services - Members :   - Direc...
#    3. Score: 0.4756 | ##### 1.9 To seek justification on contested grades imposed by any faculty. In such a case, a student may file a re-computation/rectification in writi...
#    4. Score: 0.4524 | ## SECTION 6. GRADING SYSTEM  6.1 The students’ academic performance shall be graded in accordance with the following numerical system:  Grade: 1.00 P...
#    5. Score: 0.4511 | ## ARTICLE VIII ### PROCEDURES FOR THE SETTLEMENT OF COMPLAINTS/GRIEVANCES The procedure for the redress and settlement of complaints and grievances i...
#
# ──────────────────────────────────────────────────────────────────────
# Question 4/8
# Q: What is the policy on academic probation or retention?
# Expected Reference: Academic Retention Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What is the policy on academic probation or retention?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6899 | Students who have been placed on probation for two successive semesters shall be dropped from the rolls of the College in which he/she is enrolled. Ho...
#    2. Score: 0.6273 | The Dean's Office/OSAS issues the communication as regards the lifting of the probation status after a counseling session has been held. ### Section 4...
#    3. Score: 0.6153 | ### 11.2 Probation  Students who previously have a failing grade and still accumulate one in the succeeding semester in at least one (1) of his/her su...
#    4. Score: 0.6150 | ## SECTION 8. TENURE, LEAVE OF ABSENCE, AND HONORABLE DISMISSAL  ### 8.1 Tenure  #### 8.1.1 For Regular Students: A regular student should finish the ...
#    5. Score: 0.6107 | Suspension for more than three days will require the approval of the Vice President for Academic Affairs. The suspension is considered as absence volu...
#
# ──────────────────────────────────────────────────────────────────────
# Question 5/8
# Q: How do I qualify for the Dean’s List?
# Expected Reference: Honors and Awards section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How do I qualify for the Dean’s List?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5634 | - Transferees preferably with no grade/s of "Dropped", "Incomplete", and "Failed" may be admitted depending on the availability of slots by the chosen...
#    2. Score: 0.5351 | ### 9.4 A candidate for graduation shall have his/her deficiencies made up his record cleared not later than the date specified in the academic calend...
#    3. Score: 0.4999 | The cut-off score in the Program Preparedness Tests, the enhancement courses to be taken by conditionally admitted students, and the equivalent units ...
#    4. Score: 0.4878 | #### 8.2.9 Upon his/her return, a student is covered by the curriculum currently in effect.  #### 8.2.10 In case a student loses his/her status as a s...
#    5. Score: 0.4773 | ARTICLE II ACADEMIC POLICIES  Section 1. REGISTRATION AND CROSS ENROLLMENT PROCEDURE  1.1 A student must be officially registered in order to receive ...
#
# ──────────────────────────────────────────────────────────────────────
# Question 6/8
# Q: What should I do if I failed a subject?
# Expected Reference: Repetition of Subjects section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What should I do if I failed a subject?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.4659 | ##### 1.9 To seek justification on contested grades imposed by any faculty. In such a case, a student may file a re-computation/rectification in writi...
#    2. Score: 0.4516 | Students who have been placed on probation for two successive semesters shall be dropped from the rolls of the College in which he/she is enrolled. Ho...
#    3. Score: 0.4438 | ### 7.5 Students can only be on probation twice. Inability to lift the second probation, a student will be ineligible to enroll for the succeeding sem...
#    4. Score: 0.4356 | ### 9.4 A candidate for graduation shall have his/her deficiencies made up his record cleared not later than the date specified in the academic calend...
#    5. Score: 0.4346 | #### 6.9 The following are the composition of the Committee on Rectification of Grades: - Chair : Director, Instruction Services - Members :   - Direc...
#
# ──────────────────────────────────────────────────────────────────────
# Question 7/8
# Q: Can I take make-up exams for missed tests?
# Expected Reference: Make-up Examination Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Can I take make-up exams for missed tests?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.4007 | The evaluation of the interviewer is final and unappealable.  ### Screening Level 3: Program Preparedness Test Program Preparedness Tests are placemen...
#    2. Score: 0.3783 | ##### 4.4.3 For persons with orthopedic handicaps – the requirements provided for by Batas Pambansa Bilang 344, otherwise known as the Accessibility L...
#    3. Score: 0.3739 | The cut-off score in the Program Preparedness Tests, the enhancement courses to be taken by conditionally admitted students, and the equivalent units ...
#    4. Score: 0.3490 | 2.4 For the intersession class, the regular academic load is 6 units. A student may be allowed to enroll additional three (3) units under the followin...
#    5. Score: 0.3487 | - Transferees preferably with no grade/s of "Dropped", "Incomplete", and "Failed" may be admitted depending on the availability of slots by the chosen...
#
# ──────────────────────────────────────────────────────────────────────
# Question 8/8
# Q: What is the policy on incomplete grades?
# Expected Reference: Incomplete Grade section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What is the policy on incomplete grades?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6133 | ## SECTION 6. GRADING SYSTEM  6.1 The students’ academic performance shall be graded in accordance with the following numerical system:  Grade: 1.00 P...
#    2. Score: 0.6000 | ##### 1.9 To seek justification on contested grades imposed by any faculty. In such a case, a student may file a re-computation/rectification in writi...
#    3. Score: 0.5930 | ### 9.4 A candidate for graduation shall have his/her deficiencies made up his record cleared not later than the date specified in the academic calend...
#    4. Score: 0.5873 | 6.2 At the end of the Semester, only the Faculty Member assigned to a particular subject can give grades to the students listed in the particular clas...
#    5. Score: 0.5852 | SECTION 11. SCHOLASTIC DELINQUENCY  ### 11.1 Warning  Any student who at the end of the semester obtains final grades of “5.00” in three (3) courses, ...
#
# ======================================================================
# CATEGORY SUMMARY: Academic Policies and Grading
# ======================================================================
# Average Top Score: 0.5714
# Score Range: 0.4007 - 0.6899
#
# Confidence Distribution:
#    High (>0.7):   0/8 questions (0.0%)
#    Medium (0.5-0.7): 6/8 questions (75.0%)
#    Low (<0.5):    2/8 questions (25.0%)
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: Attendance and Conduct
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: Attendance and Conduct
# Total Questions: 6
# Model: multi-qa-mpnet-base-dot-v1
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/6
# Q: What happens if I exceed the number of absences allowed?
# Expected Reference: Attendance Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What happens if I exceed the number of absences allowed?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.4823 | ## SECTION 8. TENURE, LEAVE OF ABSENCE, AND HONORABLE DISMISSAL  ### 8.1 Tenure  #### 8.1.1 For Regular Students: A regular student should finish the ...
#    2. Score: 0.4678 | Suspension for more than three days will require the approval of the Vice President for Academic Affairs. The suspension is considered as absence volu...
#    3. Score: 0.4592 | ## ARTICLE VII ### DISCIPLINARY SANCTIONS These disciplinary sanctions shall be imposed for the commission of any offense defined in this Handbook or ...
#    4. Score: 0.4504 | Students who have been placed on probation for two successive semesters shall be dropped from the rolls of the College in which he/she is enrolled. Ho...
#    5. Score: 0.4369 | ### 11.2 Probation  Students who previously have a failing grade and still accumulate one in the succeeding semester in at least one (1) of his/her su...
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/6
# Q: Are students required to wear uniforms in EARIST?
# Expected Reference: Student Uniform Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Are students required to wear uniforms in EARIST?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6488 | 3.1.1. A pregnant student may be allowed not to wear the prescribed uniform by submitting a medical certification validated by the EARIST Medical Offi...
#    2. Score: 0.6187 | Students, as individuals or groups, shall not be allowed to use the name and logo of the Institute without the recommendation of the activity adviser/...
#    3. Score: 0.5622 | 3.2.2.1. 2nd loss – “Negligence” (Minor Offense), requires parent conference. 3.2.2.2. 3rd loss – “Gross Negligence” (Major Offense), subject to disci...
#    4. Score: 0.5312 | 4.1.1.35. Unauthorized posting of class videos, recordings, pictures or statements in social media 4.1.1.36. Other similar acts that violate the right...
#    5. Score: 0.5309 | No failed grades in his/her previous semester (for old students)   ##### 4.11.2 Benefits of Student-Athletes  A student-athlete shall be eligible for ...
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/6
# Q: What are the disciplinary actions for students who violate school rules?
# Expected Reference: Code of Discipline section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What are the disciplinary actions for students who violate school rules?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6912 | 4.1.1.14. Instigating, leading or participating in any concerted activity leading to stoppage of classes or preventing students/faculty members/admini...
#    2. Score: 0.6680 | ## ARTICLE VII ### DISCIPLINARY SANCTIONS These disciplinary sanctions shall be imposed for the commission of any offense defined in this Handbook or ...
#    3. Score: 0.6626 | 3.3.7.1. Students are prohibited from creating unnecessary noise and loitering during class hours. 3.3.7.2. Students must refrain from using gadgets d...
# ...
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: Graduation and Academic Completion
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: Graduation and Academic Completion
# Total Questions: 5
# Model: multi-qa-mpnet-base-dot-v1
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/5
# Q: What are the requirements to graduate from EARIST?
# Expected Reference: Graduation Requirements section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What are the requirements to graduate from EARIST?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6173 | - A notarized affidavit of support and proof of adequate financial support - Equivalent High School Diploma   SCREENING PROCESS  There shall be three ...
#    2. Score: 0.6162 | 4. Must have finished the course being taken within the specified years as indicated in the prescribed curriculum. Otherwise, discontinuance of this s...
#    3. Score: 0.5958 | - Transferees preferably with no grade/s of "Dropped", "Incomplete", and "Failed" may be admitted depending on the availability of slots by the chosen...
#    4. Score: 0.5871 | Through the EARIST Cultural Affairs Division (ECAD), the Institute generates interest and participation in cultural/artistic activities by designing w...
#    5. Score: 0.5843 | - Doctor in Business Administration - Doctor in Public Administration   EARIST - CAVITE CAMPUS  #### J. Graduate Program - Doctor in Education   - Maj...
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/5
# Q: When are graduation applications usually submitted?
# Expected Reference: Application for Graduation section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'When are graduation applications usually submitted?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.4557 | #### 8.2.9 Upon his/her return, a student is covered by the curriculum currently in effect.  #### 8.2.10 In case a student loses his/her status as a s...
#    2. Score: 0.4507 | ### 9.4 A candidate for graduation shall have his/her deficiencies made up his record cleared not later than the date specified in the academic calend...
#    3. Score: 0.4188 | - Food Technology     - Drafting Technology   ## ARTICLE I ### ADMISSION POLICY  Admission of all students shall be primarily based on academic prepar...
#    4. Score: 0.4181 | 15.1 All announcements of Student Affairs and Services are posted on the official social media account (Email/Facebook).  15.2 The documents for appli...
#    5. Score: 0.4165 | The cut-off score in the Program Preparedness Tests, the enhancement courses to be taken by conditionally admitted students, and the equivalent units ...
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/5
# Q: Can I join the graduation ceremony if I still have incomplete grades?
# Expected Reference: Graduation Eligibility section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Can I join the graduation ceremony if I still have incomplete grades?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5872 | ### 9.4 A candidate for graduation shall have his/her deficiencies made up his record cleared not later than the date specified in the academic calend...
#    2. Score: 0.4861 | #### 8.2.9 Upon his/her return, a student is covered by the curriculum currently in effect.  #### 8.2.10 In case a student loses his/her status as a s...
#    3. Score: 0.4858 | - Transferees preferably with no grade/s of "Dropped", "Incomplete", and "Failed" may be admitted depending on the availability of slots by the chosen...
#    4. Score: 0.4622 | Students who did not meet the score requirements of their first-choice program will be advised to apply for admission in his/her second choice of prog...
#    5. Score: 0.4553 | ##### 1.9 To seek justification on contested grades imposed by any faculty. In such a case, a student may file a re-computation/rectification in writi...
#
# ──────────────────────────────────────────────────────────────────────
# Question 4/5
# Q: How can I request for my diploma or transcript after graduation?
# Expected Reference: Post-Graduation Document Request section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How can I request for my diploma or transcript after graduation?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5267 | ### 9.4 A candidate for graduation shall have his/her deficiencies made up his record cleared not later than the date specified in the academic calend...
#    2. Score: 0.5134 | #### 8.2.9 Upon his/her return, a student is covered by the curriculum currently in effect.  #### 8.2.10 In case a student loses his/her status as a s...
#    3. Score: 0.4809 | - Transferees preferably with no grade/s of "Dropped", "Incomplete", and "Failed" may be admitted depending on the availability of slots by the chosen...
#    4. Score: 0.4531 | ## ARTICLE V ### RIGHTS AND RESPONSIBILITIES OF STUDENTS  #### Section 1. STUDENT RIGHTS  Bonafide students of EARIST shall enjoy the following rights...
#    5. Score: 0.4517 | If the new curriculum will be followed by the student, he/she shall be required to enroll and pass the additional general education subjects identifie...
#
# ──────────────────────────────────────────────────────────────────────
# Question 5/5
# Q: Does EARIST hold recognition ceremonies for honor students?
# Expected Reference: Honors and Recognition section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Does EARIST hold recognition ceremonies for honor students?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5423 | 15.1 All announcements of Student Affairs and Services are posted on the official social media account (Email/Facebook).  15.2 The documents for appli...
#    2. Score: 0.5326 | No failed grades in his/her previous semester (for old students)   ##### 4.11.2 Benefits of Student-Athletes  A student-athlete shall be eligible for ...
#    3. Score: 0.5106 | ## ARTICLE V ### RIGHTS AND RESPONSIBILITIES OF STUDENTS  #### Section 1. STUDENT RIGHTS  Bonafide students of EARIST shall enjoy the following rights...
#    4. Score: 0.4953 | Through the EARIST Cultural Affairs Division (ECAD), the Institute generates interest and participation in cultural/artistic activities by designing w...
#    5. Score: 0.4744 | ### 9.4 A candidate for graduation shall have his/her deficiencies made up his record cleared not later than the date specified in the academic calend...
#
# ======================================================================
# CATEGORY SUMMARY: Graduation and Academic Completion
# ======================================================================
# Average Top Score: 0.5458
# Score Range: 0.4557 - 0.6173
#
# Confidence Distribution:
#    High (>0.7):   0/5 questions (0.0%)
#    Medium (0.5-0.7): 4/5 questions (80.0%)
#    Low (<0.5):    1/5 questions (20.0%)
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: General and Miscellaneous Information
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: General and Miscellaneous Information
# Total Questions: 3
# Model: multi-qa-mpnet-base-dot-v1
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/3
# Q: Where is the EARIST main campus located?
# Expected Reference: Institutional Information section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Where is the EARIST main campus located?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5199 | Through the EARIST Cultural Affairs Division (ECAD), the Institute generates interest and participation in cultural/artistic activities by designing w...
#    2. Score: 0.5142 | Provided, further, that the Institute shall formulate or adopt such mechanisms related to online payment of fees and charges subject to the requiremen...
#    3. Score: 0.5104 | ## ARTICLE V ### RIGHTS AND RESPONSIBILITIES OF STUDENTS  #### Section 1. STUDENT RIGHTS  Bonafide students of EARIST shall enjoy the following rights...
#    4. Score: 0.5103 | CURRICULAR OFFERINGS (Approved Changes in Nomenclature)  ### MAIN CAMPUS  #### A. COLLEGE OF ARCHITECTURE AND FINE ARTS (CAFA) - Bachelor of Science i...
#    5. Score: 0.4968 | 6. Finished Phase I (June 14, 1999) of the Multi-Purpose Sports Complex Gymnasium with a 2.5M appropriation from Speaker Jose C. De Venecia, Jr. 7. Co...
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/3
# Q: Who is the current president of EARIST?
# Expected Reference: Administration section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Who is the current president of EARIST?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5404 | Board of Trustees Republic of the Philippines EULOGIO "AMANG" RODRIGUEZ INSTITUTE OF SCIENCE AND TECHNOLOGY Nagtahan, Sampoc, Manila  BOARD OF TRUSTEE...
#    2. Score: 0.5203 | HISTORY OF EARIST  The Eulogio "Amang" Rodriguez Institute of Science and Technology (EARIST) was established after the liberation of Manila in 1945. ...
#    3. Score: 0.4855 | Republic of the Philippines EULOGIO "AMANG" RODRIGUEZ INSTITUTE OF SCIENCE AND TECHNOLOGY Nagtahan, Sampoc, Manila  INSTITUTE OFFICIAL  DR. EDITHA V. ...
#    4. Score: 0.4830 | Chairman, EARIST Grievance Committee and College Legal Counsel MS. GILDA S. FAMILARA College & Board Secretary CHAIR DR. FREDERICK C. PENA Vice Presid...
#    5. Score: 0.4655 | ## ARTICLE V ### RIGHTS AND RESPONSIBILITIES OF STUDENTS  #### Section 1. STUDENT RIGHTS  Bonafide students of EARIST shall enjoy the following rights...
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/3
# Q: What are the official communication channels of EARIST for students?
# Expected Reference: Official Communication Channels section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What are the official communication channels of EARIST for students?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5974 | Section 3 – Any bonafide faculty, administrative employee, or student that desires to present a cultural program/activity shall submit the following t...
#    2. Score: 0.5832 | ## ARTICLE V ### RIGHTS AND RESPONSIBILITIES OF STUDENTS  #### Section 1. STUDENT RIGHTS  Bonafide students of EARIST shall enjoy the following rights...
#    3. Score: 0.5784 | #### 2.4 Student Discipline Judicious implementation of institutional rules and regulations governing student behavior and conduct (Refer to Article 6...
#    4. Score: 0.5660 | 13.1 Posters and notices shall be posted only on freedom boards or any other location as may be duly authorized by the Director, OSAS. Such proponents...
#    5. Score: 0.5470 | 4.1.1.35. Unauthorized posting of class videos, recordings, pictures or statements in social media 4.1.1.36. Other similar acts that violate the right...
#
# ======================================================================
# CATEGORY SUMMARY: General and Miscellaneous Information
# ======================================================================
# Average Top Score: 0.5525
# Score Range: 0.5199 - 0.5974
#
# Confidence Distribution:
#    High (>0.7):   0/3 questions (0.0%)
#    Medium (0.5-0.7): 3/3 questions (100.0%)
#    Low (<0.5):    0/3 questions (0.0%)
#
#
# ======================================================================
# OVERALL PERFORMANCE SUMMARY
# ======================================================================
#
# Admissions:
#    Questions: 8
#    Avg Score: 0.5775
#    Range: 0.4893 - 0.7043
#
# Enrollment and Registration:
#    Questions: 8
#    Avg Score: 0.5581
#    Range: 0.4827 - 0.6308
#
# Fees, Payments and Scholarships:
#    Questions: 6
#    Avg Score: 0.5795
#    Range: 0.4774 - 0.6621
#
# Academic Policies and Grading:
#    Questions: 8
#    Avg Score: 0.5714
#    Range: 0.4007 - 0.6899
#
# Attendance and Conduct:
#    Questions: 6
#    Avg Score: 0.5885
#    Range: 0.4296 - 0.6912
#
# Student Services and Organizations:
#    Questions: 6
#    Avg Score: 0.5060
#    Range: 0.4698 - 0.5553
#
# Graduation and Academic Completion:
#    Questions: 5
#    Avg Score: 0.5458
#    Range: 0.4557 - 0.6173
#
# General and Miscellaneous Information:
#    Questions: 3
#    Avg Score: 0.5525
#    Range: 0.5199 - 0.5974
#
# ──────────────────────────────────────────────────────────────────────
# GLOBAL STATISTICS:
#    Total Questions Tested: 50
#    Overall Average Score: 0.5617
#    Median Score: 0.5648
#    Std Deviation: 0.0711
#
#    Overall Confidence Distribution:
#       High (>0.7):   1/50 (2.0%)
#       Medium (0.5-0.7): 36/50 (72.0%)
#       Low (<0.5):    13/50 (26.0%)
# [SUCCESS] Saved 17 experiments to experiment_results.json
#
# ======================================================================
# EXPERIMENT COMPLETE: CustomChunk + multi-qa-mpnet-base-dot-v1
# ======================================================================
# Overall Avg Score: 0.5617
# High Confidence: 2.0%
# Execution Time: 0.6s
# ======================================================================
# {'experiment_name': 'CustomChunk + multi-qa-mpnet-base-dot-v1',
#  'timestamp': '2025-10-26 19:40:08',
#  'chunking_config': {'strategy': 'customchunk',
#   'percentile': 'NA',
#   'buffer_size': 'NA'},
#  'embedding_model': 'sentence-transformers/multi-qa-mpnet-base-dot-v1',
#  'top_k': 5,
#  'metrics': {'overall_avg_score': 0.5617463183403015,
#   'overall_median_score': 0.5648342072963715,
#   'overall_std': 0.0711441703210817,
#   'min_score': 0.400662899017334,
#   'max_score': 0.704254150390625,
#   'high_confidence_pct': 2.0,
#   'medium_confidence_pct': 72.0,
#   'low_confidence_pct': 26.0,
#   'total_questions': 50,
#   'execution_time_seconds': 0.6409101486206055},
#  'category_metrics': {'Admissions': {'avg_score': 0.5774774923920631,
#    'min_score': 0.4893261790275574,
#    'max_score': 0.704254150390625,
#    'num_questions': 8},
#   'Enrollment and Registration': {'avg_score': 0.5581474117934704,
#    'min_score': 0.4826532304286957,
#    'max_score': 0.6307817697525024,
#    'num_questions': 8},
#   'Fees, Payments and Scholarships': {'avg_score': 0.5795117169618607,
#    'min_score': 0.4774486720561981,
#    'max_score': 0.6621416807174683,
#    'num_questions': 6},
#   'Academic Policies and Grading': {'avg_score': 0.5714250132441521,
#    'min_score': 0.400662899017334,
#    'max_score': 0.689899742603302,
#    'num_questions': 8},
#   'Attendance and Conduct': {'avg_score': 0.5885165929794312,
#    'min_score': 0.42963284254074097,
#    'max_score': 0.6911693811416626,
#    'num_questions': 6},
#   'Student Services and Organizations': {'avg_score': 0.5060069213310877,
#    'min_score': 0.4698053300380707,
#    'max_score': 0.5553181171417236,
#    'num_questions': 6},
#   'Graduation and Academic Completion': {'avg_score': 0.5458185374736786,
#    'min_score': 0.4556511342525482,
#    'max_score': 0.6172673106193542,
#    'num_questions': 5},
#   'General and Miscellaneous Information': {'avg_score': 0.5525375008583069,
#    'min_score': 0.519854724407196,
#    'max_score': 0.5973775386810303,
#    'num_questions': 3}}}

# %%
# ========================================
# VIEW RESULTS & COMPARISON
# ========================================

# Show comparison dashboard
compare_experiments()

# Show visual comparison
plot_experiment_comparison()
# Out:
# ================================================================================
# EXPERIMENT COMPARISON DASHBOARD
# ================================================================================
# Total Experiments: 17
#
# Rank   Experiment Name                     Avg Score    High Conf %  Time (s)
# ────────────────────────────────────────────────────────────────────────────────
# 1      P50-multi-qa-mpnet-base-dot-v1      0.6408       22.0         0.6
# 2      P50-multi-qa-mpnet-base-dot-v1      0.6408       22.0         1.6
# 3      P50-multi-qa-mpnet-base-dot-v1      0.6341       12.0         1.6
# 4      P45-multi-qa-mpnet-base-dot-v1      0.6318       12.0         0.6
# 5      P45-multi-qa-mpnet-base-dot-v1      0.6318       12.0         0.6
# 6      P60-multi-qa-mpnet-base-dot-v1      0.6259       16.0         1.6
# 7      P65-multi-qa-mpnet-base-dot-v1      0.6230       16.0         1.6
# 8      P50-multi-qa-mpnet-base-dot-v1      0.6226       8.0          1.7
# 9      P70-multi-qa-mpnet-base-dot-v1      0.6213       14.0         1.6
# 10     P50-multi-qa-mpnet-base-dot-v1      0.6189       12.0         0.6
# 11     P75-multi-qa-mpnet-base-dot-v1      0.6122       14.0         1.6
# 12     P70-multi-qa-mpnet-base-dot-v1      0.6093       10.0         0.7
# 13     P65-all-mpnet-base-v2               0.5826       8.0          1.5
# 14     P70-all-mpnet-base-v2               0.5790       8.0          1.6
# 15     P75-all-mpnet-base-v2               0.5693       8.0          1.5
# 16     CustomChunk + multi-qa-mpnet-base   0.5617       2.0          0.6
# 17     P80-all-mpnet-base-v2               0.5588       6.0          1.6
#
# ================================================================================
# 🏆 BEST EXPERIMENT: P50-multi-qa-mpnet-base-dot-v1
# ================================================================================
#
# Configuration:
#    Chunking: {'strategy': 'semantic', 'percentile': 50, 'buffer_size': 1}
#    Embedding Model: sentence-transformers/multi-qa-mpnet-base-dot-v1
#    Top-K: 5
#
# Performance Metrics:
#    Average Score: 0.6408
#    Median Score: 0.6387
#    Std Deviation: 0.0649
#    Score Range: 0.4770 - 0.7936
#
# Confidence Distribution:
#    High (>0.7):   22.0%
#    Medium (0.5-0.7): 76.0%
#    Low (<0.5):    2.0%
#
# Category Performance:
#    Admissions: 0.6550
#    Enrollment and Registration: 0.6592
#    Fees, Payments and Scholarships: 0.6438
#    Academic Policies and Grading: 0.6642
#    Attendance and Conduct: 0.6208
#    Student Services and Organizations: 0.5941
#    Graduation and Academic Completion: 0.6238
#    General and Miscellaneous Information: 0.6471
#
# 📈 Improvement over worst: 14.7%
#
# ================================================================================
#
#
# ======================================================================
# EXPERIMENT PERFORMANCE VISUALIZATION
# ======================================================================
#
# Average Score Comparison:
# ----------------------------------------------------------------------
# P50-multi-qa-mpnet-base-dot-v1 0.6408 ████████████████████████████████████████
# P50-multi-qa-mpnet-base-dot-v1 0.6408 ███████████████████████████████████████
# P50-multi-qa-mpnet-base-dot-v1 0.6341 ███████████████████████████████████████
# P45-multi-qa-mpnet-base-dot-v1 0.6318 ███████████████████████████████████████
# P45-multi-qa-mpnet-base-dot-v1 0.6318 ███████████████████████████████████████
# P60-multi-qa-mpnet-base-dot-v1 0.6259 ███████████████████████████████████████
# P65-multi-qa-mpnet-base-dot-v1 0.6230 ██████████████████████████████████████
# P50-multi-qa-mpnet-base-dot-v1 0.6226 ██████████████████████████████████████
# P70-multi-qa-mpnet-base-dot-v1 0.6213 ██████████████████████████████████████
# P50-multi-qa-mpnet-base-dot-v1 0.6189 ██████████████████████████████████████
# P75-multi-qa-mpnet-base-dot-v1 0.6122 ██████████████████████████████████████
# P70-multi-qa-mpnet-base-dot-v1 0.6093 ██████████████████████████████████████
# P65-all-mpnet-base-v2          0.5826 ████████████████████████████████████
# P70-all-mpnet-base-v2          0.5790 ████████████████████████████████████
# P75-all-mpnet-base-v2          0.5693 ███████████████████████████████████
# CustomChunk + multi-qa-mpnet-b 0.5617 ███████████████████████████████████
# P80-all-mpnet-base-v2          0.5588 ██████████████████████████████████
#
# High Confidence (>0.7) Percentage:
# ----------------------------------------------------------------------
# P50-multi-qa-mpnet-base-dot-v1   22.0% ████████████████████████████████████████
# P50-multi-qa-mpnet-base-dot-v1   22.0% ████████████████████████████████████████
# P50-multi-qa-mpnet-base-dot-v1   12.0% █████████████████████
# P45-multi-qa-mpnet-base-dot-v1   12.0% █████████████████████
# P45-multi-qa-mpnet-base-dot-v1   12.0% █████████████████████
# P60-multi-qa-mpnet-base-dot-v1   16.0% █████████████████████████████
# P65-multi-qa-mpnet-base-dot-v1   16.0% █████████████████████████████
# P50-multi-qa-mpnet-base-dot-v1    8.0% ██████████████
# P70-multi-qa-mpnet-base-dot-v1   14.0% █████████████████████████
# P50-multi-qa-mpnet-base-dot-v1   12.0% █████████████████████
# P75-multi-qa-mpnet-base-dot-v1   14.0% █████████████████████████
# P70-multi-qa-mpnet-base-dot-v1   10.0% ██████████████████
# P65-all-mpnet-base-v2             8.0% ██████████████
# P70-all-mpnet-base-v2             8.0% ██████████████
# P75-all-mpnet-base-v2             8.0% ██████████████
# CustomChunk + multi-qa-mpnet-b    2.0% ███
# P80-all-mpnet-base-v2             6.0% ██████████
#
# ======================================================================
