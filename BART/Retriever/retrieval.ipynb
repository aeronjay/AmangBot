# %%
with open('../Dataset/StudentHandbookDataset.txt', 'r', encoding='utf-8') as f:
    dataset = f.read()

print(f"Dataset loaded: {len(dataset):,} characters")
print(f"Estimated pages: ~{len(dataset) // 2000}")
# Out:
# Dataset loaded: 171,284 characters
# Estimated pages: ~85

# %%
import torch
from langchain_experimental.text_splitter import SemanticChunker
from langchain_community.embeddings import HuggingFaceEmbeddings
import faiss
import numpy as np
import pickle
import os
import warnings
warnings.filterwarnings('ignore')

# %%
def check_chunks_exist():
    """Check if chunks have been saved"""
    return os.path.exists("saved_chunks/chunks.pkl")

def save_chunks(chunks, filename="saved_chunks/chunks.pkl"):
    """Save chunks to disk"""
    os.makedirs("saved_chunks", exist_ok=True)
    with open(filename, 'wb') as f:
        pickle.dump(chunks, f)
    print(f"[SUCCESS] Saved {len(chunks)} chunks to {filename}")

def load_chunks(filename="saved_chunks/chunks.pkl"):
    """Load chunks from disk"""
    try:
        with open(filename, 'rb') as f:
            chunks = pickle.load(f)
        print(f"[SUCCESS] Loaded {len(chunks)} chunks from {filename}")
        return chunks
    except FileNotFoundError:
        print(f"[ERROR] Chunks file not found: {filename}")
        return None

# Check if chunks already exist
if check_chunks_exist():
    print("[SUCCESS] Chunks file found! You can skip to Step 2 (Embedding Experiments)")
    print("[INFO] To reload chunks, run: chunks = load_chunks()")
else:
    print("[INFO] No saved chunks found. Run the chunking cells below.")
# Out:
# [INFO] No saved chunks found. Run the chunking cells below.

# %%
# ========================================
# EXPERIMENT PARAMETER: CHUNKING STRATEGY
# ========================================
# Change these values to experiment with different chunking!

CHUNKING_STRATEGY = "semantic"  # Options: "semantic", "fixed" (future)
PERCENTILE_THRESHOLD = 50       # Try: 70, 75, 80, 85, 90 (higher = fewer, larger chunks)
BUFFER_SIZE = 1                 # Sentences to merge around breakpoints

# ========================================

# ONLY RUN THIS IF CHUNKS DON'T EXIST OR YOU WANT TO RE-CHUNK
print(f"Loading embedding model for {CHUNKING_STRATEGY} chunking...")
print("   Using CPU for stable performance")

chunking_embed_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2",
    model_kwargs={'device': 'cuda' if torch.cuda.is_available() else 'cpu'},
    encode_kwargs={'normalize_embeddings': True}
)

print(f"Setting up semantic chunker with PERCENTILE={PERCENTILE_THRESHOLD}...")
text_splitter = SemanticChunker(
    embeddings=chunking_embed_model,
    breakpoint_threshold_type="percentile",
    breakpoint_threshold_amount=PERCENTILE_THRESHOLD,
    buffer_size=BUFFER_SIZE,
    add_start_index=True
)
print(f"[SUCCESS] Chunker ready (Percentile: {PERCENTILE_THRESHOLD}, Buffer: {BUFFER_SIZE})!")

# ONLY RUN THIS IF CHUNKS DON'T EXIST OR YOU WANT TO RE-CHUNK
print("Creating semantic chunks from raw text...")
print(f"Configuration: Percentile={PERCENTILE_THRESHOLD}, Buffer={BUFFER_SIZE}")
chunks = text_splitter.create_documents([dataset])
print(f"[SUCCESS] Created {len(chunks)} semantic chunks")

# Analyze chunk quality
chunk_sizes = [len(chunk.page_content) for chunk in chunks]
print(f"\nChunk Analysis:")
print(f"   Average size: {np.mean(chunk_sizes):.0f} characters")
print(f"   Size range: {min(chunk_sizes)} - {max(chunk_sizes)} characters")
print(f"   Total chunks: {len(chunks)}")

# Show sample chunks
print("\nSample chunks:")
for i in range(min(3, len(chunks))):
    chunk_preview = chunks[i].page_content[:150].replace('\n', ' ')
    print(f"   Chunk {i+1}: {chunk_preview}...")

# SAVE THE CHUNKS with configuration in filename
chunk_filename = f"saved_chunks/chunks_p{PERCENTILE_THRESHOLD}_b{BUFFER_SIZE}.pkl"
save_chunks(chunks, filename=chunk_filename)
print(f"\n[SUCCESS] Chunking complete and saved to {chunk_filename}!")
print(f"[INFO] Configuration: Percentile={PERCENTILE_THRESHOLD}, Buffer={BUFFER_SIZE}")

# Load saved chunks - automatically detect the correct file based on parameters
chunk_filename = f"saved_chunks/chunks_p{PERCENTILE_THRESHOLD}_b{BUFFER_SIZE}.pkl"

print(f"Looking for chunks: {chunk_filename}")
chunks = load_chunks(filename=chunk_filename)

if chunks is None:
    print(f"[ERROR] Chunks not found for P={PERCENTILE_THRESHOLD}, B={BUFFER_SIZE}")
    print("[INFO] Please run Step 1 (Chunking) cells first with these parameters!")
else:
    print(f"[SUCCESS] Ready to experiment with {len(chunks)} chunks!")
    print(f"[INFO] Loaded configuration: Percentile={PERCENTILE_THRESHOLD}, Buffer={BUFFER_SIZE}")
# Out:
# Loading embedding model for semantic chunking...
#    Using CPU for stable performance
# Setting up semantic chunker with PERCENTILE=50...
# [SUCCESS] Chunker ready (Percentile: 50, Buffer: 1)!
# Creating semantic chunks from raw text...
# Configuration: Percentile=50, Buffer=1
# [SUCCESS] Created 613 semantic chunks
#
# Chunk Analysis:
#    Average size: 260 characters
#    Size range: 2 - 4752 characters
#    Total chunks: 613
#
# Sample chunks:
#    Chunk 1: ﻿Republic of the Philippines  Eulogio "Amang" Rodriguez Institute of Science and Technology Office of Student Affairs and Services   EARIST STUDENT HA...
#    Chunk 2: i - Acknowledgment ........
#    Chunk 3: ii - HISTORY OF EARIST ..... 1 - MISSION STATEMENTS   - Vision ........
# [SUCCESS] Saved 613 chunks to saved_chunks/chunks_p50_b1.pkl
#
# [SUCCESS] Chunking complete and saved to saved_chunks/chunks_p50_b1.pkl!
# [INFO] Configuration: Percentile=50, Buffer=1
# Looking for chunks: saved_chunks/chunks_p50_b1.pkl
# [SUCCESS] Loaded 613 chunks from saved_chunks/chunks_p50_b1.pkl
# [SUCCESS] Ready to experiment with 613 chunks!
# [INFO] Loaded configuration: Percentile=50, Buffer=1

# %%
# ========================================
# EXPERIMENT PARAMETER: EMBEDDING MODEL
# ========================================
# Change MODEL_NAME to experiment with different embeddings!

# Current options (uncomment one):
# MODEL_NAME = "sentence-transformers/all-mpnet-base-v2"  # Best quality, 768 dim
# MODEL_NAME = "sentence-transformers/all-MiniLM-L6-v2"  # Fast, 384 dim
MODEL_NAME = "sentence-transformers/multi-qa-mpnet-base-dot-v1"  # Q&A optimized
# MODEL_NAME = "sentence-transformers/paraphrase-multilingual-mpnet-base-v2"  # Multilingual

# ========================================

print(f"\n{'='*70}")
print(f"EMBEDDING MODEL CONFIGURATION")
print(f"{'='*70}")
print(f"Model: {MODEL_NAME}")
print("   Using CPU for stable performance")

embedding_model = HuggingFaceEmbeddings(
    model_name=MODEL_NAME,
    model_kwargs={
        'device': 'cuda',
        'trust_remote_code': True
    },
    encode_kwargs={'normalize_embeddings': True}
)

# Get embedding dimension
test_embed = embedding_model.embed_query("test")

print(f"[SUCCESS] Embedding model loaded!")
print(f"   Model: {MODEL_NAME.split('/')[-1]}")
print(f"   Embedding dimension: {len(test_embed)}")
print(f"   Device: CPU")
print(f"{'='*70}\n")

print("\nGenerating embeddings for all chunks with current model...")
chunk_texts = [chunk.page_content for chunk in chunks]

# Process embeddings in batches to avoid memory issues
batch_size = 32
all_embeddings = []

import time
start_time = time.time()

for i in range(0, len(chunk_texts), batch_size):
    batch = chunk_texts[i:i+batch_size]
    batch_embeddings = embedding_model.embed_documents(batch)
    all_embeddings.extend(batch_embeddings)
    print(f"   Processed batch {i//batch_size + 1}/{(len(chunk_texts) + batch_size - 1)//batch_size}")

elapsed_time = time.time() - start_time
print(f"\n[SUCCESS] Generated {len(all_embeddings)} embeddings in {elapsed_time:.2f}s")
print(f"Average: {elapsed_time/len(all_embeddings):.3f}s per chunk")


# Build FAISS vector store for fast similarity search
print("\nBuilding FAISS vector database...")
dimension = len(all_embeddings[0])
index = faiss.IndexFlatIP(dimension)  # Inner Product for cosine similarity

# Normalize embeddings for proper cosine similarity
embeddings_array = np.array(all_embeddings).astype('float32')
faiss.normalize_L2(embeddings_array)
index.add(embeddings_array)

print(f"[SUCCESS] FAISS index ready: {index.ntotal:,} vectors ({dimension} dimensions)")
print(f"Model: {MODEL_NAME.split('/')[-1]}")
# Out:
# ======================================================================
# EMBEDDING MODEL CONFIGURATION
# ======================================================================
# Model: sentence-transformers/multi-qa-mpnet-base-dot-v1
#    Using CPU for stable performance
# [SUCCESS] Embedding model loaded!
#    Model: multi-qa-mpnet-base-dot-v1
#    Embedding dimension: 768
#    Device: CPU
# ======================================================================
#
#
# Generating embeddings for all chunks with current model...
#    Processed batch 1/20
#    Processed batch 2/20
#    Processed batch 3/20
#    Processed batch 4/20
#    Processed batch 5/20
#    Processed batch 6/20
#    Processed batch 7/20
#    Processed batch 8/20
#    Processed batch 9/20
#    Processed batch 10/20
#    Processed batch 11/20
#    Processed batch 12/20
#    Processed batch 13/20
#    Processed batch 14/20
#    Processed batch 15/20
#    Processed batch 16/20
#    Processed batch 17/20
#    Processed batch 18/20
#    Processed batch 19/20
#    Processed batch 20/20
#
# [SUCCESS] Generated 613 embeddings in 5.90s
# Average: 0.010s per chunk
#
# Building FAISS vector database...
# [SUCCESS] FAISS index ready: 613 vectors (768 dimensions)
# Model: multi-qa-mpnet-base-dot-v1

# %%
def retrieve_relevant_chunks(query, top_k=5):
    """Find most relevant chunks for the query"""
    print(f"\nSearching for: '{query}'")
    print(f"Model: {MODEL_NAME.split('/')[-1]}")
    print("=" * 50)

    # Embed the query
    query_embedding = embedding_model.embed_query(query)
    query_vector = np.array([query_embedding]).astype('float32')
    faiss.normalize_L2(query_vector)

    # Search FAISS index
    scores, indices = index.search(query_vector, top_k)

    # Return results with metadata
    results = []
    for idx, score in zip(indices[0], scores[0]):
        if idx < len(chunks):  # Safety check
            chunk = chunks[idx]
            results.append({
                'text': chunk.page_content,
                'score': float(score),
                'chunk_id': int(idx),
                'start_pos': chunk.metadata.get('start_index', 0) if hasattr(chunk, 'metadata') else 0
            })

    return results

def display_retrieval_results(query, results):
    """Display comprehensive retrieval results"""
    print(f"Found {len(results)} relevant chunks for: '{query}'")
    print("=" * 70)

    for i, result in enumerate(results, 1):
        print(f"\nChunk {i} (ID: {result['chunk_id']})")
        print(f"Relevance Score: {result['score']:.4f}")
        print(f"Position in Document: Character {result['start_pos']:,}")
        print(f"Length: {len(result['text'])} characters")
        print(f"Content Preview (first 200 chars):")
        print(f"   {result['text'][:200].replace(chr(10), ' ').replace(chr(13), '')}...")

        # Show full content if it's short enough
        if len(result['text']) <= 500:
            print(f"Full Content:")
            print(f"   {result['text']}")

        print("-" * 40)

    return results

print("[SUCCESS] Retrieval functions ready!")
# Out:
# [SUCCESS] Retrieval functions ready!

# %%
import json
# Load questions from Questions.json
with open('Questions.json', 'r', encoding='utf-8') as f:
    questions_data = json.load(f)

# Count total questions
total_questions = sum(len(questions) for questions in questions_data.values())
print(f"[SUCCESS] Loaded {total_questions} questions across {len(questions_data)} categories")
print("\nCategories:")
for category, questions in questions_data.items():
    print(f"   • {category}: {len(questions)} questions")
# Out:
# [SUCCESS] Loaded 50 questions across 8 categories
#
# Categories:
#    • Admissions: 8 questions
#    • Enrollment and Registration: 8 questions
#    • Fees, Payments and Scholarships: 6 questions
#    • Academic Policies and Grading: 8 questions
#    • Attendance and Conduct: 6 questions
#    • Student Services and Organizations: 6 questions
#    • Graduation and Academic Completion: 5 questions
#    • General and Miscellaneous Information: 3 questions

# %%
def test_category_questions(category_name, top_k=3, show_full_results=False):
    """Test all questions from a specific category"""
    if category_name not in questions_data:
        print(f"[ERROR] Category '{category_name}' not found!")
        print(f"Available categories: {', '.join(questions_data.keys())}")
        return

    questions = questions_data[category_name]
    print(f"\n{'='*70}")
    print(f"Testing Category: {category_name}")
    print(f"Total Questions: {len(questions)}")
    print(f"Model: {MODEL_NAME.split('/')[-1]}")
    print(f"Retrieving top {top_k} chunks per question")
    print(f"{'='*70}")

    all_results = []

    for i, q_item in enumerate(questions, 1):
        question = q_item['question']
        expected_ref = q_item['expected_reference']

        print(f"\n{'─'*70}")
        print(f"Question {i}/{len(questions)}")
        print(f"Q: {question}")
        print(f"Expected Reference: {expected_ref}")
        print(f"{'─'*70}")

        # Retrieve relevant chunks
        results = retrieve_relevant_chunks(question, top_k=top_k)

        # Store results for analysis
        all_results.append({
            'question': question,
            'expected_reference': expected_ref,
            'results': results,
            'top_score': results[0]['score'] if results else 0
        })

        if show_full_results:
            display_retrieval_results(question, results)
        else:
            # Show compact summary
            print(f"\nTop {min(top_k, len(results))} Results:")
            for j, result in enumerate(results[:top_k], 1):
                preview = result['text'][:150].replace('\n', ' ').replace('\r', '')
                print(f"   {j}. Score: {result['score']:.4f} | {preview}...")

    # Summary statistics
    print(f"\n{'='*70}")
    print(f"CATEGORY SUMMARY: {category_name}")
    print(f"{'='*70}")
    avg_top_score = np.mean([r['top_score'] for r in all_results])
    print(f"Average Top Score: {avg_top_score:.4f}")
    print(f"Score Range: {min([r['top_score'] for r in all_results]):.4f} - {max([r['top_score'] for r in all_results]):.4f}")

    # Score distribution
    high_confidence = sum(1 for r in all_results if r['top_score'] > 0.7)
    medium_confidence = sum(1 for r in all_results if 0.5 <= r['top_score'] <= 0.7)
    low_confidence = sum(1 for r in all_results if r['top_score'] < 0.5)

    print(f"\nConfidence Distribution:")
    print(f"   High (>0.7):   {high_confidence}/{len(all_results)} questions ({high_confidence/len(all_results)*100:.1f}%)")
    print(f"   Medium (0.5-0.7): {medium_confidence}/{len(all_results)} questions ({medium_confidence/len(all_results)*100:.1f}%)")
    print(f"   Low (<0.5):    {low_confidence}/{len(all_results)} questions ({low_confidence/len(all_results)*100:.1f}%)")

    return all_results

print("[SUCCESS] Category testing function ready!")


def test_all_questions(top_k=3, show_detailed=False):
    """Test all questions from all categories"""
    print(f"\n{'='*70}")
    print(f"COMPREHENSIVE RETRIEVAL TEST")
    print(f"{'='*70}")
    print(f"Model: {MODEL_NAME.split('/')[-1]}")
    print(f"Total Categories: {len(questions_data)}")
    print(f"Total Questions: {sum(len(q) for q in questions_data.values())}")
    print(f"Top-K per question: {top_k}")
    print(f"{'='*70}")

    all_category_results = {}

    for category_name in questions_data.keys():
        print(f"\n\n{'█'*70}")
        print(f"CATEGORY: {category_name}")
        print(f"{'█'*70}")

        category_results = test_category_questions(
            category_name,
            top_k=top_k,
            show_full_results=show_detailed
        )
        all_category_results[category_name] = category_results

    # Overall summary
    print(f"\n\n{'='*70}")
    print(f"OVERALL PERFORMANCE SUMMARY")
    print(f"{'='*70}")

    all_scores = []
    for category, results in all_category_results.items():
        scores = [r['top_score'] for r in results]
        all_scores.extend(scores)
        avg = np.mean(scores)
        print(f"\n{category}:")
        print(f"   Questions: {len(results)}")
        print(f"   Avg Score: {avg:.4f}")
        print(f"   Range: {min(scores):.4f} - {max(scores):.4f}")

    # Global statistics
    print(f"\n{'─'*70}")
    print(f"GLOBAL STATISTICS:")
    print(f"   Total Questions Tested: {len(all_scores)}")
    print(f"   Overall Average Score: {np.mean(all_scores):.4f}")
    print(f"   Median Score: {np.median(all_scores):.4f}")
    print(f"   Std Deviation: {np.std(all_scores):.4f}")

    # Overall confidence distribution
    high = sum(1 for s in all_scores if s > 0.7)
    medium = sum(1 for s in all_scores if 0.5 <= s <= 0.7)
    low = sum(1 for s in all_scores if s < 0.5)

    print(f"\n   Overall Confidence Distribution:")
    print(f"      High (>0.7):   {high}/{len(all_scores)} ({high/len(all_scores)*100:.1f}%)")
    print(f"      Medium (0.5-0.7): {medium}/{len(all_scores)} ({medium/len(all_scores)*100:.1f}%)")
    print(f"      Low (<0.5):    {low}/{len(all_scores)} ({low/len(all_scores)*100:.1f}%)")

    return all_category_results

print("[SUCCESS] Comprehensive testing function ready!")




# Create experiment tracking system
experiment_results = []

def save_experiment_results(filename="experiment_results.json"):
    """Save all experiment results to file"""
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(experiment_results, f, indent=2)
    print(f"[SUCCESS] Saved {len(experiment_results)} experiments to {filename}")

def load_experiment_results(filename="experiment_results.json"):
    """Load previous experiment results"""
    global experiment_results
    try:
        with open(filename, 'r', encoding='utf-8') as f:
            experiment_results = json.load(f)
        print(f"[SUCCESS] Loaded {len(experiment_results)} previous experiments")
        return experiment_results
    except FileNotFoundError:
        print(f"[INFO] No previous results found. Starting fresh!")
        return []

# Try to load previous results
load_experiment_results()

print("[SUCCESS] Experiment tracking system ready!")
print(f"Current experiments tracked: {len(experiment_results)}")


def run_full_experiment(experiment_name, chunking_config, embedding_model_name, top_k=3):
    """
    Run a complete experiment with specific chunking and embedding configuration

    Args:
        experiment_name: Descriptive name for this experiment
        chunking_config: Dict with keys 'strategy', 'params' (e.g., percentile, overlap)
        embedding_model_name: HuggingFace model name
        top_k: Number of chunks to retrieve per query
    """
    start_time = time.time()

    print(f"\n{'█'*70}")
    print(f"RUNNING EXPERIMENT: {experiment_name}")
    print(f"{'█'*70}")
    print(f"Chunking: {chunking_config}")
    print(f"Embedding: {embedding_model_name}")
    print(f"Top-K: {top_k}")
    print(f"{'█'*70}\n")

    # Test with all questions
    category_results = test_all_questions(top_k=top_k, show_detailed=False)

    # Calculate metrics
    all_scores = []
    category_scores = {}

    for category, results in category_results.items():
        scores = [r['top_score'] for r in results]
        all_scores.extend(scores)
        category_scores[category] = {
            'avg_score': float(np.mean(scores)),
            'min_score': float(min(scores)),
            'max_score': float(max(scores)),
            'num_questions': len(scores)
        }

    # Compute overall metrics
    elapsed_time = time.time() - start_time

    experiment_data = {
        'experiment_name': experiment_name,
        'timestamp': time.strftime('%Y-%m-%d %H:%M:%S'),
        'chunking_config': chunking_config,
        'embedding_model': embedding_model_name,
        'top_k': top_k,
        'metrics': {
            'overall_avg_score': float(np.mean(all_scores)),
            'overall_median_score': float(np.median(all_scores)),
            'overall_std': float(np.std(all_scores)),
            'min_score': float(min(all_scores)),
            'max_score': float(max(all_scores)),
            'high_confidence_pct': float(sum(1 for s in all_scores if s > 0.7) / len(all_scores) * 100),
            'medium_confidence_pct': float(sum(1 for s in all_scores if 0.5 <= s <= 0.7) / len(all_scores) * 100),
            'low_confidence_pct': float(sum(1 for s in all_scores if s < 0.5) / len(all_scores) * 100),
            'total_questions': len(all_scores),
            'execution_time_seconds': elapsed_time
        },
        'category_metrics': category_scores
    }

    # Save to tracking
    experiment_results.append(experiment_data)
    save_experiment_results()

    print(f"\n{'='*70}")
    print(f"EXPERIMENT COMPLETE: {experiment_name}")
    print(f"{'='*70}")
    print(f"Overall Avg Score: {experiment_data['metrics']['overall_avg_score']:.4f}")
    print(f"High Confidence: {experiment_data['metrics']['high_confidence_pct']:.1f}%")
    print(f"Execution Time: {elapsed_time:.1f}s")
    print(f"{'='*70}\n")

    return experiment_data

print("[SUCCESS] Experiment runner ready!")


def compare_experiments():
    """Compare all tracked experiments and show rankings"""
    if not experiment_results:
        print("[INFO] No experiments to compare yet. Run some experiments first!")
        return

    print(f"\n{'='*80}")
    print(f"EXPERIMENT COMPARISON DASHBOARD")
    print(f"{'='*80}")
    print(f"Total Experiments: {len(experiment_results)}\n")

    # Sort by overall average score
    sorted_experiments = sorted(
        experiment_results,
        key=lambda x: x['metrics']['overall_avg_score'],
        reverse=True
    )

    # Display ranking table
    print(f"{'Rank':<6} {'Experiment Name':<35} {'Avg Score':<12} {'High Conf %':<12} {'Time (s)':<10}")
    print(f"{'─'*80}")

    for i, exp in enumerate(sorted_experiments, 1):
        name = exp['experiment_name'][:33]
        avg_score = exp['metrics']['overall_avg_score']
        high_conf = exp['metrics']['high_confidence_pct']
        exec_time = exp['metrics']['execution_time_seconds']

        print(f"{i:<6} {name:<35} {avg_score:<12.4f} {high_conf:<12.1f} {exec_time:<10.1f}")

    # Show best experiment details
    print(f"\n{'='*80}")
    print(f"🏆 BEST EXPERIMENT: {sorted_experiments[0]['experiment_name']}")
    print(f"{'='*80}")
    best = sorted_experiments[0]

    print(f"\nConfiguration:")
    print(f"   Chunking: {best['chunking_config']}")
    print(f"   Embedding Model: {best['embedding_model']}")
    print(f"   Top-K: {best['top_k']}")

    print(f"\nPerformance Metrics:")
    print(f"   Average Score: {best['metrics']['overall_avg_score']:.4f}")
    print(f"   Median Score: {best['metrics']['overall_median_score']:.4f}")
    print(f"   Std Deviation: {best['metrics']['overall_std']:.4f}")
    print(f"   Score Range: {best['metrics']['min_score']:.4f} - {best['metrics']['max_score']:.4f}")

    print(f"\nConfidence Distribution:")
    print(f"   High (>0.7):   {best['metrics']['high_confidence_pct']:.1f}%")
    print(f"   Medium (0.5-0.7): {best['metrics']['medium_confidence_pct']:.1f}%")
    print(f"   Low (<0.5):    {best['metrics']['low_confidence_pct']:.1f}%")

    print(f"\nCategory Performance:")
    for category, metrics in best['category_metrics'].items():
        print(f"   {category}: {metrics['avg_score']:.4f}")

    # Show comparison with worst
    if len(sorted_experiments) > 1:
        worst = sorted_experiments[-1]
        improvement = ((best['metrics']['overall_avg_score'] - worst['metrics']['overall_avg_score'])
                      / worst['metrics']['overall_avg_score'] * 100)
        print(f"\n📈 Improvement over worst: {improvement:.1f}%")

    print(f"\n{'='*80}\n")

    return sorted_experiments

print("[SUCCESS] Comparison function ready!")


# Quick visualization of experiment results
def plot_experiment_comparison():
    """Create a simple text-based comparison chart"""
    if not experiment_results:
        print("[INFO] No experiments to visualize yet.")
        return

    sorted_exp = sorted(experiment_results, key=lambda x: x['metrics']['overall_avg_score'], reverse=True)

    print(f"\n{'='*70}")
    print(f"EXPERIMENT PERFORMANCE VISUALIZATION")
    print(f"{'='*70}\n")

    # Bar chart of average scores
    print("Average Score Comparison:")
    print("-" * 70)
    max_score = max(e['metrics']['overall_avg_score'] for e in sorted_exp)

    for exp in sorted_exp:
        name = exp['experiment_name'][:30]
        score = exp['metrics']['overall_avg_score']
        bar_length = int((score / max_score) * 40)
        bar = '█' * bar_length
        print(f"{name:<30} {score:.4f} {bar}")

    print()

    # High confidence percentage comparison
    print("High Confidence (>0.7) Percentage:")
    print("-" * 70)
    max_conf = max(e['metrics']['high_confidence_pct'] for e in sorted_exp)

    for exp in sorted_exp:
        name = exp['experiment_name'][:30]
        conf = exp['metrics']['high_confidence_pct']
        bar_length = int((conf / max_conf) * 40) if max_conf > 0 else 0
        bar = '█' * bar_length
        print(f"{name:<30} {conf:>6.1f}% {bar}")

    print(f"\n{'='*70}\n")

print("[SUCCESS] Visualization function ready!")
# Out:
# [SUCCESS] Category testing function ready!
# [SUCCESS] Comprehensive testing function ready!
# [SUCCESS] Loaded 15 previous experiments
# [SUCCESS] Experiment tracking system ready!
# Current experiments tracked: 15
# [SUCCESS] Experiment runner ready!
# [SUCCESS] Comparison function ready!
# [SUCCESS] Visualization function ready!

# %%
# ========================================
# RUN CURRENT EXPERIMENT
# ========================================
# This will test your current chunking + embedding configuration
# against all questions from Questions.json

# Automatically detect current configuration
current_chunking = {
    "strategy": "semantic",
    "percentile": PERCENTILE_THRESHOLD if 'PERCENTILE_THRESHOLD' in dir() else 80,
    "buffer_size": BUFFER_SIZE if 'BUFFER_SIZE' in dir() else 1
}

current_model = MODEL_NAME.split('/')[-1] if 'MODEL_NAME' in dir() else "unknown"

# Generate experiment name
experiment_name = f"P{current_chunking['percentile']}-{current_model}"

print(f"Ready to run experiment: {experiment_name}")
print(f"Chunking: {current_chunking}")
print(f"Embedding: {MODEL_NAME if 'MODEL_NAME' in dir() else 'Not set'}")
print("\n🚀 Uncomment the line below to run the experiment:")
print("# run_full_experiment(experiment_name, current_chunking, MODEL_NAME, top_k=5)")

# Uncomment to run:
run_full_experiment(experiment_name, current_chunking, MODEL_NAME, top_k=5)
# Out:
# Ready to run experiment: P50-multi-qa-mpnet-base-dot-v1
# Chunking: {'strategy': 'semantic', 'percentile': 50, 'buffer_size': 1}
# Embedding: sentence-transformers/multi-qa-mpnet-base-dot-v1
#
# 🚀 Uncomment the line below to run the experiment:
# # run_full_experiment(experiment_name, current_chunking, MODEL_NAME, top_k=5)
#
# ██████████████████████████████████████████████████████████████████████
# RUNNING EXPERIMENT: P50-multi-qa-mpnet-base-dot-v1
# ██████████████████████████████████████████████████████████████████████
# Chunking: {'strategy': 'semantic', 'percentile': 50, 'buffer_size': 1}
# Embedding: sentence-transformers/multi-qa-mpnet-base-dot-v1
# Top-K: 5
# ██████████████████████████████████████████████████████████████████████
#
#
# ======================================================================
# COMPREHENSIVE RETRIEVAL TEST
# ======================================================================
# Model: multi-qa-mpnet-base-dot-v1
# Total Categories: 8
# Total Questions: 50
# Top-K per question: 5
# ======================================================================
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: Admissions
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: Admissions
# Total Questions: 8
# Model: multi-qa-mpnet-base-dot-v1
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/8
# Q: What are the requirements for new freshmen applying to EARIST?
# Expected Reference: Admission Requirements section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What are the requirements for new freshmen applying to EARIST?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7431 | Admission Requirements   #### 1....
#    2. Score: 0.7108 | Must be enrolled in any bachelor or associate program (Undergraduate Program)                                                                         ...
#    3. Score: 0.6943 | Section 4. CLASSIFICATION OF STUDENTS   4.1 According to Admission Status   4.1.1 As Beginning Freshmen – Student admitted through the EARIST College ...
#    4. Score: 0.6922 | Freshman – first year student....
#    5. Score: 0.6893 | Freshmen 1.1 Form 138 (Senior and High School Report Card)   1.2 Certificate of Good Moral Character with school seal   1.3 Birth Certificate (PSA Aut...
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/8
# Q: How can I apply for admission as a transferee student?
# Expected Reference: Admission Procedures section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How can I apply for admission as a transferee student?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7079 | ##### 4.1.4.2 From Another School – Students may be admitted as transferees depending on the availability of slots and have met all the academic and a...
#    2. Score: 0.6170 | Qualifications 1. Currently enrolled in one of the courses in any of the college....
#    3. Score: 0.6019 | Admission Requirements   #### 1....
#    4. Score: 0.6012 | Must be enrolled in any bachelor or associate program (Undergraduate Program)                                                                         ...
#    5. Score: 0.6007 | Freshmen 1.1 Form 138 (Senior and High School Report Card)   1.2 Certificate of Good Moral Character with school seal   1.3 Birth Certificate (PSA Aut...
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/8
# Q: Does EARIST accept students from other schools?
# Expected Reference: Transfer Student Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Does EARIST accept students from other schools?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6187 | The number of applicants to be admitted depends on the resources of the Institute such as rooms and faculty. **Admission Qualifications of Local Stude...
#    2. Score: 0.6097 | EARIST Faculty Sponsored Scholarship 3....
#    3. Score: 0.5912 | Section 4. CLASSIFICATION OF STUDENTS   4.1 According to Admission Status   4.1.1 As Beginning Freshmen – Student admitted through the EARIST College ...
#    4. Score: 0.5827 | ##### 4.1.4.2 From Another School – Students may be admitted as transferees depending on the availability of slots and have met all the academic and a...
#    5. Score: 0.5683 | Cross Enroll – to enroll from one school to another....
#
# ──────────────────────────────────────────────────────────────────────
# Question 4/8
# Q: Where can I submit my admission documents?
# Expected Reference: Office of Admissions section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Where can I submit my admission documents?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5962 | Admission Requirements   #### 1....
#    2. Score: 0.5740 | Admission Recommendation from the College Dean....
#    3. Score: 0.5623 | * 1.4.3.3 Student organization applicants shall then proceed......
#    4. Score: 0.5446 | Failure to enroll......
#    5. Score: 0.5268 | In case of loss of ID, the following must be submitted: 3.2.1.1. Notarized Affidavit of Loss 3.2.1.2. Accomplished Clearance Form (from the Office of ...
#
# ──────────────────────────────────────────────────────────────────────
# Question 5/8
# Q: When does EARIST usually start accepting new enrollees?
# Expected Reference: Admission Schedule section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'When does EARIST usually start accepting new enrollees?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6039 | Section 4. CLASSIFICATION OF STUDENTS   4.1 According to Admission Status   4.1.1 As Beginning Freshmen – Student admitted through the EARIST College ...
#    2. Score: 0.5894 | The number of applicants to be admitted depends on the resources of the Institute such as rooms and faculty. **Admission Qualifications of Local Stude...
#    3. Score: 0.5263 | Must be enrolled....
#    4. Score: 0.5263 | Must be enrolled....
#    5. Score: 0.5147 | Failure to enroll......
#
# ──────────────────────────────────────────────────────────────────────
# Question 6/8
# Q: Are there entrance exams required for admission?
# Expected Reference: Entrance Examination section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Are there entrance exams required for admission?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7032 | Admission Requirements   #### 1....
#    2. Score: 0.6169 | Qualifications 1....
#    3. Score: 0.5957 | Must be enrolled in any bachelor or associate program (Undergraduate Program)                                                                         ...
#    4. Score: 0.5901 | Entry Level Physical Examination for Freshmen                                                                                                         ...
#    5. Score: 0.5822 | Must be enrolled....
#
# ──────────────────────────────────────────────────────────────────────
# Question 7/8
# Q: Can foreign students apply to EARIST?
# Expected Reference: Foreign Student Admission section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Can foreign students apply to EARIST?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6253 | EARIST Faculty Sponsored Scholarship 3....
#    2. Score: 0.5941 | Section 4. CLASSIFICATION OF STUDENTS   4.1 According to Admission Status   4.1.1 As Beginning Freshmen – Student admitted through the EARIST College ...
#    3. Score: 0.5910 | The number of applicants to be admitted depends on the resources of the Institute such as rooms and faculty. **Admission Qualifications of Local Stude...
#    4. Score: 0.5847 | Admission Requirements   #### 1....
#    5. Score: 0.5773 | ##### 4.1.4.2 From Another School – Students may be admitted as transferees depending on the availability of slots and have met all the academic and a...
#
# ──────────────────────────────────────────────────────────────────────
# Question 8/8
# Q: What documents are needed for returning students to be readmitted?
# Expected Reference: Re-admission Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What documents are needed for returning students to be readmitted?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6417 | Copy of Approved Leave of Absence; 2. Evaluation Record Form from the Registrar's Office; and 3....
#    2. Score: 0.6267 | For Re-Admission of students who would like to continue their program after taking the leave of absence, the following are needed:   1....
#    3. Score: 0.6048 | Copy of current and previous Certificate of Registration (COR) 3. Copy of current and previous Report of Grades 4....
#    4. Score: 0.5765 | Must be enrolled....
#    5. Score: 0.5765 | Must be enrolled....
#
# ======================================================================
# CATEGORY SUMMARY: Admissions
# ======================================================================
# Average Top Score: 0.6550
# Score Range: 0.5962 - 0.7431
#
# Confidence Distribution:
#    High (>0.7):   3/8 questions (37.5%)
#    Medium (0.5-0.7): 5/8 questions (62.5%)
#    Low (<0.5):    0/8 questions (0.0%)
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: Enrollment and Registration
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: Enrollment and Registration
# Total Questions: 8
# Model: multi-qa-mpnet-base-dot-v1
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/8
# Q: How do I enroll in EARIST after being admitted?
# Expected Reference: Enrollment Procedures section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How do I enroll in EARIST after being admitted?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6702 | Section 4. CLASSIFICATION OF STUDENTS   4.1 According to Admission Status   4.1.1 As Beginning Freshmen – Student admitted through the EARIST College ...
#    2. Score: 0.6039 | The number of applicants to be admitted depends on the resources of the Institute such as rooms and faculty. **Admission Qualifications of Local Stude...
#    3. Score: 0.5972 | EARIST Faculty Sponsored Scholarship 3....
#    4. Score: 0.5917 | Freshmen 1.1 Form 138 (Senior and High School Report Card)   1.2 Certificate of Good Moral Character with school seal   1.3 Birth Certificate (PSA Aut...
#    5. Score: 0.5865 | Failure to enroll......
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/8
# Q: What is the process for online registration of classes?
# Expected Reference: Registration Process section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What is the process for online registration of classes?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6674 | Must be enrolled....
#    2. Score: 0.6674 | Must be enrolled....
#    3. Score: 0.6492 | REGISTRATION AND CROSS ENROLLMENT PROCEDURE   1.1 A student must be officially registered in order to receive credit for course work. The following sh...
#    4. Score: 0.6173 | Copy of previous Certificate of Registration....
#    5. Score: 0.6173 | Copy of previous Certificate of Registration....
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/8
# Q: Can I still enroll if I missed the enrollment period?
# Expected Reference: Late Enrollment Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Can I still enroll if I missed the enrollment period?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6760 | Failure to enroll......
#    2. Score: 0.5604 | Must be enrolled....
#    3. Score: 0.5604 | Must be enrolled....
#    4. Score: 0.5514 | ### 7.1 Old students, except those in the senior year, with failures corresponding to three (3) or more courses within a semester or five (5) cumulati...
#    5. Score: 0.5159 | Cross Enroll – to enroll from one school to another....
#
# ──────────────────────────────────────────────────────────────────────
# Question 4/8
# Q: How do I change or drop a subject after enrollment?
# Expected Reference: Adding and Dropping of Subjects section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How do I change or drop a subject after enrollment?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6743 | CHANGING CLASSES, SUBSTITUTION, AND DROPPING OF COURSES   3.1 The student may apply for a change of class (subject/schedule) by filing the College Adv...
#    2. Score: 0.6691 | Dropped – withdraw of course/subject in a given period of time....
#    3. Score: 0.6359 | Conditions 1. Shall not drop any subject, shift courses, or stop from schooling without the approval of the Dean and the Registrar. 2....
#    4. Score: 0.6359 | Conditions 1. Shall not drop any subject, shift courses, or stop from schooling without the approval of the Dean and the Registrar. 2....
#    5. Score: 0.5824 | Failure to enroll......
#
# ──────────────────────────────────────────────────────────────────────
# Question 5/8
# Q: What should I do if my class schedule conflicts with another subject?
# Expected Reference: Schedule Adjustment Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What should I do if my class schedule conflicts with another subject?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5420 | CHANGING CLASSES, SUBSTITUTION, AND DROPPING OF COURSES   3.1 The student may apply for a change of class (subject/schedule) by filing the College Adv...
#    2. Score: 0.5075 | Attendance to classes                                                                                                                                 ...
#    3. Score: 0.4718 | Dropped – withdraw of course/subject in a given period of time....
#    4. Score: 0.4707 | It enjoins the students......
#    5. Score: 0.4649 | Conditions 1. Shall not drop any subject, shift courses, or stop from schooling without the approval of the Dean and the Registrar. 2....
#
# ──────────────────────────────────────────────────────────────────────
# Question 6/8
# Q: Where can I see the list of courses offered by EARIST?
# Expected Reference: Curriculum Offerings section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Where can I see the list of courses offered by EARIST?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6055 | EARIST Faculty Sponsored Scholarship 3....
#    2. Score: 0.5443 | TERTIARY EDUCATION PROGRAM   ##### a. Qualifications 1....
#    3. Score: 0.5309 | Pillo. Today, EARIST is: - Baccalaureate College - Comprehensive Teaching and Baccalaureate University LEVEL II - Graduate Capable HEIs LEVEL III (Res...
#    4. Score: 0.5238 | Section 4. CLASSIFICATION OF STUDENTS   4.1 According to Admission Status   4.1.1 As Beginning Freshmen – Student admitted through the EARIST College ...
#    5. Score: 0.5224 | #### Section 2. SCHEDULE OF TUITION FEES AND OTHER CHARGES   Notwithstanding as the EARIST Board of Trustees may prescribe pursuant to the provisions ...
#
# ──────────────────────────────────────────────────────────────────────
# Question 7/8
# Q: Can I enroll in overload subjects this semester?
# Expected Reference: Overload Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Can I enroll in overload subjects this semester?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6446 | ACADEMIC LOAD   2.1 A student shall carry the regular load every semester as prescribed in the curricular program. 2.2 In no instance shall a student ...
#    2. Score: 0.5677 | Must not have a failing grade and dropped subject in the previous semester....
#    3. Score: 0.5581 | 2. Must carry a minimum academic load of 18 units (except for graduating students). 3....
#    4. Score: 0.5329 | Must not have a failing grade or dropped subject in the previous semester. ##### b....
#    5. Score: 0.5096 | Freshman – first year student....
#
# ──────────────────────────────────────────────────────────────────────
# Question 8/8
# Q: What are the steps to enroll as a cross-enrollee from another school?
# Expected Reference: Cross-Enrollment section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What are the steps to enroll as a cross-enrollee from another school?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7936 | Cross Enroll – to enroll from one school to another....
#    2. Score: 0.6975 | REGISTRATION AND CROSS ENROLLMENT PROCEDURE   1.1 A student must be officially registered in order to receive credit for course work. The following sh...
#    3. Score: 0.6467 | 1.1.4 The Registrar's Office should be provided a copy of his approved request. 1.7 No cross enrollee from another institution shall be admitted into ...
#    4. Score: 0.6313 | Otherwise, the Certificate of Registration shall be considered prior to final Official Class List. 1.6 Cross enrollment in another school is allowed o...
#    5. Score: 0.6272 | Must be enrolled....
#
# ======================================================================
# CATEGORY SUMMARY: Enrollment and Registration
# ======================================================================
# Average Top Score: 0.6592
# Score Range: 0.5420 - 0.7936
#
# Confidence Distribution:
#    High (>0.7):   1/8 questions (12.5%)
#    Medium (0.5-0.7): 7/8 questions (87.5%)
#    Low (<0.5):    0/8 questions (0.0%)
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: Fees, Payments and Scholarships
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: Fees, Payments and Scholarships
# Total Questions: 6
# Model: multi-qa-mpnet-base-dot-v1
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/6
# Q: How much is the tuition fee per unit at EARIST?
# Expected Reference: Tuition Fees section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How much is the tuition fee per unit at EARIST?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6130 | EARIST Faculty Sponsored Scholarship 3....
#    2. Score: 0.6113 | * 4.1.3 List of tuition and other school fees and educational visits and field trips are posted in conspicuous places....
#    3. Score: 0.6106 | Freshman – first year student....
#    4. Score: 0.5959 | Senior – fourth year student....
#    5. Score: 0.5792 | Admission Requirements   #### 1....
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/6
# Q: Are there any miscellaneous fees aside from tuition?
# Expected Reference: Miscellaneous Fees section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Are there any miscellaneous fees aside from tuition?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6378 | * 4.1.3 List of tuition and other school fees and educational visits and field trips are posted in conspicuous places....
#    2. Score: 0.5978 | The Institute charges a fixed amount per unit/hour. Laboratory fees may vary according to the laboratory subject. ##### 2.2 Payee Students   ###### 2....
#    3. Score: 0.5552 | No. 10931 and its IRR and such applicable laws, rules, and regulations, the Board of Trustees shall fix the tuition fees and others necessary school c...
#    4. Score: 0.5464 | Fee – an amount of money to be paid in a given semester....
#    5. Score: 0.5331 | Master’s – a master's degree Midterm Examination – an examination given at the middle of the semester. Miscellaneous – additional fees aside from tuit...
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/6
# Q: Where can I pay my tuition fees?
# Expected Reference: Payment Procedures section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Where can I pay my tuition fees?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5558 | * 4.1.3 List of tuition and other school fees and educational visits and field trips are posted in conspicuous places....
#    2. Score: 0.5420 | Must be enrolled....
#    3. Score: 0.5420 | Must be enrolled....
#    4. Score: 0.5202 | No. 10931 and its IRR and such applicable laws, rules, and regulations, the Board of Trustees shall fix the tuition fees and others necessary school c...
#    5. Score: 0.5158 | Tuition – money that is paid to a school for the right to study in a school, college or university. Undergraduate – a student at a college or universi...
#
# ──────────────────────────────────────────────────────────────────────
# Question 4/6
# Q: Does EARIST offer scholarships or financial aid programs?
# Expected Reference: Scholarships and Grants section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Does EARIST offer scholarships or financial aid programs?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7472 | EARIST Faculty Sponsored Scholarship 3....
#    2. Score: 0.5742 | Must not be a recipient of scholarship/grant from any government agency. 4....
#    3. Score: 0.5643 | #### SECTION 3. FACULTY AND EMPLOYEES UNION SCHOLARSHIP   This is given by the Institute to all qualified children of all employees enrolled in EARIST...
#    4. Score: 0.5515 | SPECIAL GRANTS   The following agencies offer scholarships/grants: 1. CHED-Student Financial Assistance Programs (StuFAPs) Scholarship Grant 2....
#    5. Score: 0.5489 | DOST-SEI Scholarship Grant 4....
#
# ──────────────────────────────────────────────────────────────────────
# Question 5/6
# Q: How can I apply for an academic scholarship?
# Expected Reference: Academic Scholarship Requirements section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How can I apply for an academic scholarship?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7099 | Must not be a recipient of scholarship/grant from any government agency. 4....
#    2. Score: 0.6595 | Requirements 1. Duly accomplished Scholarship Form from the Office of Student Affairs and Services (APPENDIX J, Page 90) and signed by the respective ...
#    3. Score: 0.6595 | Requirements 1. Duly accomplished Scholarship Form from the Office of Student Affairs and Services (APPENDIX J, Page 90) and signed by the respective ...
#    4. Score: 0.6303 | Requirements 1. Duly accomplished Scholarship Form from the Office of Student Affairs (SAS) and signed by the respective personnel concerned. 2....
#    5. Score: 0.6233 | EARIST Faculty Sponsored Scholarship 3....
#
# ──────────────────────────────────────────────────────────────────────
# Question 6/6
# Q: What happens if I fail to pay my fees on time?
# Expected Reference: Late Payment Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What happens if I fail to pay my fees on time?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5988 | Refund – to return certain amount of fees within a prescribed period....
#    2. Score: 0.5210 | Failure to enroll......
#    3. Score: 0.5059 | Paying Students – overstaying students who are not able to finish their program on the prescribed period and is considered ineligible to avail the fre...
#    4. Score: 0.4994 | Fee – an amount of money to be paid in a given semester....
#    5. Score: 0.4789 | Penalties    * 3.2.2.1....
#
# ======================================================================
# CATEGORY SUMMARY: Fees, Payments and Scholarships
# ======================================================================
# Average Top Score: 0.6438
# Score Range: 0.5558 - 0.7472
#
# Confidence Distribution:
#    High (>0.7):   2/6 questions (33.3%)
#    Medium (0.5-0.7): 4/6 questions (66.7%)
#    Low (<0.5):    0/6 questions (0.0%)
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: Academic Policies and Grading
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: Academic Policies and Grading
# Total Questions: 8
# Model: multi-qa-mpnet-base-dot-v1
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/8
# Q: How is the grading system computed in EARIST?
# Expected Reference: Grading System section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How is the grading system computed in EARIST?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7199 | ## SECTION 6. GRADING SYSTEM   6.1 The students’ academic performance shall be graded in accordance with the following numerical system:   Grade: 1.00...
#    2. Score: 0.5769 | Freshmen 1.1 Form 138 (Senior and High School Report Card)   1.2 Certificate of Good Moral Character with school seal   1.3 Birth Certificate (PSA Aut...
#    3. Score: 0.5580 | Section 4. CLASSIFICATION OF STUDENTS   4.1 According to Admission Status   4.1.1 As Beginning Freshmen – Student admitted through the EARIST College ...
#    4. Score: 0.5479 | Rectification of grades – to correct wrong entries of data....
#    5. Score: 0.5261 | * 4.11.1 Guidelines on Selection of Student-Athletes                                                                                                  ...
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/8
# Q: What is the passing grade for college students?
# Expected Reference: Academic Standards section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What is the passing grade for college students?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7280 | Senior – fourth year student....
#    2. Score: 0.7097 | Junior – third year student....
#    3. Score: 0.7037 | Freshman – first year student....
#    4. Score: 0.6941 | Fifth Year – fifth year student....
#    5. Score: 0.6786 | Must not have a failing grade or dropped subject in the previous semester. ##### b....
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/8
# Q: Can I request for grade reconsideration if I believe there was an error?
# Expected Reference: Grade Re-evaluation Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Can I request for grade reconsideration if I believe there was an error?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6974 | Rectification of grades – to correct wrong entries of data....
#    2. Score: 0.6342 | 6.8 Request for change of grade   A request for a change of grade may be teacher/student-initiated if the teacher inadvertently made a mistake in the ...
#    3. Score: 0.5420 | Copy of current Report of Grades....
#    4. Score: 0.5420 | Copy of current Report of Grades....
#    5. Score: 0.5334 | 6.7 A student who has received a passing grade in a course shall not be allowed to take another examination for the purpose of improving his grade....
#
# ──────────────────────────────────────────────────────────────────────
# Question 4/8
# Q: What is the policy on academic probation or retention?
# Expected Reference: Academic Retention Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What is the policy on academic probation or retention?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6487 | 7.2. #### 11.2.3 Probation shall be lifted once a student has passed all his/her subjects in the following semester. #### 11.2.4 Students who have bee...
#    2. Score: 0.6110 | #### 8.2.9 Upon his/her return, a student is covered by the curriculum currently in effect. #### 8.2.10 In case a student loses his/her status as a st...
#    3. Score: 0.6088 | TENURE, LEAVE OF ABSENCE, AND HONORABLE DISMISSAL   ### 8.1 Tenure   #### 8.1.1 For Regular Students: A regular student should finish the academic pro...
#    4. Score: 0.5872 | Retention – enrolment in any school year that continues to be in school the following year....
#    5. Score: 0.5763 | ARTICLE II ACADEMIC POLICIES   Section 1....
#
# ──────────────────────────────────────────────────────────────────────
# Question 5/8
# Q: How do I qualify for the Dean’s List?
# Expected Reference: Honors and Awards section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How do I qualify for the Dean’s List?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7174 | Admission Recommendation from the College Dean....
#    2. Score: 0.6171 | Admission Requirements   #### 1....
#    3. Score: 0.6010 | Must be enrolled in any bachelor or associate program (Undergraduate Program)                                                                         ...
#    4. Score: 0.5867 | Must not be a recipient of scholarship/grant from any government agency. 4....
#    5. Score: 0.5759 | #### 10.2.4.2 Have completed at least 75% of the total number of the academic units or hours required for graduation in the Institute. #### 10.2.4.3 H...
#
# ──────────────────────────────────────────────────────────────────────
# Question 6/8
# Q: What should I do if I failed a subject?
# Expected Reference: Repetition of Subjects section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What should I do if I failed a subject?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6707 | Obtain a failing grade......
#    2. Score: 0.6417 | Failure to enroll......
#    3. Score: 0.6064 | * b. Obtain a failing grade during term......
#    4. Score: 0.5818 | Failed Grade – a grade given to a student who does not qualify for passing a subject....
#    5. Score: 0.5799 | Must not have a failing grade and dropped subject in the previous semester....
#
# ──────────────────────────────────────────────────────────────────────
# Question 7/8
# Q: Can I take make-up exams for missed tests?
# Expected Reference: Make-up Examination Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Can I take make-up exams for missed tests?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.4770 | Rectification of grades – to correct wrong entries of data....
#    2. Score: 0.4549 | Failure to enroll......
#    3. Score: 0.4521 | Obtain a failing grade......
#    4. Score: 0.4303 | Must not have a failing grade and dropped subject in the previous semester....
#    5. Score: 0.4273 | Copy of current Report of Grades....
#
# ──────────────────────────────────────────────────────────────────────
# Question 8/8
# Q: What is the policy on incomplete grades?
# Expected Reference: Incomplete Grade section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What is the policy on incomplete grades?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6548 | Copy of current Report of Grades....
#    2. Score: 0.6548 | Copy of current Report of Grades....
#    3. Score: 0.6399 | Incomplete Grade – a temporarily grade given to a student who may qualify for passing but has not complied with certain requirements of the subject. I...
#    4. Score: 0.6398 | Rectification of grades – to correct wrong entries of data....
#    5. Score: 0.6376 | Failed Grade – a grade given to a student who does not qualify for passing a subject....
#
# ======================================================================
# CATEGORY SUMMARY: Academic Policies and Grading
# ======================================================================
# Average Top Score: 0.6642
# Score Range: 0.4770 - 0.7280
#
# Confidence Distribution:
#    High (>0.7):   3/8 questions (37.5%)
#    Medium (0.5-0.7): 4/8 questions (50.0%)
#    Low (<0.5):    1/8 questions (12.5%)
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: Attendance and Conduct
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: Attendance and Conduct
# Total Questions: 6
# Model: multi-qa-mpnet-base-dot-v1
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/6
# Q: What happens if I exceed the number of absences allowed?
# Expected Reference: Attendance Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What happens if I exceed the number of absences allowed?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5712 | 5.10 Three successive unexcused absences shall be reported by the faculty member concerned to the College Prefect of Discipline who shall call for the...
#    2. Score: 0.5413 | Likewise, the faculty member drops the student from the roll for having exceeded the allowable number of absences. 6.6 The No Credit (NC) grade shall ...
#    3. Score: 0.5093 | ### 7.1 Old students, except those in the senior year, with failures corresponding to three (3) or more courses within a semester or five (5) cumulati...
#    4. Score: 0.4977 | Penalties    * 3.2.2.1....
#    5. Score: 0.4906 | The Dean/Chairperson shall inform the faculty member(s) concerned. 5.8 Absence due to illness may be excused if the student submits a medical certific...
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/6
# Q: Are students required to wear uniforms in EARIST?
# Expected Reference: Student Uniform Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Are students required to wear uniforms in EARIST?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6353 | CONDUCT IN SCHOOL 3.1. Wearing of Prescribed Uniform * Every student shall wear the prescribed uniform on Mondays, Wednesdays, and Fridays. * Students...
#    2. Score: 0.6264 | Students shall be allowed to wear organizational shirts if the recognized organization is conducting an activity approved by the Institute. 3.2....
#    3. Score: 0.6236 | Unauthorized changing of uniform inside the campus                 * 4.1.2.18....
#    4. Score: 0.6206 | * Organizational Shirt uniform may be worn on Saturdays....
#    5. Score: 0.6163 | Wearing of goatee, colored nail polish, earrings for male students, and body piercings or loud tattoos are prohibited....
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/6
# Q: What are the disciplinary actions for students who violate school rules?
# Expected Reference: Code of Discipline section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What are the disciplinary actions for students who violate school rules?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6766 | Disrespect or discourtesy to any faculty member or school personnel              * 4.1.1.6....
#    2. Score: 0.6669 | Other violations of school rules and regulations as may be determined by the concerned authorities ARTICLE IX  STUDENT AFFAIRS AND SERVICES (SAS)  (CM...
#    3. Score: 0.6650 | Preventing faculty members and school employees from performing their duties or from entering the school premises              * 4.1.1.16. Vandalism, ...
#    4. Score: 0.6396 | STUDENT DISCIPLINE 4.1. Types of Offenses 4.1.1....
#    5. Score: 0.6346 | Littering within the school premises                 * 4.1.2.5....
#
# ──────────────────────────────────────────────────────────────────────
# Question 4/6
# Q: Can I excuse my absences due to sickness?
# Expected Reference: Excused Absences Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Can I excuse my absences due to sickness?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5976 | The Dean/Chairperson shall inform the faculty member(s) concerned. 5.8 Absence due to illness may be excused if the student submits a medical certific...
#    2. Score: 0.4555 | 5.10 Three successive unexcused absences shall be reported by the faculty member concerned to the College Prefect of Discipline who shall call for the...
#    3. Score: 0.4355 | Copy of Approved Leave of Absence; 2. Evaluation Record Form from the Registrar's Office; and 3....
#    4. Score: 0.4300 | #### 8.1.3 For Working Student: Working students may finish the academic program within a period equivalent to one and one-half (11/2) times the norma...
#    5. Score: 0.4165 | Failure to enroll......
#
# ──────────────────────────────────────────────────────────────────────
# Question 5/6
# Q: Are there rules about student behavior inside the classroom?
# Expected Reference: Classroom Conduct section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Are there rules about student behavior inside the classroom?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6396 | Peace and Order           * 3.3.7.1. Students are prohibited from creating unnecessary noise and loitering during class hours....
#    2. Score: 0.5981 | Students are expected to show respect to all members of the EARIST academic community and use school property with care. * 3.3.7....
#    3. Score: 0.5938 | Fighting inside or outside the school premises              * 4.1.1.5....
#    4. Score: 0.5765 | Littering within the school premises                 * 4.1.2.5....
#    5. Score: 0.5672 | Wearing of goatee, colored nail polish, earrings for male students, and body piercings or loud tattoos are prohibited....
#
# ──────────────────────────────────────────────────────────────────────
# Question 6/6
# Q: Who handles disciplinary cases in EARIST?
# Expected Reference: Disciplinary Committee section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Who handles disciplinary cases in EARIST?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6044 | ##### 6.8.5 The Dean makes the appropriate recommendation and endorses the case to the Office of the Vice President for Academic Affairs....
#    2. Score: 0.5987 | Dismissal – discharge....
#    3. Score: 0.5915 | MAUNDELITO S. FLORENDO Chief, Institutional Infrastructure Planning and Development Office Chairman, EARIST Grievance Committee and College Legal Coun...
#    4. Score: 0.5316 | ## ARTICLE V ### RIGHTS AND RESPONSIBILITIES OF STUDENTS   #### Section 1. STUDENT RIGHTS   Bonafide students of EARIST shall enjoy the following righ...
#    5. Score: 0.5301 | Develop and foster respect for teammates, coaches, officials and spectators                                                                           ...
#
# ======================================================================
# CATEGORY SUMMARY: Attendance and Conduct
# ======================================================================
# Average Top Score: 0.6208
# Score Range: 0.5712 - 0.6766
#
# Confidence Distribution:
#    High (>0.7):   0/6 questions (0.0%)
#    Medium (0.5-0.7): 6/6 questions (100.0%)
#    Low (<0.5):    0/6 questions (0.0%)
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: Student Services and Organizations
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: Student Services and Organizations
# Total Questions: 6
# Model: multi-qa-mpnet-base-dot-v1
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/6
# Q: What student organizations can I join in EARIST?
# Expected Reference: Student Organizations section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What student organizations can I join in EARIST?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5957 | Membership in an unrecognized student organization              * 4.1.1.12....
#    2. Score: 0.5931 | 2.1 Student Organizations and Student Activities Recognition/accreditation, supervision, and monitoring of student groups......
#    3. Score: 0.5729 | EARIST Faculty Sponsored Scholarship 3....
#    4. Score: 0.5616 | * 1.4.3.3 Student organization applicants shall then proceed......
#    5. Score: 0.5510 | It believes that the EARIST Student Government......
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/6
# Q: Where can I get my student ID validated or replaced?
# Expected Reference: Registrar or Student Affairs Office section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Where can I get my student ID validated or replaced?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6833 | Official Receipt (for ID replacement) 3.2.2....
#    2. Score: 0.6100 | Copy of previous Certificate of Registration....
#    3. Score: 0.6100 | Copy of previous Certificate of Registration....
#    4. Score: 0.6013 | In case of loss of ID, the following must be submitted: 3.2.1.1. Notarized Affidavit of Loss 3.2.1.2. Accomplished Clearance Form (from the Office of ...
#    5. Score: 0.5741 | Membership in an unrecognized student organization              * 4.1.1.12....
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/6
# Q: Does EARIST offer guidance or counseling services?
# Expected Reference: Guidance and Counseling Office section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Does EARIST offer guidance or counseling services?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5559 | It regularly conducts consultations......
#    2. Score: 0.5512 | * 1.2.2 Counseling is a goal-oriented relationship between a professionally trained, competent counselor and an individual seeking help......
#    3. Score: 0.5218 | * 4.9.2 Programs for life skills training (e.g. conflict management, counseling, testing, referrals to specialists) are done whenever necessary....
#    4. Score: 0.4929 | * 1.3.1 There shall be regular career seminars and job placement services available for the students....
#    5. Score: 0.4918 | EARIST Faculty Sponsored Scholarship 3....
#
# ──────────────────────────────────────────────────────────────────────
# Question 4/6
# Q: How can I request a copy of my transcript of records?
# Expected Reference: Registrar Services section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How can I request a copy of my transcript of records?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6687 | Transcript Of Records – an official record of a student’s grade....
#    2. Score: 0.5986 | Copy of current Report of Grades....
#    3. Score: 0.5986 | Copy of current Report of Grades....
#    4. Score: 0.5409 | The subject(s) taken from the previous school may be credited upon submission of Official Transcript of Records, to be evaluated by the Department Cha...
#    5. Score: 0.5376 | Copy of Approved Leave of Absence; 2. Evaluation Record Form from the Registrar's Office; and 3....
#
# ──────────────────────────────────────────────────────────────────────
# Question 5/6
# Q: Who should I contact if I have a problem with my class schedule?
# Expected Reference: Registrar or Academic Department section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Who should I contact if I have a problem with my class schedule?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5267 | 5.10 Three successive unexcused absences shall be reported by the faculty member concerned to the College Prefect of Discipline who shall call for the...
#    2. Score: 0.5248 | CHANGING CLASSES, SUBSTITUTION, AND DROPPING OF COURSES   3.1 The student may apply for a change of class (subject/schedule) by filing the College Adv...
#    3. Score: 0.5206 | Failure to enroll......
#    4. Score: 0.5000 | 2009)   ## SECTION 5. ATTENDANCE   5.1 Students are required to attend all classes starting with the first meeting of every class. 5.2 Non-attendance ...
#    5. Score: 0.4890 | Attendance to classes                                                                                                                                 ...
#
# ──────────────────────────────────────────────────────────────────────
# Question 6/6
# Q: Where can I find announcements about campus activities?
# Expected Reference: Student Affairs or Bulletin Announcements section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Where can I find announcements about campus activities?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5342 | Loitering or making unnecessary noise within the campus                 * 4.1.2.4....
#    2. Score: 0.5255 | Also, will promote the exercise of ecumenism and unity of the faithful on the campus. ARTICLE XIII GUIDELINES ON CULTURAL PROGRAMS / ACTIVITIES   Sect...
#    3. Score: 0.5132 | * 4.1.3 List of tuition and other school fees and educational visits and field trips are posted in conspicuous places....
#    4. Score: 0.5114 | 54 - ARTICLE XI – GUIDELINES ON CAMPUS PUBLICATION ..... 62 - ARTICLE XII – GUIDELINES ON RELIGIOUS ACTIVITIES ..... 65 - ARTICLE XIII – GUIDELINES ON...
#    5. Score: 0.5001 | 7.7 All approved student activities must be disseminated and coordinated with the concerned College Dean and Security office....
#
# ======================================================================
# CATEGORY SUMMARY: Student Services and Organizations
# ======================================================================
# Average Top Score: 0.5941
# Score Range: 0.5267 - 0.6833
#
# Confidence Distribution:
#    High (>0.7):   0/6 questions (0.0%)
#    Medium (0.5-0.7): 6/6 questions (100.0%)
#    Low (<0.5):    0/6 questions (0.0%)
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: Graduation and Academic Completion
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: Graduation and Academic Completion
# Total Questions: 5
# Model: multi-qa-mpnet-base-dot-v1
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/5
# Q: What are the requirements to graduate from EARIST?
# Expected Reference: Graduation Requirements section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What are the requirements to graduate from EARIST?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7368 | Must be enrolled in any bachelor or associate program (Undergraduate Program)                                                                         ...
#    2. Score: 0.7205 | Admission Requirements   #### 1....
#    3. Score: 0.6637 | Must not have a failing grade or dropped subject in the previous semester. ##### b....
#    4. Score: 0.6617 | Section 4. CLASSIFICATION OF STUDENTS   4.1 According to Admission Status   4.1.1 As Beginning Freshmen – Student admitted through the EARIST College ...
#    5. Score: 0.6616 | Qualifications 1. Currently enrolled in one of the courses in any of the college....
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/5
# Q: When are graduation applications usually submitted?
# Expected Reference: Application for Graduation section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'When are graduation applications usually submitted?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5810 | Junior – third year student....
#    2. Score: 0.5796 | Senior – fourth year student....
#    3. Score: 0.5737 | Freshman – first year student....
#    4. Score: 0.5491 | Admission Recommendation from the College Dean....
#    5. Score: 0.5412 | Fifth Year – fifth year student....
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/5
# Q: Can I join the graduation ceremony if I still have incomplete grades?
# Expected Reference: Graduation Eligibility section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Can I join the graduation ceremony if I still have incomplete grades?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5960 | Must not have a failing grade and dropped subject in the previous semester....
#    2. Score: 0.5756 | Failure to enroll......
#    3. Score: 0.5669 | Must not have a failing grade or dropped subject in the previous semester. ##### b....
#    4. Score: 0.5455 | Must have a passing grade in all subjects including P.E. and NSTP (MTSLTS/CWTS) enrolled in order to qualify for continuance for the following semeste...
#    5. Score: 0.5387 | 1.5 No student will be allowed to attend classes in any subject if his/her name is not included in the Official Class List issued by the Office of the...
#
# ──────────────────────────────────────────────────────────────────────
# Question 4/5
# Q: How can I request for my diploma or transcript after graduation?
# Expected Reference: Post-Graduation Document Request section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How can I request for my diploma or transcript after graduation?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6185 | Admission Recommendation from the College Dean....
#    2. Score: 0.5506 | GRADUATION REQUIREMENTS   ### 9.1 A candidate for graduation shall file an application for graduation to the Registrar's Office. ### 9.2 A student sha...
#    3. Score: 0.5338 | The subject(s) taken from the previous school may be credited upon submission of Official Transcript of Records, to be evaluated by the Department Cha...
#    4. Score: 0.5292 | Must be enrolled in any bachelor or associate program (Undergraduate Program)                                                                         ...
#    5. Score: 0.5281 | Must not have a failing grade and dropped subject in the previous semester....
#
# ──────────────────────────────────────────────────────────────────────
# Question 5/5
# Q: Does EARIST hold recognition ceremonies for honor students?
# Expected Reference: Honors and Recognition section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Does EARIST hold recognition ceremonies for honor students?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5868 | Student leaders are given opportunities to attend leadership training......
#    2. Score: 0.5742 | EARIST Faculty Sponsored Scholarship 3....
#    3. Score: 0.5419 | May God bless our Alma Mater and its graduates forever....
#    4. Score: 0.5370 | MAMARADLO President, EARIST Alumni Association, Inc. Member HON....
#    5. Score: 0.5186 | * 2.5.2 The EARISTians shall be the official yearbook......
#
# ======================================================================
# CATEGORY SUMMARY: Graduation and Academic Completion
# ======================================================================
# Average Top Score: 0.6238
# Score Range: 0.5810 - 0.7368
#
# Confidence Distribution:
#    High (>0.7):   1/5 questions (20.0%)
#    Medium (0.5-0.7): 4/5 questions (80.0%)
#    Low (<0.5):    0/5 questions (0.0%)
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: General and Miscellaneous Information
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: General and Miscellaneous Information
# Total Questions: 3
# Model: multi-qa-mpnet-base-dot-v1
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/3
# Q: Where is the EARIST main campus located?
# Expected Reference: Institutional Information section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Where is the EARIST main campus located?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6116 | EARIST Faculty Sponsored Scholarship 3....
#    2. Score: 0.5867 | On July 1, 1946, EARIST acquired its present site at Nagtahan, Sampaloc, Manila....
#    3. Score: 0.5728 | Construction of EARIST – Cavite Campus school buildings   1. December 29, 1983 – Acquisition of 31,282 sq....
#    4. Score: 0.5439 | 3   - Objectives ..... 3 - CURRICULAR OFFERINGS   - Main Campus     - College of Architecture and Fine Arts ..... 4     - College of Arts and Sciences...
#    5. Score: 0.5405 | It believes that the EARIST Student Government......
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/3
# Q: Who is the current president of EARIST?
# Expected Reference: Administration section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Who is the current president of EARIST?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7226 | Caillao in 2006 to 2010. The 7th and current President of EARIST is Dr. Editha V....
#    2. Score: 0.7042 | PILLO President, EARIST Vice – Chair HON....
#    3. Score: 0.6187 | President – the head of the school, college or university....
#    4. Score: 0.6060 | Elected officers......
#    5. Score: 0.5853 | Arturo P. Casuga is the 4th president followed by the 6th President Dr. Eduardo S....
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/3
# Q: What are the official communication channels of EARIST for students?
# Expected Reference: Official Communication Channels section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What are the official communication channels of EARIST for students?'
# Model: multi-qa-mpnet-base-dot-v1
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6070 | Also, will promote the exercise of ecumenism and unity of the faithful on the campus. ARTICLE XIII GUIDELINES ON CULTURAL PROGRAMS / ACTIVITIES   Sect...
#    2. Score: 0.5996 | * 1.4.3.3 Student organization applicants shall then proceed......
#    3. Score: 0.5883 | * 1.3.1 There shall be regular career seminars and job placement services available for the students....
#    4. Score: 0.5800 | 2.1 Student Organizations and Student Activities Recognition/accreditation, supervision, and monitoring of student groups......
#    5. Score: 0.5791 | ## ARTICLE V ### RIGHTS AND RESPONSIBILITIES OF STUDENTS   #### Section 1. STUDENT RIGHTS   Bonafide students of EARIST shall enjoy the following righ...
#
# ======================================================================
# CATEGORY SUMMARY: General and Miscellaneous Information
# ======================================================================
# Average Top Score: 0.6471
# Score Range: 0.6070 - 0.7226
#
# Confidence Distribution:
#    High (>0.7):   1/3 questions (33.3%)
#    Medium (0.5-0.7): 2/3 questions (66.7%)
#    Low (<0.5):    0/3 questions (0.0%)
#
#
# ======================================================================
# OVERALL PERFORMANCE SUMMARY
# ======================================================================
#
# Admissions:
#    Questions: 8
#    Avg Score: 0.6550
#    Range: 0.5962 - 0.7431
#
# Enrollment and Registration:
#    Questions: 8
#    Avg Score: 0.6592
#    Range: 0.5420 - 0.7936
#
# Fees, Payments and Scholarships:
#    Questions: 6
#    Avg Score: 0.6438
#    Range: 0.5558 - 0.7472
#
# Academic Policies and Grading:
#    Questions: 8
#    Avg Score: 0.6642
#    Range: 0.4770 - 0.7280
#
# Attendance and Conduct:
#    Questions: 6
#    Avg Score: 0.6208
#    Range: 0.5712 - 0.6766
#
# Student Services and Organizations:
#    Questions: 6
#    Avg Score: 0.5941
#    Range: 0.5267 - 0.6833
#
# Graduation and Academic Completion:
#    Questions: 5
#    Avg Score: 0.6238
#    Range: 0.5810 - 0.7368
#
# General and Miscellaneous Information:
#    Questions: 3
#    Avg Score: 0.6471
#    Range: 0.6070 - 0.7226
#
# ──────────────────────────────────────────────────────────────────────
# GLOBAL STATISTICS:
#    Total Questions Tested: 50
#    Overall Average Score: 0.6408
#    Median Score: 0.6387
#    Std Deviation: 0.0649
#
#    Overall Confidence Distribution:
#       High (>0.7):   11/50 (22.0%)
#       Medium (0.5-0.7): 38/50 (76.0%)
#       Low (<0.5):    1/50 (2.0%)
# [SUCCESS] Saved 16 experiments to experiment_results.json
#
# ======================================================================
# EXPERIMENT COMPLETE: P50-multi-qa-mpnet-base-dot-v1
# ======================================================================
# Overall Avg Score: 0.6408
# High Confidence: 22.0%
# Execution Time: 0.6s
# ======================================================================
# {'experiment_name': 'P50-multi-qa-mpnet-base-dot-v1',
#  'timestamp': '2025-10-19 12:01:52',
#  'chunking_config': {'strategy': 'semantic',
#   'percentile': 50,
#   'buffer_size': 1},
#  'embedding_model': 'sentence-transformers/multi-qa-mpnet-base-dot-v1',
#  'top_k': 5,
#  'metrics': {'overall_avg_score': 0.6407887136936188,
#   'overall_median_score': 0.6386988759040833,
#   'overall_std': 0.0648837799767138,
#   'min_score': 0.47695988416671753,
#   'max_score': 0.7936431169509888,
#   'high_confidence_pct': 22.0,
#   'medium_confidence_pct': 76.0,
#   'low_confidence_pct': 2.0,
#   'total_questions': 50,
#   'execution_time_seconds': 0.6107816696166992},
#  'category_metrics': {'Admissions': {'avg_score': 0.6549903377890587,
#    'min_score': 0.5961695909500122,
#    'max_score': 0.7430684566497803,
#    'num_questions': 8},
#   'Enrollment and Registration': {'avg_score': 0.6592017114162445,
#    'min_score': 0.5420384407043457,
#    'max_score': 0.7936431169509888,
#    'num_questions': 8},
#   'Fees, Payments and Scholarships': {'avg_score': 0.6437605718771616,
#    'min_score': 0.555824875831604,
#    'max_score': 0.7472105026245117,
#    'num_questions': 6},
#   'Academic Policies and Grading': {'avg_score': 0.6642211675643921,
#    'min_score': 0.47695988416671753,
#    'max_score': 0.7279680371284485,
#    'num_questions': 8},
#   'Attendance and Conduct': {'avg_score': 0.6207684278488159,
#    'min_score': 0.5712016820907593,
#    'max_score': 0.676616907119751,
#    'num_questions': 6},
#   'Student Services and Organizations': {'avg_score': 0.5940905114014944,
#    'min_score': 0.5267239212989807,
#    'max_score': 0.6833059787750244,
#    'num_questions': 6},
#   'Graduation and Academic Completion': {'avg_score': 0.6238342642784118,
#    'min_score': 0.5810352563858032,
#    'max_score': 0.7367950677871704,
#    'num_questions': 5},
#   'General and Miscellaneous Information': {'avg_score': 0.6470805207888285,
#    'min_score': 0.6070315837860107,
#    'max_score': 0.7226303815841675,
#    'num_questions': 3}}}

# %%
# ========================================
# VIEW RESULTS & COMPARISON
# ========================================

# Show comparison dashboard
compare_experiments()

# Show visual comparison
plot_experiment_comparison()
# Out:
# ================================================================================
# EXPERIMENT COMPARISON DASHBOARD
# ================================================================================
# Total Experiments: 16
#
# Rank   Experiment Name                     Avg Score    High Conf %  Time (s)
# ────────────────────────────────────────────────────────────────────────────────
# 1      P50-multi-qa-mpnet-base-dot-v1      0.6408       22.0         0.6
# 2      P50-multi-qa-mpnet-base-dot-v1      0.6408       22.0         1.6
# 3      P50-multi-qa-mpnet-base-dot-v1      0.6341       12.0         1.6
# 4      P45-multi-qa-mpnet-base-dot-v1      0.6318       12.0         0.6
# 5      P45-multi-qa-mpnet-base-dot-v1      0.6318       12.0         0.6
# 6      P60-multi-qa-mpnet-base-dot-v1      0.6259       16.0         1.6
# 7      P65-multi-qa-mpnet-base-dot-v1      0.6230       16.0         1.6
# 8      P50-multi-qa-mpnet-base-dot-v1      0.6226       8.0          1.7
# 9      P70-multi-qa-mpnet-base-dot-v1      0.6213       14.0         1.6
# 10     P50-multi-qa-mpnet-base-dot-v1      0.6189       12.0         0.6
# 11     P75-multi-qa-mpnet-base-dot-v1      0.6122       14.0         1.6
# 12     P70-multi-qa-mpnet-base-dot-v1      0.6093       10.0         0.7
# 13     P65-all-mpnet-base-v2               0.5826       8.0          1.5
# 14     P70-all-mpnet-base-v2               0.5790       8.0          1.6
# 15     P75-all-mpnet-base-v2               0.5693       8.0          1.5
# 16     P80-all-mpnet-base-v2               0.5588       6.0          1.6
#
# ================================================================================
# 🏆 BEST EXPERIMENT: P50-multi-qa-mpnet-base-dot-v1
# ================================================================================
#
# Configuration:
#    Chunking: {'strategy': 'semantic', 'percentile': 50, 'buffer_size': 1}
#    Embedding Model: sentence-transformers/multi-qa-mpnet-base-dot-v1
#    Top-K: 5
#
# Performance Metrics:
#    Average Score: 0.6408
#    Median Score: 0.6387
#    Std Deviation: 0.0649
#    Score Range: 0.4770 - 0.7936
#
# Confidence Distribution:
#    High (>0.7):   22.0%
#    Medium (0.5-0.7): 76.0%
#    Low (<0.5):    2.0%
#
# Category Performance:
#    Admissions: 0.6550
#    Enrollment and Registration: 0.6592
#    Fees, Payments and Scholarships: 0.6438
#    Academic Policies and Grading: 0.6642
#    Attendance and Conduct: 0.6208
#    Student Services and Organizations: 0.5941
#    Graduation and Academic Completion: 0.6238
#    General and Miscellaneous Information: 0.6471
#
# 📈 Improvement over worst: 14.7%
#
# ================================================================================
#
#
# ======================================================================
# EXPERIMENT PERFORMANCE VISUALIZATION
# ======================================================================
#
# Average Score Comparison:
# ----------------------------------------------------------------------
# P50-multi-qa-mpnet-base-dot-v1 0.6408 ████████████████████████████████████████
# P50-multi-qa-mpnet-base-dot-v1 0.6408 ███████████████████████████████████████
# P50-multi-qa-mpnet-base-dot-v1 0.6341 ███████████████████████████████████████
# P45-multi-qa-mpnet-base-dot-v1 0.6318 ███████████████████████████████████████
# P45-multi-qa-mpnet-base-dot-v1 0.6318 ███████████████████████████████████████
# P60-multi-qa-mpnet-base-dot-v1 0.6259 ███████████████████████████████████████
# P65-multi-qa-mpnet-base-dot-v1 0.6230 ██████████████████████████████████████
# P50-multi-qa-mpnet-base-dot-v1 0.6226 ██████████████████████████████████████
# P70-multi-qa-mpnet-base-dot-v1 0.6213 ██████████████████████████████████████
# P50-multi-qa-mpnet-base-dot-v1 0.6189 ██████████████████████████████████████
# P75-multi-qa-mpnet-base-dot-v1 0.6122 ██████████████████████████████████████
# P70-multi-qa-mpnet-base-dot-v1 0.6093 ██████████████████████████████████████
# P65-all-mpnet-base-v2          0.5826 ████████████████████████████████████
# P70-all-mpnet-base-v2          0.5790 ████████████████████████████████████
# P75-all-mpnet-base-v2          0.5693 ███████████████████████████████████
# P80-all-mpnet-base-v2          0.5588 ██████████████████████████████████
#
# High Confidence (>0.7) Percentage:
# ----------------------------------------------------------------------
# P50-multi-qa-mpnet-base-dot-v1   22.0% ████████████████████████████████████████
# P50-multi-qa-mpnet-base-dot-v1   22.0% ████████████████████████████████████████
# P50-multi-qa-mpnet-base-dot-v1   12.0% █████████████████████
# P45-multi-qa-mpnet-base-dot-v1   12.0% █████████████████████
# P45-multi-qa-mpnet-base-dot-v1   12.0% █████████████████████
# P60-multi-qa-mpnet-base-dot-v1   16.0% █████████████████████████████
# P65-multi-qa-mpnet-base-dot-v1   16.0% █████████████████████████████
# P50-multi-qa-mpnet-base-dot-v1    8.0% ██████████████
# P70-multi-qa-mpnet-base-dot-v1   14.0% █████████████████████████
# P50-multi-qa-mpnet-base-dot-v1   12.0% █████████████████████
# P75-multi-qa-mpnet-base-dot-v1   14.0% █████████████████████████
# P70-multi-qa-mpnet-base-dot-v1   10.0% ██████████████████
# P65-all-mpnet-base-v2             8.0% ██████████████
# P70-all-mpnet-base-v2             8.0% ██████████████
# P75-all-mpnet-base-v2             8.0% ██████████████
# P80-all-mpnet-base-v2             6.0% ██████████
#
# ======================================================================
