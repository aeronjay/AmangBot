# %%
with open('../Dataset/StudentHandbookDataset.txt', 'r', encoding='utf-8') as f:
    dataset = f.read()

print(f"Dataset loaded: {len(dataset):,} characters")
print(f"Estimated pages: ~{len(dataset) // 2000}")
# Out:
# Dataset loaded: 171,284 characters
# Estimated pages: ~85

# %%
import torch
from langchain_experimental.text_splitter import SemanticChunker
from langchain_community.embeddings import HuggingFaceEmbeddings
import faiss
import numpy as np
import pickle
import os
import warnings
warnings.filterwarnings('ignore')

# %%
def check_chunks_exist():
    """Check if chunks have been saved"""
    return os.path.exists("saved_chunks/chunks.pkl")

def save_chunks(chunks, filename="saved_chunks/chunks.pkl"):
    """Save chunks to disk"""
    os.makedirs("saved_chunks", exist_ok=True)
    with open(filename, 'wb') as f:
        pickle.dump(chunks, f)
    print(f"[SUCCESS] Saved {len(chunks)} chunks to {filename}")

def load_chunks(filename="saved_chunks/chunks.pkl"):
    """Load chunks from disk"""
    try:
        with open(filename, 'rb') as f:
            chunks = pickle.load(f)
        print(f"[SUCCESS] Loaded {len(chunks)} chunks from {filename}")
        return chunks
    except FileNotFoundError:
        print(f"[ERROR] Chunks file not found: {filename}")
        return None

# Check if chunks already exist
if check_chunks_exist():
    print("[SUCCESS] Chunks file found! You can skip to Step 2 (Embedding Experiments)")
    print("[INFO] To reload chunks, run: chunks = load_chunks()")
else:
    print("[INFO] No saved chunks found. Run the chunking cells below.")
# Out:
# [INFO] No saved chunks found. Run the chunking cells below.

# %%
# ========================================
# EXPERIMENT PARAMETER: CHUNKING STRATEGY
# ========================================
# Change these values to experiment with different chunking!

CHUNKING_STRATEGY = "semantic"  # Options: "semantic", "fixed" (future)
PERCENTILE_THRESHOLD = 60       # Try: 70, 75, 80, 85, 90 (higher = fewer, larger chunks)
BUFFER_SIZE = 1                 # Sentences to merge around breakpoints

# ========================================

# ONLY RUN THIS IF CHUNKS DON'T EXIST OR YOU WANT TO RE-CHUNK
print(f"Loading embedding model for {CHUNKING_STRATEGY} chunking...")
print("   Using CPU for stable performance")

chunking_embed_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2",
    model_kwargs={'device': 'cuda' if torch.cuda.is_available() else 'cpu'},
    encode_kwargs={'normalize_embeddings': True}
)

print(f"Setting up semantic chunker with PERCENTILE={PERCENTILE_THRESHOLD}...")
text_splitter = SemanticChunker(
    embeddings=chunking_embed_model,
    breakpoint_threshold_type="percentile",
    breakpoint_threshold_amount=PERCENTILE_THRESHOLD,
    buffer_size=BUFFER_SIZE,
    add_start_index=True
)
print(f"[SUCCESS] Chunker ready (Percentile: {PERCENTILE_THRESHOLD}, Buffer: {BUFFER_SIZE})!")

# ONLY RUN THIS IF CHUNKS DON'T EXIST OR YOU WANT TO RE-CHUNK
print("Creating semantic chunks from raw text...")
print(f"Configuration: Percentile={PERCENTILE_THRESHOLD}, Buffer={BUFFER_SIZE}")
chunks = text_splitter.create_documents([dataset])
print(f"[SUCCESS] Created {len(chunks)} semantic chunks")

# Analyze chunk quality
chunk_sizes = [len(chunk.page_content) for chunk in chunks]
print(f"\nChunk Analysis:")
print(f"   Average size: {np.mean(chunk_sizes):.0f} characters")
print(f"   Size range: {min(chunk_sizes)} - {max(chunk_sizes)} characters")
print(f"   Total chunks: {len(chunks)}")

# Show sample chunks
print("\nSample chunks:")
for i in range(min(3, len(chunks))):
    chunk_preview = chunks[i].page_content[:150].replace('\n', ' ')
    print(f"   Chunk {i+1}: {chunk_preview}...")

# SAVE THE CHUNKS with configuration in filename
chunk_filename = f"saved_chunks/chunks_p{PERCENTILE_THRESHOLD}_b{BUFFER_SIZE}.pkl"
save_chunks(chunks, filename=chunk_filename)
print(f"\n[SUCCESS] Chunking complete and saved to {chunk_filename}!")
print(f"[INFO] Configuration: Percentile={PERCENTILE_THRESHOLD}, Buffer={BUFFER_SIZE}")

# Load saved chunks - automatically detect the correct file based on parameters
chunk_filename = f"saved_chunks/chunks_p{PERCENTILE_THRESHOLD}_b{BUFFER_SIZE}.pkl"

print(f"Looking for chunks: {chunk_filename}")
chunks = load_chunks(filename=chunk_filename)

if chunks is None:
    print(f"[ERROR] Chunks not found for P={PERCENTILE_THRESHOLD}, B={BUFFER_SIZE}")
    print("[INFO] Please run Step 1 (Chunking) cells first with these parameters!")
else:
    print(f"[SUCCESS] Ready to experiment with {len(chunks)} chunks!")
    print(f"[INFO] Loaded configuration: Percentile={PERCENTILE_THRESHOLD}, Buffer={BUFFER_SIZE}")
# Out:
# Loading embedding model for semantic chunking...
#    Using CPU for stable performance
# Setting up semantic chunker with PERCENTILE=60...
# [SUCCESS] Chunker ready (Percentile: 60, Buffer: 1)!
# Creating semantic chunks from raw text...
# Configuration: Percentile=60, Buffer=1
# [SUCCESS] Created 491 semantic chunks
#
# Chunk Analysis:
#    Average size: 325 characters
#    Size range: 2 - 4752 characters
#    Total chunks: 491
#
# Sample chunks:
#    Chunk 1: ﻿Republic of the Philippines  Eulogio "Amang" Rodriguez Institute of Science and Technology Office of Student Affairs and Services   EARIST STUDENT HA...
#    Chunk 2: i - Acknowledgment ........
#    Chunk 3: ii - HISTORY OF EARIST ..... 1 - MISSION STATEMENTS   - Vision ........
# [SUCCESS] Saved 491 chunks to saved_chunks/chunks_p60_b1.pkl
#
# [SUCCESS] Chunking complete and saved to saved_chunks/chunks_p60_b1.pkl!
# [INFO] Configuration: Percentile=60, Buffer=1
# Looking for chunks: saved_chunks/chunks_p60_b1.pkl
# [SUCCESS] Loaded 491 chunks from saved_chunks/chunks_p60_b1.pkl
# [SUCCESS] Ready to experiment with 491 chunks!
# [INFO] Loaded configuration: Percentile=60, Buffer=1

# %%
# ========================================
# EXPERIMENT PARAMETER: EMBEDDING MODEL
# ========================================
# Change MODEL_NAME to experiment with different embeddings!

# Current options (uncomment one):
# MODEL_NAME = "sentence-transformers/all-mpnet-base-v2"  # Best quality, 768 dim
# MODEL_NAME = "sentence-transformers/all-MiniLM-L6-v2"  # Fast, 384 dim
# MODEL_NAME = "sentence-transformers/multi-qa-mpnet-base-dot-v1"  # Q&A optimized
MODEL_NAME = "nomic-ai/nomic-embed-text-v1.5"  # Multilingual

# ========================================

print(f"\n{'='*70}")
print(f"EMBEDDING MODEL CONFIGURATION")
print(f"{'='*70}")
print(f"Model: {MODEL_NAME}")
print("   Using CPU for stable performance")

embedding_model = HuggingFaceEmbeddings(
    model_name=MODEL_NAME,
    model_kwargs={
        'device': 'cuda',
        'trust_remote_code': True
    },
    encode_kwargs={'normalize_embeddings': True}
)

# Get embedding dimension
test_embed = embedding_model.embed_query("test")

print(f"[SUCCESS] Embedding model loaded!")
print(f"   Model: {MODEL_NAME.split('/')[-1]}")
print(f"   Embedding dimension: {len(test_embed)}")
print(f"   Device: CPU")
print(f"{'='*70}\n")

print("\nGenerating embeddings for all chunks with current model...")
chunk_texts = [chunk.page_content for chunk in chunks]

# Process embeddings in batches to avoid memory issues
batch_size = 32
all_embeddings = []

import time
start_time = time.time()

for i in range(0, len(chunk_texts), batch_size):
    batch = chunk_texts[i:i+batch_size]
    batch_embeddings = embedding_model.embed_documents(batch)
    all_embeddings.extend(batch_embeddings)
    print(f"   Processed batch {i//batch_size + 1}/{(len(chunk_texts) + batch_size - 1)//batch_size}")

elapsed_time = time.time() - start_time
print(f"\n[SUCCESS] Generated {len(all_embeddings)} embeddings in {elapsed_time:.2f}s")
print(f"Average: {elapsed_time/len(all_embeddings):.3f}s per chunk")


# Build FAISS vector store for fast similarity search
print("\nBuilding FAISS vector database...")
dimension = len(all_embeddings[0])
index = faiss.IndexFlatIP(dimension)  # Inner Product for cosine similarity

# Normalize embeddings for proper cosine similarity
embeddings_array = np.array(all_embeddings).astype('float32')
faiss.normalize_L2(embeddings_array)
index.add(embeddings_array)

print(f"[SUCCESS] FAISS index ready: {index.ntotal:,} vectors ({dimension} dimensions)")
print(f"Model: {MODEL_NAME.split('/')[-1]}")
# Out:
# ======================================================================
# EMBEDDING MODEL CONFIGURATION
# ======================================================================
# Model: nomic-ai/nomic-embed-text-v1.5
#    Using CPU for stable performance
# <All keys matched successfully>
# [SUCCESS] Embedding model loaded!
#    Model: nomic-embed-text-v1.5
#    Embedding dimension: 768
#    Device: CPU
# ======================================================================
#
#
# Generating embeddings for all chunks with current model...
#    Processed batch 1/16
#    Processed batch 2/16
#    Processed batch 3/16
#    Processed batch 4/16
#    Processed batch 5/16
#    Processed batch 6/16
#    Processed batch 7/16
#    Processed batch 8/16
#    Processed batch 9/16
#    Processed batch 10/16
#    Processed batch 11/16
#    Processed batch 12/16
#    Processed batch 13/16
#    Processed batch 14/16
#    Processed batch 15/16
#    Processed batch 16/16
#
# [SUCCESS] Generated 491 embeddings in 8.16s
# Average: 0.017s per chunk
#
# Building FAISS vector database...
# [SUCCESS] FAISS index ready: 491 vectors (768 dimensions)
# Model: nomic-embed-text-v1.5

# %%
def retrieve_relevant_chunks(query, top_k=5):
    """Find most relevant chunks for the query"""
    print(f"\nSearching for: '{query}'")
    print(f"Model: {MODEL_NAME.split('/')[-1]}")
    print("=" * 50)

    # Embed the query
    query_embedding = embedding_model.embed_query(query)
    query_vector = np.array([query_embedding]).astype('float32')
    faiss.normalize_L2(query_vector)

    # Search FAISS index
    scores, indices = index.search(query_vector, top_k)

    # Return results with metadata
    results = []
    for idx, score in zip(indices[0], scores[0]):
        if idx < len(chunks):  # Safety check
            chunk = chunks[idx]
            results.append({
                'text': chunk.page_content,
                'score': float(score),
                'chunk_id': int(idx),
                'start_pos': chunk.metadata.get('start_index', 0) if hasattr(chunk, 'metadata') else 0
            })

    return results

def display_retrieval_results(query, results):
    """Display comprehensive retrieval results"""
    print(f"Found {len(results)} relevant chunks for: '{query}'")
    print("=" * 70)

    for i, result in enumerate(results, 1):
        print(f"\nChunk {i} (ID: {result['chunk_id']})")
        print(f"Relevance Score: {result['score']:.4f}")
        print(f"Position in Document: Character {result['start_pos']:,}")
        print(f"Length: {len(result['text'])} characters")
        print(f"Content Preview (first 200 chars):")
        print(f"   {result['text'][:200].replace(chr(10), ' ').replace(chr(13), '')}...")

        # Show full content if it's short enough
        if len(result['text']) <= 500:
            print(f"Full Content:")
            print(f"   {result['text']}")

        print("-" * 40)

    return results

print("[SUCCESS] Retrieval functions ready!")
# Out:
# [SUCCESS] Retrieval functions ready!

# %%
import json
# Load questions from Questions.json
with open('Questions.json', 'r', encoding='utf-8') as f:
    questions_data = json.load(f)

# Count total questions
total_questions = sum(len(questions) for questions in questions_data.values())
print(f"[SUCCESS] Loaded {total_questions} questions across {len(questions_data)} categories")
print("\nCategories:")
for category, questions in questions_data.items():
    print(f"   • {category}: {len(questions)} questions")
# Out:
# [SUCCESS] Loaded 50 questions across 8 categories
#
# Categories:
#    • Admissions: 8 questions
#    • Enrollment and Registration: 8 questions
#    • Fees, Payments and Scholarships: 6 questions
#    • Academic Policies and Grading: 8 questions
#    • Attendance and Conduct: 6 questions
#    • Student Services and Organizations: 6 questions
#    • Graduation and Academic Completion: 5 questions
#    • General and Miscellaneous Information: 3 questions

# %%
def test_category_questions(category_name, top_k=3, show_full_results=False):
    """Test all questions from a specific category"""
    if category_name not in questions_data:
        print(f"[ERROR] Category '{category_name}' not found!")
        print(f"Available categories: {', '.join(questions_data.keys())}")
        return

    questions = questions_data[category_name]
    print(f"\n{'='*70}")
    print(f"Testing Category: {category_name}")
    print(f"Total Questions: {len(questions)}")
    print(f"Model: {MODEL_NAME.split('/')[-1]}")
    print(f"Retrieving top {top_k} chunks per question")
    print(f"{'='*70}")

    all_results = []

    for i, q_item in enumerate(questions, 1):
        question = q_item['question']
        expected_ref = q_item['expected_reference']

        print(f"\n{'─'*70}")
        print(f"Question {i}/{len(questions)}")
        print(f"Q: {question}")
        print(f"Expected Reference: {expected_ref}")
        print(f"{'─'*70}")

        # Retrieve relevant chunks
        results = retrieve_relevant_chunks(question, top_k=top_k)

        # Store results for analysis
        all_results.append({
            'question': question,
            'expected_reference': expected_ref,
            'results': results,
            'top_score': results[0]['score'] if results else 0
        })

        if show_full_results:
            display_retrieval_results(question, results)
        else:
            # Show compact summary
            print(f"\nTop {min(top_k, len(results))} Results:")
            for j, result in enumerate(results[:top_k], 1):
                preview = result['text'][:150].replace('\n', ' ').replace('\r', '')
                print(f"   {j}. Score: {result['score']:.4f} | {preview}...")

    # Summary statistics
    print(f"\n{'='*70}")
    print(f"CATEGORY SUMMARY: {category_name}")
    print(f"{'='*70}")
    avg_top_score = np.mean([r['top_score'] for r in all_results])
    print(f"Average Top Score: {avg_top_score:.4f}")
    print(f"Score Range: {min([r['top_score'] for r in all_results]):.4f} - {max([r['top_score'] for r in all_results]):.4f}")

    # Score distribution
    high_confidence = sum(1 for r in all_results if r['top_score'] > 0.7)
    medium_confidence = sum(1 for r in all_results if 0.5 <= r['top_score'] <= 0.7)
    low_confidence = sum(1 for r in all_results if r['top_score'] < 0.5)

    print(f"\nConfidence Distribution:")
    print(f"   High (>0.7):   {high_confidence}/{len(all_results)} questions ({high_confidence/len(all_results)*100:.1f}%)")
    print(f"   Medium (0.5-0.7): {medium_confidence}/{len(all_results)} questions ({medium_confidence/len(all_results)*100:.1f}%)")
    print(f"   Low (<0.5):    {low_confidence}/{len(all_results)} questions ({low_confidence/len(all_results)*100:.1f}%)")

    return all_results

print("[SUCCESS] Category testing function ready!")


def test_all_questions(top_k=3, show_detailed=False):
    """Test all questions from all categories"""
    print(f"\n{'='*70}")
    print(f"COMPREHENSIVE RETRIEVAL TEST")
    print(f"{'='*70}")
    print(f"Model: {MODEL_NAME.split('/')[-1]}")
    print(f"Total Categories: {len(questions_data)}")
    print(f"Total Questions: {sum(len(q) for q in questions_data.values())}")
    print(f"Top-K per question: {top_k}")
    print(f"{'='*70}")

    all_category_results = {}

    for category_name in questions_data.keys():
        print(f"\n\n{'█'*70}")
        print(f"CATEGORY: {category_name}")
        print(f"{'█'*70}")

        category_results = test_category_questions(
            category_name,
            top_k=top_k,
            show_full_results=show_detailed
        )
        all_category_results[category_name] = category_results

    # Overall summary
    print(f"\n\n{'='*70}")
    print(f"OVERALL PERFORMANCE SUMMARY")
    print(f"{'='*70}")

    all_scores = []
    for category, results in all_category_results.items():
        scores = [r['top_score'] for r in results]
        all_scores.extend(scores)
        avg = np.mean(scores)
        print(f"\n{category}:")
        print(f"   Questions: {len(results)}")
        print(f"   Avg Score: {avg:.4f}")
        print(f"   Range: {min(scores):.4f} - {max(scores):.4f}")

    # Global statistics
    print(f"\n{'─'*70}")
    print(f"GLOBAL STATISTICS:")
    print(f"   Total Questions Tested: {len(all_scores)}")
    print(f"   Overall Average Score: {np.mean(all_scores):.4f}")
    print(f"   Median Score: {np.median(all_scores):.4f}")
    print(f"   Std Deviation: {np.std(all_scores):.4f}")

    # Overall confidence distribution
    high = sum(1 for s in all_scores if s > 0.7)
    medium = sum(1 for s in all_scores if 0.5 <= s <= 0.7)
    low = sum(1 for s in all_scores if s < 0.5)

    print(f"\n   Overall Confidence Distribution:")
    print(f"      High (>0.7):   {high}/{len(all_scores)} ({high/len(all_scores)*100:.1f}%)")
    print(f"      Medium (0.5-0.7): {medium}/{len(all_scores)} ({medium/len(all_scores)*100:.1f}%)")
    print(f"      Low (<0.5):    {low}/{len(all_scores)} ({low/len(all_scores)*100:.1f}%)")

    return all_category_results

print("[SUCCESS] Comprehensive testing function ready!")




# Create experiment tracking system
experiment_results = []

def save_experiment_results(filename="experiment_results.json"):
    """Save all experiment results to file"""
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(experiment_results, f, indent=2)
    print(f"[SUCCESS] Saved {len(experiment_results)} experiments to {filename}")

def load_experiment_results(filename="experiment_results.json"):
    """Load previous experiment results"""
    global experiment_results
    try:
        with open(filename, 'r', encoding='utf-8') as f:
            experiment_results = json.load(f)
        print(f"[SUCCESS] Loaded {len(experiment_results)} previous experiments")
        return experiment_results
    except FileNotFoundError:
        print(f"[INFO] No previous results found. Starting fresh!")
        return []

# Try to load previous results
load_experiment_results()

print("[SUCCESS] Experiment tracking system ready!")
print(f"Current experiments tracked: {len(experiment_results)}")


def run_full_experiment(experiment_name, chunking_config, embedding_model_name, top_k=3):
    """
    Run a complete experiment with specific chunking and embedding configuration

    Args:
        experiment_name: Descriptive name for this experiment
        chunking_config: Dict with keys 'strategy', 'params' (e.g., percentile, overlap)
        embedding_model_name: HuggingFace model name
        top_k: Number of chunks to retrieve per query
    """
    start_time = time.time()

    print(f"\n{'█'*70}")
    print(f"RUNNING EXPERIMENT: {experiment_name}")
    print(f"{'█'*70}")
    print(f"Chunking: {chunking_config}")
    print(f"Embedding: {embedding_model_name}")
    print(f"Top-K: {top_k}")
    print(f"{'█'*70}\n")

    # Test with all questions
    category_results = test_all_questions(top_k=top_k, show_detailed=False)

    # Calculate metrics
    all_scores = []
    category_scores = {}

    for category, results in category_results.items():
        scores = [r['top_score'] for r in results]
        all_scores.extend(scores)
        category_scores[category] = {
            'avg_score': float(np.mean(scores)),
            'min_score': float(min(scores)),
            'max_score': float(max(scores)),
            'num_questions': len(scores)
        }

    # Compute overall metrics
    elapsed_time = time.time() - start_time

    experiment_data = {
        'experiment_name': experiment_name,
        'timestamp': time.strftime('%Y-%m-%d %H:%M:%S'),
        'chunking_config': chunking_config,
        'embedding_model': embedding_model_name,
        'top_k': top_k,
        'metrics': {
            'overall_avg_score': float(np.mean(all_scores)),
            'overall_median_score': float(np.median(all_scores)),
            'overall_std': float(np.std(all_scores)),
            'min_score': float(min(all_scores)),
            'max_score': float(max(all_scores)),
            'high_confidence_pct': float(sum(1 for s in all_scores if s > 0.7) / len(all_scores) * 100),
            'medium_confidence_pct': float(sum(1 for s in all_scores if 0.5 <= s <= 0.7) / len(all_scores) * 100),
            'low_confidence_pct': float(sum(1 for s in all_scores if s < 0.5) / len(all_scores) * 100),
            'total_questions': len(all_scores),
            'execution_time_seconds': elapsed_time
        },
        'category_metrics': category_scores
    }

    # Save to tracking
    experiment_results.append(experiment_data)
    save_experiment_results()

    print(f"\n{'='*70}")
    print(f"EXPERIMENT COMPLETE: {experiment_name}")
    print(f"{'='*70}")
    print(f"Overall Avg Score: {experiment_data['metrics']['overall_avg_score']:.4f}")
    print(f"High Confidence: {experiment_data['metrics']['high_confidence_pct']:.1f}%")
    print(f"Execution Time: {elapsed_time:.1f}s")
    print(f"{'='*70}\n")

    return experiment_data

print("[SUCCESS] Experiment runner ready!")


def compare_experiments():
    """Compare all tracked experiments and show rankings"""
    if not experiment_results:
        print("[INFO] No experiments to compare yet. Run some experiments first!")
        return

    print(f"\n{'='*80}")
    print(f"EXPERIMENT COMPARISON DASHBOARD")
    print(f"{'='*80}")
    print(f"Total Experiments: {len(experiment_results)}\n")

    # Sort by overall average score
    sorted_experiments = sorted(
        experiment_results,
        key=lambda x: x['metrics']['overall_avg_score'],
        reverse=True
    )

    # Display ranking table
    print(f"{'Rank':<6} {'Experiment Name':<35} {'Avg Score':<12} {'High Conf %':<12} {'Time (s)':<10}")
    print(f"{'─'*80}")

    for i, exp in enumerate(sorted_experiments, 1):
        name = exp['experiment_name'][:33]
        avg_score = exp['metrics']['overall_avg_score']
        high_conf = exp['metrics']['high_confidence_pct']
        exec_time = exp['metrics']['execution_time_seconds']

        print(f"{i:<6} {name:<35} {avg_score:<12.4f} {high_conf:<12.1f} {exec_time:<10.1f}")

    # Show best experiment details
    print(f"\n{'='*80}")
    print(f"🏆 BEST EXPERIMENT: {sorted_experiments[0]['experiment_name']}")
    print(f"{'='*80}")
    best = sorted_experiments[0]

    print(f"\nConfiguration:")
    print(f"   Chunking: {best['chunking_config']}")
    print(f"   Embedding Model: {best['embedding_model']}")
    print(f"   Top-K: {best['top_k']}")

    print(f"\nPerformance Metrics:")
    print(f"   Average Score: {best['metrics']['overall_avg_score']:.4f}")
    print(f"   Median Score: {best['metrics']['overall_median_score']:.4f}")
    print(f"   Std Deviation: {best['metrics']['overall_std']:.4f}")
    print(f"   Score Range: {best['metrics']['min_score']:.4f} - {best['metrics']['max_score']:.4f}")

    print(f"\nConfidence Distribution:")
    print(f"   High (>0.7):   {best['metrics']['high_confidence_pct']:.1f}%")
    print(f"   Medium (0.5-0.7): {best['metrics']['medium_confidence_pct']:.1f}%")
    print(f"   Low (<0.5):    {best['metrics']['low_confidence_pct']:.1f}%")

    print(f"\nCategory Performance:")
    for category, metrics in best['category_metrics'].items():
        print(f"   {category}: {metrics['avg_score']:.4f}")

    # Show comparison with worst
    if len(sorted_experiments) > 1:
        worst = sorted_experiments[-1]
        improvement = ((best['metrics']['overall_avg_score'] - worst['metrics']['overall_avg_score'])
                      / worst['metrics']['overall_avg_score'] * 100)
        print(f"\n📈 Improvement over worst: {improvement:.1f}%")

    print(f"\n{'='*80}\n")

    return sorted_experiments

print("[SUCCESS] Comparison function ready!")


# Quick visualization of experiment results
def plot_experiment_comparison():
    """Create a simple text-based comparison chart"""
    if not experiment_results:
        print("[INFO] No experiments to visualize yet.")
        return

    sorted_exp = sorted(experiment_results, key=lambda x: x['metrics']['overall_avg_score'], reverse=True)

    print(f"\n{'='*70}")
    print(f"EXPERIMENT PERFORMANCE VISUALIZATION")
    print(f"{'='*70}\n")

    # Bar chart of average scores
    print("Average Score Comparison:")
    print("-" * 70)
    max_score = max(e['metrics']['overall_avg_score'] for e in sorted_exp)

    for exp in sorted_exp:
        name = exp['experiment_name'][:30]
        score = exp['metrics']['overall_avg_score']
        bar_length = int((score / max_score) * 40)
        bar = '█' * bar_length
        print(f"{name:<30} {score:.4f} {bar}")

    print()

    # High confidence percentage comparison
    print("High Confidence (>0.7) Percentage:")
    print("-" * 70)
    max_conf = max(e['metrics']['high_confidence_pct'] for e in sorted_exp)

    for exp in sorted_exp:
        name = exp['experiment_name'][:30]
        conf = exp['metrics']['high_confidence_pct']
        bar_length = int((conf / max_conf) * 40) if max_conf > 0 else 0
        bar = '█' * bar_length
        print(f"{name:<30} {conf:>6.1f}% {bar}")

    print(f"\n{'='*70}\n")

print("[SUCCESS] Visualization function ready!")
# Out:
# [SUCCESS] Category testing function ready!
# [SUCCESS] Comprehensive testing function ready!
# [SUCCESS] Loaded 18 previous experiments
# [SUCCESS] Experiment tracking system ready!
# Current experiments tracked: 18
# [SUCCESS] Experiment runner ready!
# [SUCCESS] Comparison function ready!
# [SUCCESS] Visualization function ready!

# %%
# ========================================
# RUN CURRENT EXPERIMENT
# ========================================
# This will test your current chunking + embedding configuration
# against all questions from Questions.json

# Automatically detect current configuration
current_chunking = {
    "strategy": "semantic",
    "percentile": PERCENTILE_THRESHOLD if 'PERCENTILE_THRESHOLD' in dir() else 80,
    "buffer_size": BUFFER_SIZE if 'BUFFER_SIZE' in dir() else 1
}

current_model = MODEL_NAME.split('/')[-1] if 'MODEL_NAME' in dir() else "unknown"

# Generate experiment name
experiment_name = f"P{current_chunking['percentile']}-{current_model}"

print(f"Ready to run experiment: {experiment_name}")
print(f"Chunking: {current_chunking}")
print(f"Embedding: {MODEL_NAME if 'MODEL_NAME' in dir() else 'Not set'}")
print("\n🚀 Uncomment the line below to run the experiment:")
print("# run_full_experiment(experiment_name, current_chunking, MODEL_NAME, top_k=5)")

# Uncomment to run:
run_full_experiment(experiment_name, current_chunking, MODEL_NAME, top_k=5)
# Out:
# Ready to run experiment: P60-nomic-embed-text-v1.5
# Chunking: {'strategy': 'semantic', 'percentile': 60, 'buffer_size': 1}
# Embedding: nomic-ai/nomic-embed-text-v1.5
#
# 🚀 Uncomment the line below to run the experiment:
# # run_full_experiment(experiment_name, current_chunking, MODEL_NAME, top_k=5)
#
# ██████████████████████████████████████████████████████████████████████
# RUNNING EXPERIMENT: P60-nomic-embed-text-v1.5
# ██████████████████████████████████████████████████████████████████████
# Chunking: {'strategy': 'semantic', 'percentile': 60, 'buffer_size': 1}
# Embedding: nomic-ai/nomic-embed-text-v1.5
# Top-K: 5
# ██████████████████████████████████████████████████████████████████████
#
#
# ======================================================================
# COMPREHENSIVE RETRIEVAL TEST
# ======================================================================
# Model: nomic-embed-text-v1.5
# Total Categories: 8
# Total Questions: 50
# Top-K per question: 5
# ======================================================================
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: Admissions
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: Admissions
# Total Questions: 8
# Model: nomic-embed-text-v1.5
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/8
# Q: What are the requirements for new freshmen applying to EARIST?
# Expected Reference: Admission Requirements section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What are the requirements for new freshmen applying to EARIST?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7919 | The number of applicants to be admitted depends on the resources of the Institute such as rooms and faculty. **Admission Qualifications of Local Stude...
#    2. Score: 0.7381 | Admission Requirements   #### 1. Freshmen 1.1 Form 138 (Senior and High School Report Card)   1.2 Certificate of Good Moral Character with school seal...
#    3. Score: 0.7272 | Section 4. CLASSIFICATION OF STUDENTS   4.1 According to Admission Status   4.1.1 As Beginning Freshmen – Student admitted through the EARIST College ...
#    4. Score: 0.6829 | * 4.11.1 Guidelines on Selection of Student-Athletes                                                                                                  ...
#    5. Score: 0.6596 | Entry Level Physical Examination for Freshmen                                                                                                         ...
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/8
# Q: How can I apply for admission as a transferee student?
# Expected Reference: Admission Procedures section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How can I apply for admission as a transferee student?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7780 | ## ADMISSION OF TRANSFEREES   Students may be admitted as transferees depending on the availability of slots provided that they meet all the academic ...
#    2. Score: 0.7589 | Admission – the act of admitting or allowing a student for enrollment....
#    3. Score: 0.7443 | Admission Requirements   #### 1. Freshmen 1.1 Form 138 (Senior and High School Report Card)   1.2 Certificate of Good Moral Character with school seal...
#    4. Score: 0.7427 | Shifters must satisfactorily meet the grade requirement prescribed by the college and there must be an available slot. #### 4.1.4 As Transferring Stud...
#    5. Score: 0.7147 | Transcript Of Records – an official record of a student’s grade. Transferee – refers to a student who entered the school from another school, either p...
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/8
# Q: Does EARIST accept students from other schools?
# Expected Reference: Transfer Student Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Does EARIST accept students from other schools?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7297 | The number of applicants to be admitted depends on the resources of the Institute such as rooms and faculty. **Admission Qualifications of Local Stude...
#    2. Score: 0.6563 | Section 4. CLASSIFICATION OF STUDENTS   4.1 According to Admission Status   4.1.1 As Beginning Freshmen – Student admitted through the EARIST College ...
#    3. Score: 0.6482 | 2017]; - Senior High School Alternative Learning System Accreditation and Equivalency passers. - Transferees preferably with no grade/s of "Dropped", ...
#    4. Score: 0.6460 | Otherwise, the Certificate of Registration shall be considered prior to final Official Class List. 1.6 Cross enrollment in another school is allowed o...
#    5. Score: 0.6393 | Shifters must satisfactorily meet the grade requirement prescribed by the college and there must be an available slot. #### 4.1.4 As Transferring Stud...
#
# ──────────────────────────────────────────────────────────────────────
# Question 4/8
# Q: Where can I submit my admission documents?
# Expected Reference: Office of Admissions section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Where can I submit my admission documents?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7048 | Admission – the act of admitting or allowing a student for enrollment....
#    2. Score: 0.6873 | PLEDGE UPON ADMISSION   Every student should sign the student's pledge and waiver of data privacy. Refusal or violation of its terms shall be a suffic...
#    3. Score: 0.6839 | Admission Requirements   #### 1. Freshmen 1.1 Form 138 (Senior and High School Report Card)   1.2 Certificate of Good Moral Character with school seal...
#    4. Score: 0.6525 | ## ADMISSION OF TRANSFEREES   Students may be admitted as transferees depending on the availability of slots provided that they meet all the academic ...
#    5. Score: 0.6422 | Registration – act or process of entering information of public records or documents in an educational institution....
#
# ──────────────────────────────────────────────────────────────────────
# Question 5/8
# Q: When does EARIST usually start accepting new enrollees?
# Expected Reference: Admission Schedule section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'When does EARIST usually start accepting new enrollees?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6977 | The number of applicants to be admitted depends on the resources of the Institute such as rooms and faculty. **Admission Qualifications of Local Stude...
#    2. Score: 0.6445 | Section 4. CLASSIFICATION OF STUDENTS   4.1 According to Admission Status   4.1.1 As Beginning Freshmen – Student admitted through the EARIST College ...
#    3. Score: 0.6206 | Admission – the act of admitting or allowing a student for enrollment....
#    4. Score: 0.6182 | ## ADMISSION OF TRANSFEREES   Students may be admitted as transferees depending on the availability of slots provided that they meet all the academic ...
#    5. Score: 0.6173 | Caillao in 2006 to 2010. The 7th and current President of EARIST is Dr. Editha V....
#
# ──────────────────────────────────────────────────────────────────────
# Question 6/8
# Q: Are there entrance exams required for admission?
# Expected Reference: Entrance Examination section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Are there entrance exams required for admission?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7377 | Admission Requirements   #### 1. Freshmen 1.1 Form 138 (Senior and High School Report Card)   1.2 Certificate of Good Moral Character with school seal...
#    2. Score: 0.7310 | Admission – the act of admitting or allowing a student for enrollment....
#    3. Score: 0.6928 | Entry Level Physical Examination for Freshmen                                                                                                         ...
#    4. Score: 0.6829 | ## ADMISSION OF TRANSFEREES   Students may be admitted as transferees depending on the availability of slots provided that they meet all the academic ...
#    5. Score: 0.6724 | The number of applicants to be admitted depends on the resources of the Institute such as rooms and faculty. **Admission Qualifications of Local Stude...
#
# ──────────────────────────────────────────────────────────────────────
# Question 7/8
# Q: Can foreign students apply to EARIST?
# Expected Reference: Foreign Student Admission section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Can foreign students apply to EARIST?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7792 | The number of applicants to be admitted depends on the resources of the Institute such as rooms and faculty. **Admission Qualifications of Local Stude...
#    2. Score: 0.6841 | Admission Requirements   #### 1. Freshmen 1.1 Form 138 (Senior and High School Report Card)   1.2 Certificate of Good Moral Character with school seal...
#    3. Score: 0.6638 | Section 4. CLASSIFICATION OF STUDENTS   4.1 According to Admission Status   4.1.1 As Beginning Freshmen – Student admitted through the EARIST College ...
#    4. Score: 0.6546 | 2017]; - Senior High School Alternative Learning System Accreditation and Equivalency passers. - Transferees preferably with no grade/s of "Dropped", ...
#    5. Score: 0.6455 | The Use of EARIST Logo and trademarks Any individual, group or organization who wishes to use, attempt to imitate the EARIST Logo, or the use of a str...
#
# ──────────────────────────────────────────────────────────────────────
# Question 8/8
# Q: What documents are needed for returning students to be readmitted?
# Expected Reference: Re-admission Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What documents are needed for returning students to be readmitted?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7650 | For Re-Admission of students who would like to continue their program after taking the leave of absence, the following are needed:   1....
#    2. Score: 0.7283 | #### 8.2.9 Upon his/her return, a student is covered by the curriculum currently in effect. #### 8.2.10 In case a student loses his/her status as a st...
#    3. Score: 0.7141 | Section 4. CLASSIFICATION OF STUDENTS   4.1 According to Admission Status   4.1.1 As Beginning Freshmen – Student admitted through the EARIST College ...
#    4. Score: 0.7026 | ## ADMISSION OF TRANSFEREES   Students may be admitted as transferees depending on the availability of slots provided that they meet all the academic ...
#    5. Score: 0.6940 | Returnee – a student who failed or left a particular year level during a given year....
#
# ======================================================================
# CATEGORY SUMMARY: Admissions
# ======================================================================
# Average Top Score: 0.7480
# Score Range: 0.6977 - 0.7919
#
# Confidence Distribution:
#    High (>0.7):   7/8 questions (87.5%)
#    Medium (0.5-0.7): 1/8 questions (12.5%)
#    Low (<0.5):    0/8 questions (0.0%)
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: Enrollment and Registration
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: Enrollment and Registration
# Total Questions: 8
# Model: nomic-embed-text-v1.5
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/8
# Q: How do I enroll in EARIST after being admitted?
# Expected Reference: Enrollment Procedures section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How do I enroll in EARIST after being admitted?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7170 | The number of applicants to be admitted depends on the resources of the Institute such as rooms and faculty. **Admission Qualifications of Local Stude...
#    2. Score: 0.6670 | Section 4. CLASSIFICATION OF STUDENTS   4.1 According to Admission Status   4.1.1 As Beginning Freshmen – Student admitted through the EARIST College ...
#    3. Score: 0.6667 | Admission – the act of admitting or allowing a student for enrollment....
#    4. Score: 0.6650 | Must be enrolled....
#    5. Score: 0.6556 | Failure to enroll......
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/8
# Q: What is the process for online registration of classes?
# Expected Reference: Registration Process section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What is the process for online registration of classes?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7614 | Registration – act or process of entering information of public records or documents in an educational institution....
#    2. Score: 0.7416 | REGISTRATION AND CROSS ENROLLMENT PROCEDURE   1.1 A student must be officially registered in order to receive credit for course work. The following sh...
#    3. Score: 0.6627 | Otherwise, the Certificate of Registration shall be considered prior to final Official Class List. 1.6 Cross enrollment in another school is allowed o...
#    4. Score: 0.6275 | Class – a series of meetings in which students are taught a particular subject or activity....
#    5. Score: 0.6267 | Copy of previous Certificate of Registration....
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/8
# Q: Can I still enroll if I missed the enrollment period?
# Expected Reference: Late Enrollment Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Can I still enroll if I missed the enrollment period?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7642 | Failure to enroll......
#    2. Score: 0.6966 | Must be enrolled....
#    3. Score: 0.6190 | ### 7.1 Old students, except those in the senior year, with failures corresponding to three (3) or more courses within a semester or five (5) cumulati...
#    4. Score: 0.6172 | REGISTRATION AND CROSS ENROLLMENT PROCEDURE   1.1 A student must be officially registered in order to receive credit for course work. The following sh...
#    5. Score: 0.6113 | 2009)   ## SECTION 5. ATTENDANCE   5.1 Students are required to attend all classes starting with the first meeting of every class. 5.2 Non-attendance ...
#
# ──────────────────────────────────────────────────────────────────────
# Question 4/8
# Q: How do I change or drop a subject after enrollment?
# Expected Reference: Adding and Dropping of Subjects section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How do I change or drop a subject after enrollment?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6948 | Dropped – withdraw of course/subject in a given period of time....
#    2. Score: 0.6896 | Conditions 1. Shall not drop any subject, shift courses, or stop from schooling without the approval of the Dean and the Registrar. 2....
#    3. Score: 0.6896 | Conditions 1. Shall not drop any subject, shift courses, or stop from schooling without the approval of the Dean and the Registrar. 2....
#    4. Score: 0.6856 | Must not have a failing grade and dropped subject in the previous semester....
#    5. Score: 0.6845 | ### Section 3. CHANGING CLASSES, SUBSTITUTION, AND DROPPING OF COURSES   3.1 The student may apply for a change of class (subject/schedule) by filing ...
#
# ──────────────────────────────────────────────────────────────────────
# Question 5/8
# Q: What should I do if my class schedule conflicts with another subject?
# Expected Reference: Schedule Adjustment Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What should I do if my class schedule conflicts with another subject?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6637 | Class – a series of meetings in which students are taught a particular subject or activity....
#    2. Score: 0.6455 | the first 10 minutes for a one-hour class. 5.4 A student is considered late or tardy if he/she arrives in class during the first 1/6 fraction of the s...
#    3. Score: 0.6417 | ### Section 3. CHANGING CLASSES, SUBSTITUTION, AND DROPPING OF COURSES   3.1 The student may apply for a change of class (subject/schedule) by filing ...
#    4. Score: 0.6257 | * 3.3.7.2. Students must refrain from using gadgets during class hours and during examinations. Section 4....
#    5. Score: 0.6187 | ACADEMIC LOAD   2.1 A student shall carry the regular load every semester as prescribed in the curricular program. 2.2 In no instance shall a student ...
#
# ──────────────────────────────────────────────────────────────────────
# Question 6/8
# Q: Where can I see the list of courses offered by EARIST?
# Expected Reference: Curriculum Offerings section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Where can I see the list of courses offered by EARIST?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6637 | The number of applicants to be admitted depends on the resources of the Institute such as rooms and faculty. **Admission Qualifications of Local Stude...
#    2. Score: 0.6325 | Pillo. Today, EARIST is: - Baccalaureate College - Comprehensive Teaching and Baccalaureate University LEVEL II - Graduate Capable HEIs LEVEL III (Res...
#    3. Score: 0.6140 | 74 - ANNEXES ..... 79     HISTORY OF EARIST   The Eulogio "Amang" Rodriguez Institute of Science and Technology (EARIST) was established after the lib...
#    4. Score: 0.6116 | ii - HISTORY OF EARIST ..... 1 - MISSION STATEMENTS   - Vision ........
#    5. Score: 0.5915 | The Use of EARIST Logo and trademarks Any individual, group or organization who wishes to use, attempt to imitate the EARIST Logo, or the use of a str...
#
# ──────────────────────────────────────────────────────────────────────
# Question 7/8
# Q: Can I enroll in overload subjects this semester?
# Expected Reference: Overload Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Can I enroll in overload subjects this semester?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7473 | ACADEMIC LOAD   2.1 A student shall carry the regular load every semester as prescribed in the curricular program. 2.2 In no instance shall a student ...
#    2. Score: 0.6357 | ### 12.2 Students who still have additional academic subject currently enrolled (i.e....
#    3. Score: 0.6228 | 2. Must carry a regular load of 18 units (except for graduating students)....
#    4. Score: 0.6209 | ### 7.1 Old students, except those in the senior year, with failures corresponding to three (3) or more courses within a semester or five (5) cumulati...
#    5. Score: 0.6203 | #### 4.2 According to Academic Load   ##### 4.2.1 Regular student – One who is registered for formal academic credits and who carries full load requir...
#
# ──────────────────────────────────────────────────────────────────────
# Question 8/8
# Q: What are the steps to enroll as a cross-enrollee from another school?
# Expected Reference: Cross-Enrollment section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What are the steps to enroll as a cross-enrollee from another school?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.8757 | Cross Enroll – to enroll from one school to another....
#    2. Score: 0.8282 | Otherwise, the Certificate of Registration shall be considered prior to final Official Class List. 1.6 Cross enrollment in another school is allowed o...
#    3. Score: 0.7376 | REGISTRATION AND CROSS ENROLLMENT PROCEDURE   1.1 A student must be officially registered in order to receive credit for course work. The following sh...
#    4. Score: 0.7077 | ## ADMISSION OF TRANSFEREES   Students may be admitted as transferees depending on the availability of slots provided that they meet all the academic ...
#    5. Score: 0.6885 | A person who desires to transfer to one school to another....
#
# ======================================================================
# CATEGORY SUMMARY: Enrollment and Registration
# ======================================================================
# Average Top Score: 0.7360
# Score Range: 0.6637 - 0.8757
#
# Confidence Distribution:
#    High (>0.7):   5/8 questions (62.5%)
#    Medium (0.5-0.7): 3/8 questions (37.5%)
#    Low (<0.5):    0/8 questions (0.0%)
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: Fees, Payments and Scholarships
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: Fees, Payments and Scholarships
# Total Questions: 6
# Model: nomic-embed-text-v1.5
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/6
# Q: How much is the tuition fee per unit at EARIST?
# Expected Reference: Tuition Fees section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How much is the tuition fee per unit at EARIST?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6653 | 10931 and its IRR and other applicable laws, rules, and regulations, the schedule of tuition fees and other charges that the Institute shall collect f...
#    2. Score: 0.6642 | Fee – an amount of money to be paid in a given semester....
#    3. Score: 0.6618 | The Institute charges a fixed amount per unit/hour. Laboratory fees may vary according to the laboratory subject. ##### 2.2 Payee Students   ###### 2....
#    4. Score: 0.6293 | The number of applicants to be admitted depends on the resources of the Institute such as rooms and faculty. **Admission Qualifications of Local Stude...
#    5. Score: 0.6170 | No. 10931 and its IRR and such applicable laws, rules, and regulations, the Board of Trustees shall fix the tuition fees and others necessary school c...
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/6
# Q: Are there any miscellaneous fees aside from tuition?
# Expected Reference: Miscellaneous Fees section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Are there any miscellaneous fees aside from tuition?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7402 | 10931 and its IRR and other applicable laws, rules, and regulations, the schedule of tuition fees and other charges that the Institute shall collect f...
#    2. Score: 0.7114 | Fee – an amount of money to be paid in a given semester....
#    3. Score: 0.7042 | The Institute charges a fixed amount per unit/hour. Laboratory fees may vary according to the laboratory subject. ##### 2.2 Payee Students   ###### 2....
#    4. Score: 0.7014 | Tuition – money that is paid to a school for the right to study in a school, college or university. Undergraduate – a student at a college or universi...
#    5. Score: 0.6919 | No. 10931 and its IRR and such applicable laws, rules, and regulations, the Board of Trustees shall fix the tuition fees and others necessary school c...
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/6
# Q: Where can I pay my tuition fees?
# Expected Reference: Payment Procedures section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Where can I pay my tuition fees?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7147 | No. 10931 and its IRR and such applicable laws, rules, and regulations, the Board of Trustees shall fix the tuition fees and others necessary school c...
#    2. Score: 0.7049 | Fee – an amount of money to be paid in a given semester....
#    3. Score: 0.6921 | Tuition – money that is paid to a school for the right to study in a school, college or university. Undergraduate – a student at a college or universi...
#    4. Score: 0.6869 | 10931 and its IRR and other applicable laws, rules, and regulations, the schedule of tuition fees and other charges that the Institute shall collect f...
#    5. Score: 0.6822 | The Institute charges a fixed amount per unit/hour. Laboratory fees may vary according to the laboratory subject. ##### 2.2 Payee Students   ###### 2....
#
# ──────────────────────────────────────────────────────────────────────
# Question 4/6
# Q: Does EARIST offer scholarships or financial aid programs?
# Expected Reference: Scholarships and Grants section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Does EARIST offer scholarships or financial aid programs?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6795 | SPECIAL GRANTS   The following agencies offer scholarships/grants: 1. CHED-Student Financial Assistance Programs (StuFAPs) Scholarship Grant 2....
#    2. Score: 0.6768 | A student who wishes to be re-admitted in a given semester/term Scholarship – is an assistance given by an individual or organization to defray their ...
#    3. Score: 0.6683 | EARIST Faculty Sponsored Scholarship 3....
#    4. Score: 0.6511 | #### SECTION 3. FACULTY AND EMPLOYEES UNION SCHOLARSHIP   This is given by the Institute to all qualified children of all employees enrolled in EARIST...
#    5. Score: 0.6486 | The number of applicants to be admitted depends on the resources of the Institute such as rooms and faculty. **Admission Qualifications of Local Stude...
#
# ──────────────────────────────────────────────────────────────────────
# Question 5/6
# Q: How can I apply for an academic scholarship?
# Expected Reference: Academic Scholarship Requirements section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How can I apply for an academic scholarship?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7066 | Shall apply for renewal of the scholarship at the end of each semester with the prescribed attachment. 4....
#    2. Score: 0.7066 | Shall apply for renewal of the scholarship at the end of each semester with the prescribed attachment. 4....
#    3. Score: 0.6857 | A student who wishes to be re-admitted in a given semester/term Scholarship – is an assistance given by an individual or organization to defray their ...
#    4. Score: 0.6754 | Requirements 1. Duly accomplished Scholarship Form from the Office of Student Affairs (SAS) and signed by the respective personnel concerned. 2....
#    5. Score: 0.6585 | Requirements 1. Duly accomplished Scholarship Form from the Office of Student Affairs and Services (APPENDIX J, Page 90) and signed by the respective ...
#
# ──────────────────────────────────────────────────────────────────────
# Question 6/6
# Q: What happens if I fail to pay my fees on time?
# Expected Reference: Late Payment Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What happens if I fail to pay my fees on time?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6184 | Refund – to return certain amount of fees within a prescribed period....
#    2. Score: 0.5973 | Paying Students – overstaying students who are not able to finish their program on the prescribed period and is considered ineligible to avail the fre...
#    3. Score: 0.5667 | Failure to enroll......
#    4. Score: 0.5482 | Fee – an amount of money to be paid in a given semester....
#    5. Score: 0.5429 | * b. Obtain a failing grade during term......
#
# ======================================================================
# CATEGORY SUMMARY: Fees, Payments and Scholarships
# ======================================================================
# Average Top Score: 0.6875
# Score Range: 0.6184 - 0.7402
#
# Confidence Distribution:
#    High (>0.7):   3/6 questions (50.0%)
#    Medium (0.5-0.7): 3/6 questions (50.0%)
#    Low (<0.5):    0/6 questions (0.0%)
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: Academic Policies and Grading
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: Academic Policies and Grading
# Total Questions: 8
# Model: nomic-embed-text-v1.5
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/8
# Q: How is the grading system computed in EARIST?
# Expected Reference: Grading System section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How is the grading system computed in EARIST?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7002 | ## SECTION 6. GRADING SYSTEM   6.1 The students’ academic performance shall be graded in accordance with the following numerical system:   Grade: 1.00...
#    2. Score: 0.6319 | The number of applicants to be admitted depends on the resources of the Institute such as rooms and faculty. **Admission Qualifications of Local Stude...
#    3. Score: 0.6268 | Rectification of grades – to correct wrong entries of data....
#    4. Score: 0.6190 | Pillo. Today, EARIST is: - Baccalaureate College - Comprehensive Teaching and Baccalaureate University LEVEL II - Graduate Capable HEIs LEVEL III (Res...
#    5. Score: 0.6145 | Grade – a mark given to a student to his/her academic performance. Graduate – is a student who successfully completes a level of education. Has earned...
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/8
# Q: What is the passing grade for college students?
# Expected Reference: Academic Standards section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What is the passing grade for college students?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7470 | Failed Grade – a grade given to a student who does not qualify for passing a subject....
#    2. Score: 0.7300 | Incomplete Grade – a temporarily grade given to a student who may qualify for passing but has not complied with certain requirements of the subject. I...
#    3. Score: 0.7249 | Grade – a mark given to a student to his/her academic performance. Graduate – is a student who successfully completes a level of education. Has earned...
#    4. Score: 0.7006 | ## SECTION 10. GRADUATION WITH HONORS   ### 10.1 The College Dean/Campus Administrator, in close coordination with the College Registrar, shall recomm...
#    5. Score: 0.6831 | Obtain a failing grade......
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/8
# Q: Can I request for grade reconsideration if I believe there was an error?
# Expected Reference: Grade Re-evaluation Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Can I request for grade reconsideration if I believe there was an error?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7763 | 6.8 Request for change of grade   A request for a change of grade may be teacher/student-initiated if the teacher inadvertently made a mistake in the ...
#    2. Score: 0.7614 | Rectification of grades – to correct wrong entries of data....
#    3. Score: 0.6895 | Copy for the petitioner and the concerned student will be provided through the Office of the Dean. ##### 6.8.8 Petition after ten (10) days from the d...
#    4. Score: 0.6744 | Obtain a failing grade......
#    5. Score: 0.6474 | Failed Grade – a grade given to a student who does not qualify for passing a subject....
#
# ──────────────────────────────────────────────────────────────────────
# Question 4/8
# Q: What is the policy on academic probation or retention?
# Expected Reference: Academic Retention Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What is the policy on academic probation or retention?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7351 | 7.2. #### 11.2.3 Probation shall be lifted once a student has passed all his/her subjects in the following semester. #### 11.2.4 Students who have bee...
#    2. Score: 0.7045 | ### 7.2 A student with a failing grade shall be given a warning by the College Dean/Campus Administrator and referred to the Counseling and Testing Of...
#    3. Score: 0.7024 | ARTICLE II ACADEMIC POLICIES   Section 1....
#    4. Score: 0.6893 | ## SECTION 11. SCHOLASTIC DELINQUENCY   ### 11.1 Warning   #### 11.1.1 Any student who at the end of the semester obtains final grades of “5.00” in th...
#    5. Score: 0.6763 | TENURE, LEAVE OF ABSENCE, AND HONORABLE DISMISSAL   ### 8.1 Tenure   #### 8.1.1 For Regular Students: A regular student should finish the academic pro...
#
# ──────────────────────────────────────────────────────────────────────
# Question 5/8
# Q: How do I qualify for the Dean’s List?
# Expected Reference: Honors and Awards section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How do I qualify for the Dean’s List?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7135 | Admission Recommendation from the College Dean....
#    2. Score: 0.6580 | Admission Requirements   #### 1. Freshmen 1.1 Form 138 (Senior and High School Report Card)   1.2 Certificate of Good Moral Character with school seal...
#    3. Score: 0.6466 | Dean – a person either appointed or designated in charge of the colleges in an educational institution....
#    4. Score: 0.6464 | Section 4. CLASSIFICATION OF STUDENTS   4.1 According to Admission Status   4.1.1 As Beginning Freshmen – Student admitted through the EARIST College ...
#    5. Score: 0.6341 | The number of applicants to be admitted depends on the resources of the Institute such as rooms and faculty. **Admission Qualifications of Local Stude...
#
# ──────────────────────────────────────────────────────────────────────
# Question 6/8
# Q: What should I do if I failed a subject?
# Expected Reference: Repetition of Subjects section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What should I do if I failed a subject?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7357 | Must not have a failing grade and dropped subject in the previous semester....
#    2. Score: 0.7328 | Must not have a failing grade or dropped subject in the previous semester. ##### b....
#    3. Score: 0.7264 | * b. Obtain a failing grade during term......
#    4. Score: 0.7249 | Failed Grade – a grade given to a student who does not qualify for passing a subject....
#    5. Score: 0.7211 | Obtain a failing grade......
#
# ──────────────────────────────────────────────────────────────────────
# Question 7/8
# Q: Can I take make-up exams for missed tests?
# Expected Reference: Make-up Examination Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Can I take make-up exams for missed tests?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.5550 | Female students are not allowed to have colored highlights in their hair....
#    2. Score: 0.5514 | the first 10 minutes for a one-hour class. 5.4 A student is considered late or tardy if he/she arrives in class during the first 1/6 fraction of the s...
#    3. Score: 0.5507 | Final Examination – an examination given before the end of school term. Form – a printed material to be filled up by anyone in the institution....
#    4. Score: 0.5477 | Must not have a failing grade or dropped subject in the previous semester. ##### b....
#    5. Score: 0.5472 | * 3.3.7.2. Students must refrain from using gadgets during class hours and during examinations. Section 4....
#
# ──────────────────────────────────────────────────────────────────────
# Question 8/8
# Q: What is the policy on incomplete grades?
# Expected Reference: Incomplete Grade section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What is the policy on incomplete grades?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7807 | Incomplete Grade – a temporarily grade given to a student who may qualify for passing but has not complied with certain requirements of the subject. I...
#    2. Score: 0.7730 | 6.3 An Incomplete "INC" is a temporary grade that may be given at the instructor's discretion to a student when illness, necessary absence, or other r...
#    3. Score: 0.7016 | 006 (APPENDIX A, Page 76). The same form must be completed within the next two (2) semesters, otherwise, the grade automatically becomes "5.0";   ####...
#    4. Score: 0.6994 | Failed Grade – a grade given to a student who does not qualify for passing a subject....
#    5. Score: 0.6991 | Likewise, the faculty member drops the student from the roll for having exceeded the allowable number of absences. 6.6 The No Credit (NC) grade shall ...
#
# ======================================================================
# CATEGORY SUMMARY: Academic Policies and Grading
# ======================================================================
# Average Top Score: 0.7179
# Score Range: 0.5550 - 0.7807
#
# Confidence Distribution:
#    High (>0.7):   7/8 questions (87.5%)
#    Medium (0.5-0.7): 1/8 questions (12.5%)
#    Low (<0.5):    0/8 questions (0.0%)
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: Attendance and Conduct
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: Attendance and Conduct
# Total Questions: 6
# Model: nomic-embed-text-v1.5
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/6
# Q: What happens if I exceed the number of absences allowed?
# Expected Reference: Attendance Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What happens if I exceed the number of absences allowed?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6544 | Paying Students – overstaying students who are not able to finish their program on the prescribed period and is considered ineligible to avail the fre...
#    2. Score: 0.6523 | 2009)   ## SECTION 5. ATTENDANCE   5.1 Students are required to attend all classes starting with the first meeting of every class. 5.2 Non-attendance ...
#    3. Score: 0.6346 | #### 8.1.3 For Working Student: Working students may finish the academic program within a period equivalent to one and one-half (11/2) times the norma...
#    4. Score: 0.6260 | the first 10 minutes for a one-hour class. 5.4 A student is considered late or tardy if he/she arrives in class during the first 1/6 fraction of the s...
#    5. Score: 0.6207 | Likewise, the faculty member drops the student from the roll for having exceeded the allowable number of absences. 6.6 The No Credit (NC) grade shall ...
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/6
# Q: Are students required to wear uniforms in EARIST?
# Expected Reference: Student Uniform Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Are students required to wear uniforms in EARIST?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7448 | CONDUCT IN SCHOOL 3.1. Wearing of Prescribed Uniform * Every student shall wear the prescribed uniform on Mondays, Wednesdays, and Fridays. * Students...
#    2. Score: 0.6910 | Third and succeeding loss of ID in the entire stay at EARIST                 * 4.1.2.16. Third and succeeding non-wearing of official ID              ...
#    3. Score: 0.6901 | Students shall be allowed to wear organizational shirts if the recognized organization is conducting an activity approved by the Institute. 3.2....
#    4. Score: 0.6789 | Peace and Order           * 3.3.7.1. Students are prohibited from creating unnecessary noise and loitering during class hours....
#    5. Score: 0.6786 | * 4.11.1 Guidelines on Selection of Student-Athletes                                                                                                  ...
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/6
# Q: What are the disciplinary actions for students who violate school rules?
# Expected Reference: Code of Discipline section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What are the disciplinary actions for students who violate school rules?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7748 | STUDENT DISCIPLINE 4.1. Types of Offenses 4.1.1. Major Offenses             * 4.1.1.1. Gross misconduct              * 4.1.1.2. Possession of deadly w...
#    2. Score: 0.7692 | Instigating, leading or participating in any concerted activity leading to stoppage of classes or preventing students/faculty members/administrative p...
#    3. Score: 0.7636 | 29   - Section 4 – Student Discipline     - 4.1 Acts Constituting Major Offense ..... 31     - 4.2 Acts Constituting Minor Offense ..... 35 - ARTICLE ...
#    4. Score: 0.7497 | Suspension – the acts of forcing someone to leave schooling due to an offense committed in an educational institution....
#    5. Score: 0.7325 | Defamation, libel, or slander of any student or school official              * 4.1.1.28. Violation of existing laws and ordinances, including Executiv...
#
# ──────────────────────────────────────────────────────────────────────
# Question 4/6
# Q: Can I excuse my absences due to sickness?
# Expected Reference: Excused Absences Policy section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Can I excuse my absences due to sickness?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6636 | the first 10 minutes for a one-hour class. 5.4 A student is considered late or tardy if he/she arrives in class during the first 1/6 fraction of the s...
#    2. Score: 0.6171 | For Re-Admission of students who would like to continue their program after taking the leave of absence, the following are needed:   1....
#    3. Score: 0.5893 | 2009)   ## SECTION 5. ATTENDANCE   5.1 Students are required to attend all classes starting with the first meeting of every class. 5.2 Non-attendance ...
#    4. Score: 0.5812 | #### 8.1.3 For Working Student: Working students may finish the academic program within a period equivalent to one and one-half (11/2) times the norma...
#    5. Score: 0.5712 | #### 8.2.9 Upon his/her return, a student is covered by the curriculum currently in effect. #### 8.2.10 In case a student loses his/her status as a st...
#
# ──────────────────────────────────────────────────────────────────────
# Question 5/6
# Q: Are there rules about student behavior inside the classroom?
# Expected Reference: Classroom Conduct section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Are there rules about student behavior inside the classroom?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7521 | Peace and Order           * 3.3.7.1. Students are prohibited from creating unnecessary noise and loitering during class hours....
#    2. Score: 0.7042 | * 3.3.7.2. Students must refrain from using gadgets during class hours and during examinations. Section 4....
#    3. Score: 0.7007 | CONDUCT IN SCHOOL 3.1. Wearing of Prescribed Uniform * Every student shall wear the prescribed uniform on Mondays, Wednesdays, and Fridays. * Students...
#    4. Score: 0.6938 | Fighting inside or outside the school premises              * 4.1.1.5....
#    5. Score: 0.6921 | Class – a series of meetings in which students are taught a particular subject or activity....
#
# ──────────────────────────────────────────────────────────────────────
# Question 6/6
# Q: Who handles disciplinary cases in EARIST?
# Expected Reference: Disciplinary Committee section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Who handles disciplinary cases in EARIST?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6069 | Suspension – the acts of forcing someone to leave schooling due to an offense committed in an educational institution....
#    2. Score: 0.6054 | STUDENT DISCIPLINE 4.1. Types of Offenses 4.1.1. Major Offenses             * 4.1.1.1. Gross misconduct              * 4.1.1.2. Possession of deadly w...
#    3. Score: 0.6016 | Caillao in 2006 to 2010. The 7th and current President of EARIST is Dr. Editha V....
#    4. Score: 0.5918 | Pillo. Today, EARIST is: - Baccalaureate College - Comprehensive Teaching and Baccalaureate University LEVEL II - Graduate Capable HEIs LEVEL III (Res...
#    5. Score: 0.5884 | ARTICLE VI – CODE OF CONDUCT AND DISCIPLINE Section 1. EARIST CODE OF CONDUCT AND DISCIPLINE  To warrant an environment conducive to the pursuit of ac...
#
# ======================================================================
# CATEGORY SUMMARY: Attendance and Conduct
# ======================================================================
# Average Top Score: 0.6994
# Score Range: 0.6069 - 0.7748
#
# Confidence Distribution:
#    High (>0.7):   3/6 questions (50.0%)
#    Medium (0.5-0.7): 3/6 questions (50.0%)
#    Low (<0.5):    0/6 questions (0.0%)
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: Student Services and Organizations
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: Student Services and Organizations
# Total Questions: 6
# Model: nomic-embed-text-v1.5
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/6
# ...
#    5. Score: 0.6186 | Failure to submit will prohibit the holding of future activities. Section 8 – Off-campus/Overnight Activities 8.1 For the Institute to authorize an of...
#
# ======================================================================
# CATEGORY SUMMARY: Student Services and Organizations
# ======================================================================
# Average Top Score: 0.6812
# Score Range: 0.6547 - 0.7308
#
# Confidence Distribution:
#    High (>0.7):   2/6 questions (33.3%)
#    Medium (0.5-0.7): 4/6 questions (66.7%)
#    Low (<0.5):    0/6 questions (0.0%)
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: Graduation and Academic Completion
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: Graduation and Academic Completion
# Total Questions: 5
# Model: nomic-embed-text-v1.5
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/5
# Q: What are the requirements to graduate from EARIST?
# Expected Reference: Graduation Requirements section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What are the requirements to graduate from EARIST?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7381 | The number of applicants to be admitted depends on the resources of the Institute such as rooms and faculty. **Admission Qualifications of Local Stude...
#    2. Score: 0.7304 | GRADUATION REQUIREMENTS   ### 9.1 A candidate for graduation shall file an application for graduation to the Registrar's Office. ### 9.2 A student sha...
#    3. Score: 0.7143 | Pillo. Today, EARIST is: - Baccalaureate College - Comprehensive Teaching and Baccalaureate University LEVEL II - Graduate Capable HEIs LEVEL III (Res...
#    4. Score: 0.7050 | ### 10.2.2 Every candidate for graduation with honors must:   #### 10.2.4.1 Have carried the normal load prescribed in his/her curriculum (Art. II Sec...
#    5. Score: 0.7034 | On-The-Job Training/Practicum/Internship/Immersion – a requirement for graduating student is 76 prescribed in the curricular of the school....
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/5
# Q: When are graduation applications usually submitted?
# Expected Reference: Application for Graduation section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'When are graduation applications usually submitted?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7354 | GRADUATION REQUIREMENTS   ### 9.1 A candidate for graduation shall file an application for graduation to the Registrar's Office. ### 9.2 A student sha...
#    2. Score: 0.6710 | ### 10.2.2 Every candidate for graduation with honors must:   #### 10.2.4.1 Have carried the normal load prescribed in his/her curriculum (Art. II Sec...
#    3. Score: 0.6563 | (2 copies)  3.5 The deadline for submission of an application for recognition shall be strictly enforced....
#    4. Score: 0.6545 | ## SECTION 10. GRADUATION WITH HONORS   ### 10.1 The College Dean/Campus Administrator, in close coordination with the College Registrar, shall recomm...
#    5. Score: 0.6530 | * 1.4.4 Student organizations who were granted a permit to operate shall submit at the end of the year a Financial Status report... * 1.4.5 Be used as...
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/5
# Q: Can I join the graduation ceremony if I still have incomplete grades?
# Expected Reference: Graduation Eligibility section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Can I join the graduation ceremony if I still have incomplete grades?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6966 | 6.3 An Incomplete "INC" is a temporary grade that may be given at the instructor's discretion to a student when illness, necessary absence, or other r...
#    2. Score: 0.6909 | Incomplete Grade – a temporarily grade given to a student who may qualify for passing but has not complied with certain requirements of the subject. I...
#    3. Score: 0.6880 | ### 10.2.2 Every candidate for graduation with honors must:   #### 10.2.4.1 Have carried the normal load prescribed in his/her curriculum (Art. II Sec...
#    4. Score: 0.6843 | GRADUATION REQUIREMENTS   ### 9.1 A candidate for graduation shall file an application for graduation to the Registrar's Office. ### 9.2 A student sha...
#    5. Score: 0.6745 | Likewise, the faculty member drops the student from the roll for having exceeded the allowable number of absences. 6.6 The No Credit (NC) grade shall ...
#
# ──────────────────────────────────────────────────────────────────────
# Question 4/5
# Q: How can I request for my diploma or transcript after graduation?
# Expected Reference: Post-Graduation Document Request section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'How can I request for my diploma or transcript after graduation?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.7290 | GRADUATION REQUIREMENTS   ### 9.1 A candidate for graduation shall file an application for graduation to the Registrar's Office. ### 9.2 A student sha...
#    2. Score: 0.6445 | The subject(s) taken from the previous school may be credited upon submission of Official Transcript of Records, to be evaluated by the Department Cha...
#    3. Score: 0.6368 | ### 10.2.2 Every candidate for graduation with honors must:   #### 10.2.4.1 Have carried the normal load prescribed in his/her curriculum (Art. II Sec...
#    4. Score: 0.6347 | Admission Requirements   #### 1. Freshmen 1.1 Form 138 (Senior and High School Report Card)   1.2 Certificate of Good Moral Character with school seal...
#    5. Score: 0.6187 | On-The-Job Training/Practicum/Internship/Immersion – a requirement for graduating student is 76 prescribed in the curricular of the school....
#
# ──────────────────────────────────────────────────────────────────────
# Question 5/5
# Q: Does EARIST hold recognition ceremonies for honor students?
# Expected Reference: Honors and Recognition section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Does EARIST hold recognition ceremonies for honor students?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6667 | Certificate of Recognition for winners at local, regional, national and international competitions. * 4.11.3 Duties and Responsibilities of Student-At...
#    2. Score: 0.6626 | Pillo. Today, EARIST is: - Baccalaureate College - Comprehensive Teaching and Baccalaureate University LEVEL II - Graduate Capable HEIs LEVEL III (Res...
#    3. Score: 0.6581 | The number of applicants to be admitted depends on the resources of the Institute such as rooms and faculty. **Admission Qualifications of Local Stude...
#    4. Score: 0.6449 | Students are expected to show respect to all members of the EARIST academic community and use school property with care. * 3.3.7....
#    5. Score: 0.6383 | * 2.5.2 The EARISTians shall be the official yearbook... Section 3 – The Learning and Sharing Center The Institute has multi-media facilities to cater...
#
# ======================================================================
# CATEGORY SUMMARY: Graduation and Academic Completion
# ======================================================================
# Average Top Score: 0.7132
# Score Range: 0.6667 - 0.7381
#
# Confidence Distribution:
#    High (>0.7):   3/5 questions (60.0%)
#    Medium (0.5-0.7): 2/5 questions (40.0%)
#    Low (<0.5):    0/5 questions (0.0%)
#
#
# ██████████████████████████████████████████████████████████████████████
# CATEGORY: General and Miscellaneous Information
# ██████████████████████████████████████████████████████████████████████
#
# ======================================================================
# Testing Category: General and Miscellaneous Information
# Total Questions: 3
# Model: nomic-embed-text-v1.5
# Retrieving top 5 chunks per question
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# Question 1/3
# Q: Where is the EARIST main campus located?
# Expected Reference: Institutional Information section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Where is the EARIST main campus located?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6568 | Pillo. Today, EARIST is: - Baccalaureate College - Comprehensive Teaching and Baccalaureate University LEVEL II - Graduate Capable HEIs LEVEL III (Res...
#    2. Score: 0.6450 | NUDAS – 1972 – 1982 (College President) 1978 – 1982 (SUC President)   - Establishment of EARIST – GASAT (now EARIST – Cavite Campus – ECC) through boa...
#    3. Score: 0.6371 | The number of applicants to be admitted depends on the resources of the Institute such as rooms and faculty. **Admission Qualifications of Local Stude...
#    4. Score: 0.6346 | 74 - ANNEXES ..... 79     HISTORY OF EARIST   The Eulogio "Amang" Rodriguez Institute of Science and Technology (EARIST) was established after the lib...
#    5. Score: 0.6118 | Caillao in 2006 to 2010. The 7th and current President of EARIST is Dr. Editha V....
#
# ──────────────────────────────────────────────────────────────────────
# Question 2/3
# Q: Who is the current president of EARIST?
# Expected Reference: Administration section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'Who is the current president of EARIST?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.8181 | Caillao in 2006 to 2010. The 7th and current President of EARIST is Dr. Editha V....
#    2. Score: 0.7065 | Pillo. Today, EARIST is: - Baccalaureate College - Comprehensive Teaching and Baccalaureate University LEVEL II - Graduate Capable HEIs LEVEL III (Res...
#    3. Score: 0.6710 | ROGELIO T. MAMARADLO President, EARIST Alumni Association, Inc. Member HON....
#    4. Score: 0.6648 | EARIST, Forever!...
#    5. Score: 0.6535 | ii - HISTORY OF EARIST ..... 1 - MISSION STATEMENTS   - Vision ........
#
# ──────────────────────────────────────────────────────────────────────
# Question 3/3
# Q: What are the official communication channels of EARIST for students?
# Expected Reference: Official Communication Channels section
# ──────────────────────────────────────────────────────────────────────
#
# Searching for: 'What are the official communication channels of EARIST for students?'
# Model: nomic-embed-text-v1.5
# ==================================================
#
# Top 5 Results:
#    1. Score: 0.6809 | * 2.5.2 The EARISTians shall be the official yearbook... Section 3 – The Learning and Sharing Center The Institute has multi-media facilities to cater...
#    2. Score: 0.6653 | The number of applicants to be admitted depends on the resources of the Institute such as rooms and faculty. **Admission Qualifications of Local Stude...
#    3. Score: 0.6394 | Pillo. Today, EARIST is: - Baccalaureate College - Comprehensive Teaching and Baccalaureate University LEVEL II - Graduate Capable HEIs LEVEL III (Res...
#    4. Score: 0.6304 | Also, will promote the exercise of ecumenism and unity of the faithful on the campus. ARTICLE XIII GUIDELINES ON CULTURAL PROGRAMS / ACTIVITIES   Sect...
#    5. Score: 0.6300 | The Use of EARIST Logo and trademarks Any individual, group or organization who wishes to use, attempt to imitate the EARIST Logo, or the use of a str...
#
# ======================================================================
# CATEGORY SUMMARY: General and Miscellaneous Information
# ======================================================================
# Average Top Score: 0.7186
# Score Range: 0.6568 - 0.8181
#
# Confidence Distribution:
#    High (>0.7):   1/3 questions (33.3%)
#    Medium (0.5-0.7): 2/3 questions (66.7%)
#    Low (<0.5):    0/3 questions (0.0%)
#
#
# ======================================================================
# OVERALL PERFORMANCE SUMMARY
# ======================================================================
#
# Admissions:
#    Questions: 8
#    Avg Score: 0.7480
#    Range: 0.6977 - 0.7919
#
# Enrollment and Registration:
#    Questions: 8
#    Avg Score: 0.7360
#    Range: 0.6637 - 0.8757
#
# Fees, Payments and Scholarships:
#    Questions: 6
#    Avg Score: 0.6875
#    Range: 0.6184 - 0.7402
#
# Academic Policies and Grading:
#    Questions: 8
#    Avg Score: 0.7179
#    Range: 0.5550 - 0.7807
#
# Attendance and Conduct:
#    Questions: 6
#    Avg Score: 0.6994
#    Range: 0.6069 - 0.7748
#
# Student Services and Organizations:
#    Questions: 6
#    Avg Score: 0.6812
#    Range: 0.6547 - 0.7308
#
# Graduation and Academic Completion:
#    Questions: 5
#    Avg Score: 0.7132
#    Range: 0.6667 - 0.7381
#
# General and Miscellaneous Information:
#    Questions: 3
#    Avg Score: 0.7186
#    Range: 0.6568 - 0.8181
#
# ──────────────────────────────────────────────────────────────────────
# GLOBAL STATISTICS:
#    Total Questions Tested: 50
#    Overall Average Score: 0.7149
#    Median Score: 0.7159
#    Std Deviation: 0.0564
#
#    Overall Confidence Distribution:
#       High (>0.7):   31/50 (62.0%)
#       Medium (0.5-0.7): 19/50 (38.0%)
#       Low (<0.5):    0/50 (0.0%)
# [SUCCESS] Saved 19 experiments to experiment_results.json
#
# ======================================================================
# EXPERIMENT COMPLETE: P60-nomic-embed-text-v1.5
# ======================================================================
# Overall Avg Score: 0.7149
# High Confidence: 62.0%
# Execution Time: 0.8s
# ======================================================================
# {'experiment_name': 'P60-nomic-embed-text-v1.5',
#  'timestamp': '2025-11-11 21:07:16',
#  'chunking_config': {'strategy': 'semantic',
#   'percentile': 60,
#   'buffer_size': 1},
#  'embedding_model': 'nomic-ai/nomic-embed-text-v1.5',
#  'top_k': 5,
#  'metrics': {'overall_avg_score': 0.71490274310112,
#   'overall_median_score': 0.7158709466457367,
#   'overall_std': 0.05638311499763657,
#   'min_score': 0.5549683570861816,
#   'max_score': 0.8756574392318726,
#   'high_confidence_pct': 62.0,
#   'medium_confidence_pct': 38.0,
#   'low_confidence_pct': 0.0,
#   'total_questions': 50,
#   'execution_time_seconds': 0.7644665241241455},
#  'category_metrics': {'Admissions': {'avg_score': 0.7479851245880127,
#    'min_score': 0.6976797580718994,
#    'max_score': 0.7918667793273926,
#    'num_questions': 8},
#   'Enrollment and Registration': {'avg_score': 0.735972598195076,
#    'min_score': 0.6636938452720642,
#    'max_score': 0.8756574392318726,
#    'num_questions': 8},
#   'Fees, Payments and Scholarships': {'avg_score': 0.6874581575393677,
#    'min_score': 0.61841881275177,
#    'max_score': 0.7401540875434875,
#    'num_questions': 6},
#   'Academic Policies and Grading': {'avg_score': 0.7179273813962936,
#    'min_score': 0.5549683570861816,
#    'max_score': 0.780748724937439,
#    'num_questions': 8},
#   'Attendance and Conduct': {'avg_score': 0.6994352539380392,
#    'min_score': 0.6068932414054871,
#    'max_score': 0.7748414278030396,
#    'num_questions': 6},
#   'Student Services and Organizations': {'avg_score': 0.6811598837375641,
#    'min_score': 0.6547155380249023,
#    'max_score': 0.7307593822479248,
#    'num_questions': 6},
#   'Graduation and Academic Completion': {'avg_score': 0.7131721496582031,
#    'min_score': 0.6667307019233704,
#    'max_score': 0.7381272315979004,
#    'num_questions': 5},
#   'General and Miscellaneous Information': {'avg_score': 0.7186252673467001,
#    'min_score': 0.6568078398704529,
#    'max_score': 0.8181365728378296,
#    'num_questions': 3}}}

# %%
# ========================================
# VIEW RESULTS & COMPARISON
# ========================================

# Show comparison dashboard
compare_experiments()

# Show visual comparison
plot_experiment_comparison()
# Out:
# ================================================================================
# EXPERIMENT COMPARISON DASHBOARD
# ================================================================================
# Total Experiments: 18
#
# Rank   Experiment Name                     Avg Score    High Conf %  Time (s)
# ────────────────────────────────────────────────────────────────────────────────
# 1      P80-nomic-embed-text-v1.5           0.6998       50.0         0.6
# 2      P50-multi-qa-mpnet-base-dot-v1      0.6408       22.0         0.6
# 3      P50-multi-qa-mpnet-base-dot-v1      0.6408       22.0         1.6
# 4      P50-multi-qa-mpnet-base-dot-v1      0.6341       12.0         1.6
# 5      P45-multi-qa-mpnet-base-dot-v1      0.6318       12.0         0.6
# 6      P45-multi-qa-mpnet-base-dot-v1      0.6318       12.0         0.6
# 7      P60-multi-qa-mpnet-base-dot-v1      0.6259       16.0         1.6
# 8      P65-multi-qa-mpnet-base-dot-v1      0.6230       16.0         1.6
# 9      P50-multi-qa-mpnet-base-dot-v1      0.6226       8.0          1.7
# 10     P70-multi-qa-mpnet-base-dot-v1      0.6213       14.0         1.6
# 11     P50-multi-qa-mpnet-base-dot-v1      0.6189       12.0         0.6
# 12     P75-multi-qa-mpnet-base-dot-v1      0.6122       14.0         1.6
# 13     P70-multi-qa-mpnet-base-dot-v1      0.6093       10.0         0.7
# 14     P65-all-mpnet-base-v2               0.5826       8.0          1.5
# 15     P70-all-mpnet-base-v2               0.5790       8.0          1.6
# 16     P75-all-mpnet-base-v2               0.5693       8.0          1.5
# 17     CustomChunk + multi-qa-mpnet-base   0.5617       2.0          0.6
# 18     P80-all-mpnet-base-v2               0.5588       6.0          1.6
#
# ================================================================================
# 🏆 BEST EXPERIMENT: P80-nomic-embed-text-v1.5
# ================================================================================
#
# Configuration:
#    Chunking: {'strategy': 'semantic', 'percentile': 80, 'buffer_size': 1}
#    Embedding Model: nomic-ai/nomic-embed-text-v1.5
#    Top-K: 5
#
# Performance Metrics:
#    Average Score: 0.6998
#    Median Score: 0.6989
#    Std Deviation: 0.0544
#    Score Range: 0.5564 - 0.8181
#
# Confidence Distribution:
#    High (>0.7):   50.0%
#    Medium (0.5-0.7): 50.0%
#    Low (<0.5):    0.0%
#
# Category Performance:
#    Admissions: 0.7450
#    Enrollment and Registration: 0.6988
#    Fees, Payments and Scholarships: 0.6819
#    Academic Policies and Grading: 0.6997
#    Attendance and Conduct: 0.6947
#    Student Services and Organizations: 0.6679
#    Graduation and Academic Completion: 0.6830
#    General and Miscellaneous Information: 0.7196
#
# 📈 Improvement over worst: 25.2%
#
# ================================================================================
#
#
# ======================================================================
# EXPERIMENT PERFORMANCE VISUALIZATION
# ======================================================================
#
# Average Score Comparison:
# ----------------------------------------------------------------------
# P80-nomic-embed-text-v1.5      0.6998 ████████████████████████████████████████
# P50-multi-qa-mpnet-base-dot-v1 0.6408 ████████████████████████████████████
# P50-multi-qa-mpnet-base-dot-v1 0.6408 ████████████████████████████████████
# P50-multi-qa-mpnet-base-dot-v1 0.6341 ████████████████████████████████████
# P45-multi-qa-mpnet-base-dot-v1 0.6318 ████████████████████████████████████
# P45-multi-qa-mpnet-base-dot-v1 0.6318 ████████████████████████████████████
# P60-multi-qa-mpnet-base-dot-v1 0.6259 ███████████████████████████████████
# P65-multi-qa-mpnet-base-dot-v1 0.6230 ███████████████████████████████████
# P50-multi-qa-mpnet-base-dot-v1 0.6226 ███████████████████████████████████
# P70-multi-qa-mpnet-base-dot-v1 0.6213 ███████████████████████████████████
# P50-multi-qa-mpnet-base-dot-v1 0.6189 ███████████████████████████████████
# P75-multi-qa-mpnet-base-dot-v1 0.6122 ██████████████████████████████████
# P70-multi-qa-mpnet-base-dot-v1 0.6093 ██████████████████████████████████
# P65-all-mpnet-base-v2          0.5826 █████████████████████████████████
# P70-all-mpnet-base-v2          0.5790 █████████████████████████████████
# P75-all-mpnet-base-v2          0.5693 ████████████████████████████████
# CustomChunk + multi-qa-mpnet-b 0.5617 ████████████████████████████████
# P80-all-mpnet-base-v2          0.5588 ███████████████████████████████
#
# High Confidence (>0.7) Percentage:
# ----------------------------------------------------------------------
# P80-nomic-embed-text-v1.5        50.0% ████████████████████████████████████████
# P50-multi-qa-mpnet-base-dot-v1   22.0% █████████████████
# P50-multi-qa-mpnet-base-dot-v1   22.0% █████████████████
# P50-multi-qa-mpnet-base-dot-v1   12.0% █████████
# P45-multi-qa-mpnet-base-dot-v1   12.0% █████████
# P45-multi-qa-mpnet-base-dot-v1   12.0% █████████
# P60-multi-qa-mpnet-base-dot-v1   16.0% ████████████
# P65-multi-qa-mpnet-base-dot-v1   16.0% ████████████
# P50-multi-qa-mpnet-base-dot-v1    8.0% ██████
# P70-multi-qa-mpnet-base-dot-v1   14.0% ███████████
# P50-multi-qa-mpnet-base-dot-v1   12.0% █████████
# P75-multi-qa-mpnet-base-dot-v1   14.0% ███████████
# P70-multi-qa-mpnet-base-dot-v1   10.0% ████████
# P65-all-mpnet-base-v2             8.0% ██████
# P70-all-mpnet-base-v2             8.0% ██████
# P75-all-mpnet-base-v2             8.0% ██████
# CustomChunk + multi-qa-mpnet-b    2.0% █
# P80-all-mpnet-base-v2             6.0% ████
#
# ======================================================================
