# %%
import json
from types import SimpleNamespace

# Load pre-processed chunks from JSON
with open('Dataset/Chunks.json', 'r', encoding='utf-8') as f:
    chunks_data = json.load(f)

# Convert to objects that mimic LangChain's Document structure for compatibility
chunks = []
for item in chunks_data:
    # We use SimpleNamespace to create a simple object with attributes
    chunk_obj = SimpleNamespace(
        page_content=item['content'],
        metadata={
            'chunk_id': item['chunk_id'],
            **item['metadata']  # Unpack the existing metadata dictionary
        }
    )
    chunks.append(chunk_obj)

print(f"📚 Loaded {len(chunks)} pre-processed chunks from 'Chunks.json'")

# Display a sample chunk to verify
if chunks:
    sample = chunks[0]
    print("\n📋 Sample Chunk:")
    print(f"   Content: {sample.page_content[:150].replace(chr(10), ' ')}...")
    print(f"   Metadata: {sample.metadata}")
# Out:
# 📚 Loaded 125 pre-processed chunks from 'Chunks.json'
#
# 📋 Sample Chunk:
#    Content: HISTORY OF EARIST  The Eulogio "Amang" Rodriguez Institute of Science and Technology (EARIST) was established after the liberation of Manila in 1945. ...
#    Metadata: {'chunk_id': 'handbook_chunk_001', 'source_document': 'Student Handbook', 'section_hierarchy': 'HISTORY OF EARIST'}

# %%
import torch
from langchain_experimental.text_splitter import SemanticChunker
from langchain_community.embeddings import HuggingFaceEmbeddings
import faiss
import numpy as np
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
import warnings
warnings.filterwarnings('ignore')

# %%
from huggingface_hub import notebook_login

# This will prompt you to enter your HF token
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
print("\n🔧 Initializing embedding model...")
embedding_model = HuggingFaceEmbeddings(
    model_name="nomic-ai/nomic-embed-text-v1.5",  # Nomic embedding model
    model_kwargs={
        'device': 'cuda' if torch.cuda.is_available() else 'cpu',
        'trust_remote_code': True
    },
    encode_kwargs={'normalize_embeddings': True}
)
print("✅ Embedding model loaded: nomic-embed-text-v1.5 (768 dimensions)")
# Out:
# 🔧 Initializing embedding model...
# <All keys matched successfully>
# ✅ Embedding model loaded: nomic-embed-text-v1.5 (768 dimensions)

# %%
print("\n🔄 Generating embeddings for all chunks...")
chunk_texts = [chunk.page_content for chunk in chunks]

# Process embeddings in batches to avoid memory issues
batch_size = 32
all_embeddings = []
for i in range(0, len(chunk_texts), batch_size):
    batch = chunk_texts[i:i+batch_size]
    batch_embeddings = embedding_model.embed_documents(batch)
    all_embeddings.extend(batch_embeddings)
    print(f"   Processed batch {i//batch_size + 1}/{(len(chunk_texts) + batch_size - 1)//batch_size}")

print(f"✅ Generated {len(all_embeddings)} embeddings")
# Out:
# 🔄 Generating embeddings for all chunks...
#    Processed batch 1/4
#    Processed batch 1/4
#    Processed batch 2/4
#    Processed batch 2/4
#    Processed batch 3/4
#    Processed batch 3/4
#    Processed batch 4/4
# ✅ Generated 125 embeddings
#    Processed batch 4/4
# ✅ Generated 125 embeddings

# %%
# 5. Build FAISS vector store for fast similarity search
print("\n🗄️ Building FAISS vector database...")
dimension = len(all_embeddings[0])
index = faiss.IndexFlatIP(dimension)  # Inner Product for cosine similarity

# Normalize embeddings for proper cosine similarity
embeddings_array = np.array(all_embeddings).astype('float32')
faiss.normalize_L2(embeddings_array)
index.add(embeddings_array)

print(f"✅ FAISS index ready: {index.ntotal:,} vectors ({dimension} dimensions)")
# Out:
# 🗄️ Building FAISS vector database...
# ✅ FAISS index ready: 125 vectors (768 dimensions)

# %%
# 6. Load high-quality language model for generation
print("\n🤖 Loading language model...")

# Configure 4-bit quantization for T4 GPU
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)
# Out:
# 🤖 Loading language model...

# %%
from huggingface_hub import notebook_login

# This will prompt you to enter your HF token
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# Use Mistral 7B for quality (perfect for T4)
model_name = "mistralai/Mistral-7B-Instruct-v0.1"

tokenizer = AutoTokenizer.from_pretrained(model_name)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map="auto",
    torch_dtype=torch.bfloat16,
    trust_remote_code=True
)

print(f"✅ Model loaded: {model_name}")
print(f"🎯 GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f}GB")
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ✅ Model loaded: mistralai/Mistral-7B-Instruct-v0.1
# 🎯 GPU Memory: 8.5GB

# %%
def retrieve_relevant_chunks(query, top_k=5):
    """Find most relevant chunks for the query"""
    # Embed the query
    query_embedding = embedding_model.embed_query(query)
    query_vector = np.array([query_embedding]).astype('float32')
    faiss.normalize_L2(query_vector)

    # Search FAISS index
    scores, indices = index.search(query_vector, top_k)

    # Return results with metadata
    results = []
    for idx, score in zip(indices[0], scores[0]):
        if idx < len(chunks):  # Safety check
            chunk = chunks[idx]
            results.append({
                'text': chunk.page_content,
                'score': float(score),
                'chunk_id': chunk.metadata.get('chunk_id', int(idx)),
                'start_pos': chunk.metadata.get('start_index', 0) if hasattr(chunk, 'metadata') else 0
            })

    return results

def generate_answer(query, context_chunks, max_new_tokens=350):
    
    # Define token limits
    MAX_TOTAL_TOKENS = 4096
    MAX_OUTPUT_TOKENS = max_new_tokens
    MAX_INPUT_TOKENS = MAX_TOTAL_TOKENS - MAX_OUTPUT_TOKENS - 32  # 32 token safety buffer

    # --- Dynamic Prompt Truncation ---
    working_chunks = list(context_chunks) # Make a copy to modify

    while True:
        if not working_chunks:
            # Handle case where all context is removed
            combined_context = "No information found in the handbook."
            break

        # Re-ranking and XML-style Tags
        best_chunk = working_chunks[0]
        other_chunks = working_chunks[1:]
        other_chunks.reverse()

        context_parts = []
        for i, chunk in enumerate(other_chunks):
            context_parts.append(f"<HANDBOOK_SECTION_{i+1}>\n{chunk['text']}\n</HANDBOOK_SECTION_{i+1}>")
        context_parts.append(f"<HANDBOOK_SECTION_MOST_RELEVANT>\n{best_chunk['text']}\n</HANDBOOK_SECTION_MOST_RELEVANT>")
        
        combined_context = "\n\n".join(context_parts)

        # Create prompt and check token length
#         prompt = f"""<s>[INST] You are Amang Bot (Ambot) a university advisor. Answer the User's question accurately using only the provided sections below.

# INFORMATION SECTIONS:
# {combined_context}

# USER QUESTION: {query}

# Provide a clear, helpful answer based on the information above. If the Information Sections doesn't contain enough information, say so. Be specific about policies, procedures, and requirements. [/INST]"""
        prompt = f"""
<s>[INST]
You are **Amang Bot (Ambot)**, a precise and helpful university advisor. 
You must answer the user's question **using only the information provided in the INFORMATION SECTIONS**. 

### Your Answer Must Follow These Rules:
1. **Start with a direct answer** to the user's question.
2. After the direct answer, **provide additional relevant details**, background, or context based strictly on the provided information.
3. If the information sections **do not include the answer**, explicitly say:
   "The provided information does not contain the answer to this question."
4. Do NOT invent or assume facts that are not in the information sections.
5. Maintain a clear, formal, and student-friendly tone.

---

### INFORMATION SECTIONS:
{combined_context}

---

### USER QUESTION:
{query}

Provide your answer now, following the rules above.
[/INST]
"""

        # Check token length
        inputs = tokenizer(prompt, return_tensors="pt", truncation=False)
        input_length = inputs['input_ids'].shape[1]

        if input_length <= MAX_INPUT_TOKENS:
            print(f"✅ Prompt fits token budget with {len(working_chunks)} chunks.")
            break
        else:
            # If prompt is too long, remove the least relevant chunk and retry
            if len(working_chunks) > 1:
                removed_chunk = working_chunks.pop(-1) # Remove last item (least relevant)
                print(f"⚠️ Prompt too long ({input_length} > {MAX_INPUT_TOKENS}). Removing least relevant chunk (Score: {removed_chunk['score']:.3f})...")
            else:
                # Can't remove any more chunks, will have to truncate
                print(f"⚠️ Prompt still too long, but only one chunk remains. Truncation will occur.")
                break

    # Tokenize with final truncation (as a safeguard)
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=MAX_INPUT_TOKENS)
    input_length = inputs['input_ids'].shape[1] 
    
    inputs = {k: v.to(model.device) for k, v in inputs.items()}

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=MAX_OUTPUT_TOKENS,
            temperature=0.2,
            do_sample=True,
            top_p=0.9,
            repetition_penalty=1.1,
            pad_token_id=tokenizer.eos_token_id,
            eos_token_id=tokenizer.eos_token_id
        )

    # Decode only the newly generated tokens
    new_tokens = outputs[0][input_length:]
    answer = tokenizer.decode(new_tokens, skip_special_tokens=True).strip()

    print(f"\n📝 Generated answer ({len(new_tokens)} tokens):\n{answer}\n")
    return answer

def ask_handbook(question, top_k=5, show_sources=True):
    """Complete RAG pipeline for handbook queries"""
    print(f"\n❓ Question: {question}")
    print("=" * 70)

    # Retrieve relevant sections
    relevant_chunks = retrieve_relevant_chunks(question, top_k)

    if not relevant_chunks:
        print("❌ No relevant information found in handbook")
        return None

    if show_sources:
        print("📚 Found relevant handbook sections:")
        for i, chunk in enumerate(relevant_chunks):
            print(f"\n📄 Section {i+1} (Relevance: {chunk['score']:.3f})")
            preview = chunk['text'][:200].replace('\n', ' ')
            print(f"   {preview}...")

    # Generate answer
    print("\n🤔 Generating answer...")
    answer = generate_answer(question, relevant_chunks)

    print(f"\n💡 Answer:")
    print(answer)
    print("\n" + "=" * 70)

    return {
        'question': question,
        'answer': answer,
        'sources': relevant_chunks,
        'num_sources': len(relevant_chunks)
    }

# Test the system
print("\n\n🚀 RAG System Ready!")
print("Testing with university-specific questions...")

# Sample test questions for university handbook
test_questions = [
    "What are the graduation requirements?",
    "How do I withdraw from a course?",
    "What is the academic probation policy?",
    "What happens if I'm caught cheating?",
    "How do I change my major?"
]

# Run a test query
# test_result = ask_handbook(test_questions[0])

# Interactive query function
def interactive_mode():
    """Interactive mode for asking questions"""
    print("\n🎓 Interactive University Handbook Assistant")
    print("Type 'quit' to exit")
    print("-" * 50)

    while True:
        question = input("\n❓ Your question: ").strip()

        if question.lower() in ['quit', 'exit', 'q']:
            print("👋 Goodbye!")
            break

        if not question:
            print("Please enter a question!")
            continue

        try:
            ask_handbook(question)
        except Exception as e:
            print(f"❌ Error: {str(e)}")

# Uncomment to start interactive mode
# interactive_mode()

print("\n📋 System Summary:")
print(f"   📚 Processed: {len(chunks):,} semantic chunks")
print(f"   🔍 Embeddings: {len(all_embeddings):,} vectors")
print(f"   🤖 Model: {model_name}")
print(f"   💾 Ready for queries!")
# Out:
# 🚀 RAG System Ready!
# Testing with university-specific questions...
#
# 📋 System Summary:
#    📚 Processed: 125 semantic chunks
#    🔍 Embeddings: 125 vectors
#    🤖 Model: mistralai/Mistral-7B-Instruct-v0.1
#    💾 Ready for queries!

# %%
interactive_mode()
# Out:
# 🎓 Interactive University Handbook Assistant
# Type 'quit' to exit
# --------------------------------------------------
#
# ❓ Question: Where is the present site of EARIST?
# ======================================================================
# 📚 Found relevant handbook sections:
#
# 📄 Section 1 (Relevance: 0.694)
#    HISTORY OF EARIST  The Eulogio "Amang" Rodriguez Institute of Science and Technology (EARIST) was established after the liberation of Manila in 1945. EARIST traces back its development from Vocational...
#
# 📄 Section 2 (Relevance: 0.625)
#    EARIST Hymn  Let the EARIST music fill the air With the echo our spirit rise There's a magic that will stir the hearts When we sing our lively tuneful march What a joy to sing the music gay When it so...
#
# 📄 Section 3 (Relevance: 0.578)
#    - Awarded LEVEL II STATUS in the Fourteen (14) Degrees Program (Accrediting Agency of Chartered Colleges and Universities in the Philippines) - Rated SUC LEVEL II (CHED-DBM-PASUC Leveling Evaluation) ...
#
# 📄 Section 4 (Relevance: 0.568)
#    Through the EARIST Cultural Affairs Division (ECAD), the Institute generates interest and participation in cultural/artistic activities by designing workshops. #### 4.11 Sports and Physical Developmen...
#
# 📄 Section 5 (Relevance: 0.547)
#    Section 5 – The SAS Director reserves the right to decide the kind of announcement that shall be granted approval for posting. Section 6 – Permit to install any banner/tarpaulin within the school prem...
#
# 🤔 Generating answer...
# ✅ Prompt fits token budget with 5 chunks.
#
# ❓ Question: Where is the present site of EARIST?
# ======================================================================
# 📚 Found relevant handbook sections:
#
# 📄 Section 1 (Relevance: 0.694)
#    HISTORY OF EARIST  The Eulogio "Amang" Rodriguez Institute of Science and Technology (EARIST) was established after the liberation of Manila in 1945. EARIST traces back its development from Vocational...
#
# 📄 Section 2 (Relevance: 0.625)
#    EARIST Hymn  Let the EARIST music fill the air With the echo our spirit rise There's a magic that will stir the hearts When we sing our lively tuneful march What a joy to sing the music gay When it so...
#
# 📄 Section 3 (Relevance: 0.578)
#    - Awarded LEVEL II STATUS in the Fourteen (14) Degrees Program (Accrediting Agency of Chartered Colleges and Universities in the Philippines) - Rated SUC LEVEL II (CHED-DBM-PASUC Leveling Evaluation) ...
#
# 📄 Section 4 (Relevance: 0.568)
#    Through the EARIST Cultural Affairs Division (ECAD), the Institute generates interest and participation in cultural/artistic activities by designing workshops. #### 4.11 Sports and Physical Developmen...
#
# 📄 Section 5 (Relevance: 0.547)
#    Section 5 – The SAS Director reserves the right to decide the kind of announcement that shall be granted approval for posting. Section 6 – Permit to install any banner/tarpaulin within the school prem...
#
# 🤔 Generating answer...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (22 tokens):
# The present site of EARIST is at Nagtahan, Sampaloc, Manila.
#
#
# 💡 Answer:
# The present site of EARIST is at Nagtahan, Sampaloc, Manila.
#
# ======================================================================
#
# 📝 Generated answer (22 tokens):
# The present site of EARIST is at Nagtahan, Sampaloc, Manila.
#
#
# 💡 Answer:
# The present site of EARIST is at Nagtahan, Sampaloc, Manila.
#
# ======================================================================
# 👋 Goodbye!
# 👋 Goodbye!

# %% [markdown]
# # Testing Workflow with Test Dataset
#
# This section will run all questions from Test.json through the RAG pipeline and save results to CSV.

# %%
import json
import pandas as pd
from datetime import datetime
import time

# Load test questions
with open('../Test/Test.json', 'r', encoding='utf-8') as f:
    test_data = json.load(f)

print(f"📋 Loaded {len(test_data)} test questions")
print(f"📊 Categories: {set(q['category'] for q in test_data)}")
print(f"📊 Difficulty levels: {set(q['difficulty'] for q in test_data)}")
# Out:
# 📋 Loaded 100 test questions
# 📊 Categories: {'unanswerable', 'direct', 'paraphrased', 'adversarial', 'scenario'}
# 📊 Difficulty levels: {'easy', 'hard', 'medium'}

# %%
def test_rag_pipeline(test_data, top_k=5, output_file='rag_test_results.csv'):
    """
    Run RAG pipeline on all test questions and save results to CSV
    
    Args:
        test_data: List of test questions with expected answers
        top_k: Number of chunks to retrieve
        output_file: Output CSV filename
    """
    results = []
    
    print(f"\n🚀 Starting RAG Pipeline Test")
    print(f"📝 Testing {len(test_data)} questions...")
    print("=" * 80)
    
    for i, test_item in enumerate(test_data):
        question = test_item['question']
        expected_answer = test_item['answer']
        difficulty = test_item['difficulty']
        category = test_item['category']
        
        print(f"\n[{i+1}/{len(test_data)}] Processing: {question[:60]}...")
        
        try:
            # Start timing
            start_time = time.time()
            
            # Retrieve relevant chunks
            relevant_chunks = retrieve_relevant_chunks(question, top_k)
            
            # Generate answer with updated token limit
            if relevant_chunks:
                generated_answer = generate_answer(question, relevant_chunks, max_new_tokens=512)
                
                # Calculate average relevance score
                avg_score = sum(chunk['score'] for chunk in relevant_chunks) / len(relevant_chunks)
                top_score = relevant_chunks[0]['score'] if relevant_chunks else 0
                
                # Get chunk IDs
                chunk_ids = [chunk['chunk_id'] for chunk in relevant_chunks]
            else:
                generated_answer = "NO RELEVANT CHUNKS FOUND"
                avg_score = 0
                top_score = 0
                chunk_ids = []
            
            # End timing
            processing_time = time.time() - start_time
            
            # Store result
            result = {
                'question_number': i + 1,
                'question': question,
                'expected_answer': expected_answer,
                'generated_answer': generated_answer,
                'difficulty': difficulty,
                'category': category,
                'processing_time_sec': round(processing_time, 2),
                'top_relevance_score': round(top_score, 4),
                'avg_relevance_score': round(avg_score, 4),
                'num_chunks_retrieved': len(relevant_chunks),
                'chunk_ids': str(chunk_ids)
            }
            
            results.append(result)
            print(f"✅ Completed in {processing_time:.2f}s (Relevance: {top_score:.3f})")
            
        except Exception as e:
            print(f"❌ Error: {str(e)}")
            result = {
                'question_number': i + 1,
                'question': question,
                'expected_answer': expected_answer,
                'generated_answer': f"ERROR: {str(e)}",
                'difficulty': difficulty,
                'category': category,
                'processing_time_sec': 0,
                'top_relevance_score': 0,
                'avg_relevance_score': 0,
                'num_chunks_retrieved': 0,
                'chunk_ids': '[]'
            }
            results.append(result)
    
    # Create DataFrame
    df = pd.DataFrame(results)
    
    # Save to CSV
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    output_filename = f"rag_test_results_{timestamp}.csv"
    df.to_csv(output_filename, index=False, encoding='utf-8-sig')
    
    print("\n" + "=" * 80)
    print(f"✅ Testing Complete!")
    print(f"📊 Total questions: {len(results)}")
    print(f"💾 Results saved to: {output_filename}")
    print(f"⏱️  Total time: {df['processing_time_sec'].sum():.2f}s")
    print(f"📈 Average processing time: {df['processing_time_sec'].mean():.2f}s per question")
    
    # Summary statistics
    print("\n📊 Summary by Category:")
    category_summary = df.groupby('category').agg({
        'question': 'count',
        'processing_time_sec': 'mean',
        'top_relevance_score': 'mean'
    }).round(2)
    print(category_summary)
    
    print("\n📊 Summary by Difficulty:")
    difficulty_summary = df.groupby('difficulty').agg({
        'question': 'count',
        'processing_time_sec': 'mean',
        'top_relevance_score': 'mean'
    }).round(2)
    print(difficulty_summary)
    
    return df, output_filename

# %%
# Run the test pipeline
results_df, output_file = test_rag_pipeline(test_data, top_k=5)

print(f"\n📄 Preview of results:")
print(results_df[['question_number', 'category', 'difficulty', 'top_relevance_score', 'processing_time_sec']].head(10))
# Out:
# 🚀 Starting RAG Pipeline Test
# 📝 Testing 100 questions...
# ================================================================================
#
# [1/100] Processing: What documents do I need to submit to apply as a freshman?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (98 tokens):
# As a freshman, you need to submit the following documents to apply to EARIST:
#
# 1. Form 138 (Senior and High School Report Card)
# 2. Certificate of Good Moral Character with school seal
# 3. Birth Certificate (PSA Authenticated)
# 4. EARISTCAT Result
# 5. Satisfactory Result of Dean's Assessment and Evaluation
# 6. Medical and Health Examination
#
# ✅ Completed in 10.19s (Relevance: 0.641)
#
# [2/100] Processing: I'm a transferee from another uni, what papers do I need?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (98 tokens):
# As a freshman, you need to submit the following documents to apply to EARIST:
#
# 1. Form 138 (Senior and High School Report Card)
# 2. Certificate of Good Moral Character with school seal
# 3. Birth Certificate (PSA Authenticated)
# 4. EARISTCAT Result
# 5. Satisfactory Result of Dean's Assessment and Evaluation
# 6. Medical and Health Examination
#
# ✅ Completed in 10.19s (Relevance: 0.641)
#
# [2/100] Processing: I'm a transferee from another uni, what papers do I need?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (178 tokens):
# As a transferee from another university, you will need to provide the following documents:
#
# 1. Transcript of Records/Certification of Grades from your previous university.
# 2. Certificate of Good Moral Character.
# 3. Satisfactory Result of Dean's Assessment and Evaluation.
# 4. Recommendation from the Dean or Guidance Counselor of the school you were previously enrolled in.
# 5. Transfer Credential/Honorable Dismissal.
# 6. EARISTCAT result.
# 7. Medical and Health Examination results.
#
# Please note that these requirements may vary depending on the specific program you are applying for at EARIST. It is best to check with the Admissions Office for the most accurate and up-to-date information regarding your specific situation.
#
# ✅ Completed in 15.21s (Relevance: 0.693)
#
# [3/100] Processing: My EARISTCAT score for BS Civil Engineering was 82%. Did I g...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (178 tokens):
# As a transferee from another university, you will need to provide the following documents:
#
# 1. Transcript of Records/Certification of Grades from your previous university.
# 2. Certificate of Good Moral Character.
# 3. Satisfactory Result of Dean's Assessment and Evaluation.
# 4. Recommendation from the Dean or Guidance Counselor of the school you were previously enrolled in.
# 5. Transfer Credential/Honorable Dismissal.
# 6. EARISTCAT result.
# 7. Medical and Health Examination results.
#
# Please note that these requirements may vary depending on the specific program you are applying for at EARIST. It is best to check with the Admissions Office for the most accurate and up-to-date information regarding your specific situation.
#
# ✅ Completed in 15.21s (Relevance: 0.693)
#
# [3/100] Processing: My EARISTCAT score for BS Civil Engineering was 82%. Did I g...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (129 tokens):
# Based on the information provided, a score of 82% on the EARISTCAT for the Bachelor of Science in Civil Engineering (BSCE) program would not necessarily mean acceptance into the program. The admission process for EARIST Cavite Campus (ECC) transferees involves meeting all the academic and admission requirements set forth by the Institute, in addition to having complied with all the requirements for admission. Therefore, it is recommended to check the official website or contact the admissions office of EARIST Cavite Campus for the most up-to-date information on the admission requirements and processes.
#
# ✅ Completed in 9.74s (Relevance: 0.575)
#
# [4/100] Processing: Admission is first-come-first-served, right? So my EARISTCAT...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (129 tokens):
# Based on the information provided, a score of 82% on the EARISTCAT for the Bachelor of Science in Civil Engineering (BSCE) program would not necessarily mean acceptance into the program. The admission process for EARIST Cavite Campus (ECC) transferees involves meeting all the academic and admission requirements set forth by the Institute, in addition to having complied with all the requirements for admission. Therefore, it is recommended to check the official website or contact the admissions office of EARIST Cavite Campus for the most up-to-date information on the admission requirements and processes.
#
# ✅ Completed in 9.74s (Relevance: 0.575)
#
# [4/100] Processing: Admission is first-come-first-served, right? So my EARISTCAT...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (106 tokens):
# Your EARISTCAT score does matter for admission, as it is one of the requirements for both freshmen and transfer students. However, admission is also based on a first-come-first-served basis, meaning that even if you have a higher EARISTCAT score, if another applicant applies before you and meets all the other requirements, they may still be admitted before you. Therefore, it's important to submit your application as early as possible to increase your chances of being admitted.
#
# ✅ Completed in 9.68s (Relevance: 0.642)
#
# [5/100] Processing: What's the deadline for freshman applications for the next s...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (106 tokens):
# Your EARISTCAT score does matter for admission, as it is one of the requirements for both freshmen and transfer students. However, admission is also based on a first-come-first-served basis, meaning that even if you have a higher EARISTCAT score, if another applicant applies before you and meets all the other requirements, they may still be admitted before you. Therefore, it's important to submit your application as early as possible to increase your chances of being admitted.
#
# ✅ Completed in 9.68s (Relevance: 0.642)
#
# [5/100] Processing: What's the deadline for freshman applications for the next s...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (21 tokens):
# The deadline for freshman applications for the next school year is not specified in the provided information sections.
#
# ✅ Completed in 43.81s (Relevance: 0.646)
#
# [6/100] Processing: I'm applying for BS Architecture. Is there any other test be...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (21 tokens):
# The deadline for freshman applications for the next school year is not specified in the provided information sections.
#
# ✅ Completed in 43.81s (Relevance: 0.646)
#
# [6/100] Processing: I'm applying for BS Architecture. Is there any other test be...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (77 tokens):
# In addition to the main entrance exam, there are also Program Preparedness Tests that are specifically designed to assess competency in specific skills/disciplines required for the Bachelor of Science in Architecture program. These tests may be used to determine if a student is conditionally admitted into the program and requires to enroll and pass one to two enhancement courses during their first year.
#
# ✅ Completed in 69.60s (Relevance: 0.687)
#
# [7/100] Processing: What's the maximum number of units I can enroll in per semes...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (77 tokens):
# In addition to the main entrance exam, there are also Program Preparedness Tests that are specifically designed to assess competency in specific skills/disciplines required for the Bachelor of Science in Architecture program. These tests may be used to determine if a student is conditionally admitted into the program and requires to enroll and pass one to two enhancement courses during their first year.
#
# ✅ Completed in 69.60s (Relevance: 0.687)
#
# [7/100] Processing: What's the maximum number of units I can enroll in per semes...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (240 tokens):
# Based on the provided information, the maximum number of units a student can enroll in per semester depends on their academic level and the specific semester. For regular students, the maximum academic units for undergraduate students is the number of units indicated on their program checklist. However, they may be allowed to enroll more than the maximum allowable load during a regular semester under certain conditions, such as back courses in their curriculum checklist, courses without pre-requisites, and recommended by the Dean/Campus Administrator and approved by the Vice President for Academic Affairs.
#
# For irregular students, the maximum academic units they can enroll in per semester is less than the full load required in their curriculum.
#
# For special students, there is no limit on the number of units they can enroll in per semester, as long as they are not earning formal academic credits.
#
# It's important to note that the maximum number of units a student can enroll in per semester may vary depending on their specific program and curriculum. It's best to consult with the appropriate academic advisor or department chairperson for more accurate information.
#
# ✅ Completed in 20.12s (Relevance: 0.743)
#
# [8/100] Processing: I'm a regular student, can I enroll in just 6 units this sem...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (240 tokens):
# Based on the provided information, the maximum number of units a student can enroll in per semester depends on their academic level and the specific semester. For regular students, the maximum academic units for undergraduate students is the number of units indicated on their program checklist. However, they may be allowed to enroll more than the maximum allowable load during a regular semester under certain conditions, such as back courses in their curriculum checklist, courses without pre-requisites, and recommended by the Dean/Campus Administrator and approved by the Vice President for Academic Affairs.
#
# For irregular students, the maximum academic units they can enroll in per semester is less than the full load required in their curriculum.
#
# For special students, there is no limit on the number of units they can enroll in per semester, as long as they are not earning formal academic credits.
#
# It's important to note that the maximum number of units a student can enroll in per semester may vary depending on their specific program and curriculum. It's best to consult with the appropriate academic advisor or department chairperson for more accurate information.
#
# ✅ Completed in 20.12s (Relevance: 0.743)
#
# [8/100] Processing: I'm a regular student, can I enroll in just 6 units this sem...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (192 tokens):
# As per the Handbook Section 2.4, the regular academic load for a student is 6 units during the intersession class. However, you may be allowed to enroll additional three (3) units under certain conditions, such as back courses in your curriculum checklist and courses without pre-requisites. It is important to note that these additional units must be recommended by the Dean/Campus Administrator and approved by the Vice President for Academic Affairs.
#
# If you are a regular student and have a part-time job, you may want to consider enrolling in the minimum required load of 6 units during the intersession class. This would allow you to balance your academic responsibilities with your part-time job. If you feel that you need more units to maintain your desired academic progress, you could discuss this with your academic advisor to see if they can recommend additional courses that meet the criteria mentioned above.
#
# ✅ Completed in 14.16s (Relevance: 0.649)
#
# [9/100] Processing: Can I enroll in two different colleges at EARIST at the same...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (192 tokens):
# As per the Handbook Section 2.4, the regular academic load for a student is 6 units during the intersession class. However, you may be allowed to enroll additional three (3) units under certain conditions, such as back courses in your curriculum checklist and courses without pre-requisites. It is important to note that these additional units must be recommended by the Dean/Campus Administrator and approved by the Vice President for Academic Affairs.
#
# If you are a regular student and have a part-time job, you may want to consider enrolling in the minimum required load of 6 units during the intersession class. This would allow you to balance your academic responsibilities with your part-time job. If you feel that you need more units to maintain your desired academic progress, you could discuss this with your academic advisor to see if they can recommend additional courses that meet the criteria mentioned above.
#
# ✅ Completed in 14.16s (Relevance: 0.649)
#
# [9/100] Processing: Can I enroll in two different colleges at EARIST at the same...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (58 tokens):
# No, you cannot enroll in two different colleges at EARIST at the same time to get two degrees. According to the Handbook Section 1.4, no student shall be enrolled in more than one college to earn more than one academic degree at the same time.
#
# ✅ Completed in 6.25s (Relevance: 0.737)
#
# [10/100] Processing: How much is the tuition fee per unit?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (58 tokens):
# No, you cannot enroll in two different colleges at EARIST at the same time to get two degrees. According to the Handbook Section 1.4, no student shall be enrolled in more than one college to earn more than one academic degree at the same time.
#
# ✅ Completed in 6.25s (Relevance: 0.737)
#
# [10/100] Processing: How much is the tuition fee per unit?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (13 tokens):
# The provided information does not contain the answer to this question.
#
# ✅ Completed in 3.11s (Relevance: 0.670)
#
# [11/100] Processing: My required subject isn't offered this sem. Can I just take ...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (13 tokens):
# The provided information does not contain the answer to this question.
#
# ✅ Completed in 3.11s (Relevance: 0.670)
#
# [11/100] Processing: My required subject isn't offered this sem. Can I just take ...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (277 tokens):
# According to the Handbook Sections provided, cross-enrolling in another school is allowed under certain conditions. However, before proceeding with cross-enrollment, you should first check if the required subject is being offered in the next semester or if it can be taken online. If neither option is available, then cross-enrollment may be considered.
#
# To cross-enroll, you will need to submit a request to the Registrar's Office and obtain written permission from the Dean/Campus Administrator of the school where you wish to take the subject. Additionally, you will need to provide a copy of your Official Transcript of Records and have it evaluated by the Department Chairperson and the Registrar's Office.
#
# It's important to note that cross-enrollment is only allowed up to a maximum of six (6) units per semester. Also, if you choose to follow the old curriculum, you do not need to take the Bridging Program for Lifelong Learners. However, if you choose to follow the new curriculum, you will be required to enroll and pass the additional general education subjects identified in the Bridging Program for Lifelong Learners.
#
# Lastly, the Institute does not accept applications for a second baccalaureate degree.
#
# ✅ Completed in 21.08s (Relevance: 0.707)
#
# [12/100] Processing: What's the official process for dropping a subject?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (277 tokens):
# According to the Handbook Sections provided, cross-enrolling in another school is allowed under certain conditions. However, before proceeding with cross-enrollment, you should first check if the required subject is being offered in the next semester or if it can be taken online. If neither option is available, then cross-enrollment may be considered.
#
# To cross-enroll, you will need to submit a request to the Registrar's Office and obtain written permission from the Dean/Campus Administrator of the school where you wish to take the subject. Additionally, you will need to provide a copy of your Official Transcript of Records and have it evaluated by the Department Chairperson and the Registrar's Office.
#
# It's important to note that cross-enrollment is only allowed up to a maximum of six (6) units per semester. Also, if you choose to follow the old curriculum, you do not need to take the Bridging Program for Lifelong Learners. However, if you choose to follow the new curriculum, you will be required to enroll and pass the additional general education subjects identified in the Bridging Program for Lifelong Learners.
#
# Lastly, the Institute does not accept applications for a second baccalaureate degree.
#
# ✅ Completed in 21.08s (Relevance: 0.707)
#
# [12/100] Processing: What's the official process for dropping a subject?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (93 tokens):
# According to the provided information sections, the official process for dropping a subject is not explicitly stated. However, it is mentioned that students who fail or withdraw (authorized or unauthorized) thrice in the same course (or subject) will be dropped from the roll. Additionally, students can only be on probation twice. Inability to lift the second probation, a student will be ineligible to enroll for the succeeding semester.
#
# ✅ Completed in 8.58s (Relevance: 0.672)
#
# [13/100] Processing: I failed my 'Intro to Programming' major. Can I just substit...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (93 tokens):
# According to the provided information sections, the official process for dropping a subject is not explicitly stated. However, it is mentioned that students who fail or withdraw (authorized or unauthorized) thrice in the same course (or subject) will be dropped from the roll. Additionally, students can only be on probation twice. Inability to lift the second probation, a student will be ineligible to enroll for the succeeding semester.
#
# ✅ Completed in 8.58s (Relevance: 0.672)
#
# [13/100] Processing: I failed my 'Intro to Programming' major. Can I just substit...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (219 tokens):
# According to the information provided in Section 3.3 of the Handbook, substitution of courses is allowed in certain cases such as when a required course is not offered or when a curriculum has been superseded by a new one. However, the proposed substitute course must be aligned with the one being substituted, have the same or higher number of units, involve courses within the same department if possible, and be recommended by the Program Chairperson, endorsed by College Dean and Registrar, and approved by the Vice President for Academic Affairs.
#
# In this case, since you failed your 'Intro to Programming' major, it is unlikely that 'Web Development 1' would be considered a suitable substitute course as they are not substantially similar in scope and coverage. It is recommended that you speak with your college dean or academic advisor to discuss your options for replacing your failed course. They may be able to provide guidance on which courses would be most appropriate for you to take based on your academic goals and the requirements of your program.
#
# ✅ Completed in 19.29s (Relevance: 0.620)
#
# [14/100] Processing: How many absences am I allowed before I get dropped from a c...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (219 tokens):
# According to the information provided in Section 3.3 of the Handbook, substitution of courses is allowed in certain cases such as when a required course is not offered or when a curriculum has been superseded by a new one. However, the proposed substitute course must be aligned with the one being substituted, have the same or higher number of units, involve courses within the same department if possible, and be recommended by the Program Chairperson, endorsed by College Dean and Registrar, and approved by the Vice President for Academic Affairs.
#
# In this case, since you failed your 'Intro to Programming' major, it is unlikely that 'Web Development 1' would be considered a suitable substitute course as they are not substantially similar in scope and coverage. It is recommended that you speak with your college dean or academic advisor to discuss your options for replacing your failed course. They may be able to provide guidance on which courses would be most appropriate for you to take based on your academic goals and the requirements of your program.
#
# ✅ Completed in 19.29s (Relevance: 0.620)
#
# [14/100] Processing: How many absences am I allowed before I get dropped from a c...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (121 tokens):
# According to Section 5.11 of the Handbook, a student who has been absent for more than 20 percent of the hours of recitation, lectures, laboratory, or any other scheduled work in one subject for the semester, or any academic period, shall be automatically dropped from the class roll and the Registrar shall be advised accordingly. Therefore, you would need to calculate the percentage of absences you have had in each subject and determine if you have exceeded the 20 percent threshold. If you have, then you will be dropped from the class.
#
# ✅ Completed in 11.03s (Relevance: 0.707)
#
# [15/100] Processing: How late can I be to class before I'm marked absent?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (121 tokens):
# According to Section 5.11 of the Handbook, a student who has been absent for more than 20 percent of the hours of recitation, lectures, laboratory, or any other scheduled work in one subject for the semester, or any academic period, shall be automatically dropped from the class roll and the Registrar shall be advised accordingly. Therefore, you would need to calculate the percentage of absences you have had in each subject and determine if you have exceeded the 20 percent threshold. If you have, then you will be dropped from the class.
#
# ✅ Completed in 11.03s (Relevance: 0.707)
#
# [15/100] Processing: How late can I be to class before I'm marked absent?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (149 tokens):
# Based on the provided information, a student is considered late or tardy if they arrive in class during the first 1/6 fraction of the scheduled class time. This means that if a class is scheduled for three hours, a student would be considered tardy if they arrive more than 30 minutes late. If a class is scheduled for two hours, a student would be considered tardy if they arrive more than 20 minutes late. If a class is scheduled for one hour and a half, a student would be considered tardy if they arrive more than 15 minutes late. If a class is scheduled for one hour, a student would be considered tardy if they arrive more than 10 minutes late.
#
# ✅ Completed in 13.77s (Relevance: 0.673)
#
# [16/100] Processing: I've been late three times. Does that equal one absence?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (149 tokens):
# Based on the provided information, a student is considered late or tardy if they arrive in class during the first 1/6 fraction of the scheduled class time. This means that if a class is scheduled for three hours, a student would be considered tardy if they arrive more than 30 minutes late. If a class is scheduled for two hours, a student would be considered tardy if they arrive more than 20 minutes late. If a class is scheduled for one hour and a half, a student would be considered tardy if they arrive more than 15 minutes late. If a class is scheduled for one hour, a student would be considered tardy if they arrive more than 10 minutes late.
#
# ✅ Completed in 13.77s (Relevance: 0.673)
#
# [16/100] Processing: I've been late three times. Does that equal one absence?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (103 tokens):
# According to Section 5.3 of the Handbook, a student is considered absent from class if they arrive after the first 1/6 fraction of the scheduled class time. Therefore, three instances of tardiness would not necessarily equal one absence. However, it's important to note that tardiness can lead to an accumulation of absences, which could ultimately result in a drop from the class roll. It's always best to maintain attendance and punctuality to ensure academic success.
#
# ✅ Completed in 59.54s (Relevance: 0.546)
#
# [17/100] Processing: I was sick and missed my midterms. What should I do to get a...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (103 tokens):
# According to Section 5.3 of the Handbook, a student is considered absent from class if they arrive after the first 1/6 fraction of the scheduled class time. Therefore, three instances of tardiness would not necessarily equal one absence. However, it's important to note that tardiness can lead to an accumulation of absences, which could ultimately result in a drop from the class roll. It's always best to maintain attendance and punctuality to ensure academic success.
#
# ✅ Completed in 59.54s (Relevance: 0.546)
#
# [17/100] Processing: I was sick and missed my midterms. What should I do to get a...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (214 tokens):
# To get an excused absence for missing your midterms due to illness, you need to follow these steps:
#
# 1. Submit a medical certificate: You need to provide a medical certificate from the Institute's Medical Officer or any other physician, verifying your illness. This certificate should be submitted to the College Dean as soon as possible.
# 2. Notify the faculty member: Inform your faculty member about your illness and the reason for your absence. They will then report your excused absence to the College Dean.
# 3. Comply with other class requirements: Even though you have been granted an excused absence, you still need to complete any outstanding assignments or participate in class discussions within a reasonable period of time.
# 4. Avoid further absences: Make sure to attend all remaining classes and avoid any further absences, as three consecutive unexcused absences could lead to disciplinary action.
#
# Remember that you should submit your medical certificate and notify your faculty member as soon as possible to ensure a smooth process.
#
# ✅ Completed in 76.31s (Relevance: 0.628)
#
# [18/100] Processing: What's the minimum passing grade?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (214 tokens):
# To get an excused absence for missing your midterms due to illness, you need to follow these steps:
#
# 1. Submit a medical certificate: You need to provide a medical certificate from the Institute's Medical Officer or any other physician, verifying your illness. This certificate should be submitted to the College Dean as soon as possible.
# 2. Notify the faculty member: Inform your faculty member about your illness and the reason for your absence. They will then report your excused absence to the College Dean.
# 3. Comply with other class requirements: Even though you have been granted an excused absence, you still need to complete any outstanding assignments or participate in class discussions within a reasonable period of time.
# 4. Avoid further absences: Make sure to attend all remaining classes and avoid any further absences, as three consecutive unexcused absences could lead to disciplinary action.
#
# Remember that you should submit your medical certificate and notify your faculty member as soon as possible to ensure a smooth process.
#
# ✅ Completed in 76.31s (Relevance: 0.628)
#
# [18/100] Processing: What's the minimum passing grade?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (32 tokens):
# The minimum passing grade is 3.00, which corresponds to a percentage equivalent of 75. This grade is described as "Passed".
#
# ✅ Completed in 52.55s (Relevance: 0.609)
#
# [19/100] Processing: I got a 2.50 in a subject. What does that mean?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (32 tokens):
# The minimum passing grade is 3.00, which corresponds to a percentage equivalent of 75. This grade is described as "Passed".
#
# ✅ Completed in 52.55s (Relevance: 0.609)
#
# [19/100] Processing: I got a 2.50 in a subject. What does that mean?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (55 tokens):
# A 2.50 grade point average (GPA) indicates that you have achieved a satisfactory academic performance in your subject. This means that you have met the minimum requirement for passing the course, as per the grading system provided in the information section.
#
# ✅ Completed in 6.62s (Relevance: 0.616)
#
# [20/100] Processing: My prof gave me an INC last sem. How long do I have to fix i...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (55 tokens):
# A 2.50 grade point average (GPA) indicates that you have achieved a satisfactory academic performance in your subject. This means that you have met the minimum requirement for passing the course, as per the grading system provided in the information section.
#
# ✅ Completed in 6.62s (Relevance: 0.616)
#
# [20/100] Processing: My prof gave me an INC last sem. How long do I have to fix i...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (50 tokens):
# Based on the provided information, the user needs to complete their Incomplete ("INC") grade within the next two (2) semesters. Failure to do so will result in the grade automatically becoming a "5.0".
#
# ✅ Completed in 6.88s (Relevance: 0.667)
#
# [21/100] Processing: I passed my class with a 3.0 but I want to improve it. Can I...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (50 tokens):
# Based on the provided information, the user needs to complete their Incomplete ("INC") grade within the next two (2) semesters. Failure to do so will result in the grade automatically becoming a "5.0".
#
# ✅ Completed in 6.88s (Relevance: 0.667)
#
# [21/100] Processing: I passed my class with a 3.0 but I want to improve it. Can I...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (73 tokens):
# According to the provided information, a student who has received a passing grade in a course (in this case, a 3.0) is not allowed to take another examination for the purpose of improving their grade. This policy is stated in Section 6.7 of the handbook. Therefore, you cannot retake the exam to improve your grade.
#
# ✅ Completed in 8.04s (Relevance: 0.614)
#
# [22/100] Processing: What's the grading breakdown? like how many percent for quiz...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (73 tokens):
# According to the provided information, a student who has received a passing grade in a course (in this case, a 3.0) is not allowed to take another examination for the purpose of improving their grade. This policy is stated in Section 6.7 of the handbook. Therefore, you cannot retake the exam to improve your grade.
#
# ✅ Completed in 8.04s (Relevance: 0.614)
#
# [22/100] Processing: What's the grading breakdown? like how many percent for quiz...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (14 tokens):
# The provided information does not contain the answer to this question.
#
# ✅ Completed in 47.64s (Relevance: 0.689)
#
# [23/100] Processing: My prof, who gave me an INC, is on leave and I can't contact...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (14 tokens):
# The provided information does not contain the answer to this question.
#
# ✅ Completed in 47.64s (Relevance: 0.689)
#
# [23/100] Processing: My prof, who gave me an INC, is on leave and I can't contact...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (181 tokens):
# Based on the provided information, you can complete your Incomplete ("INC") grade by following these steps:
#
# 1. Submit a SARRMS Form No. 006 (Appendix A, Page 76) to the Instruction Services Director.
# 2. Ensure that you comply with all other requirements associated with INC grades.
# 3. If the faculty member is on leave, unresponsive, or their whereabouts are unknown, the Area Chairperson can act upon the grade with the approval of the Dean.
#
# Please note that if the faculty member is retired, has resigned, or is disconnected from the service to the Institute, the Area Chairperson can also act upon the grade with the approval of the Dean. In cases of disability or death of the faculty, the Area Chairperson can act upon the grade without requiring Dean approval.
#
# ✅ Completed in 62.76s (Relevance: 0.765)
#
# [24/100] Processing: What happens if I fail 3 subjects in one semester?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (181 tokens):
# Based on the provided information, you can complete your Incomplete ("INC") grade by following these steps:
#
# 1. Submit a SARRMS Form No. 006 (Appendix A, Page 76) to the Instruction Services Director.
# 2. Ensure that you comply with all other requirements associated with INC grades.
# 3. If the faculty member is on leave, unresponsive, or their whereabouts are unknown, the Area Chairperson can act upon the grade with the approval of the Dean.
#
# Please note that if the faculty member is retired, has resigned, or is disconnected from the service to the Institute, the Area Chairperson can also act upon the grade with the approval of the Dean. In cases of disability or death of the faculty, the Area Chairperson can act upon the grade without requiring Dean approval.
#
# ✅ Completed in 62.76s (Relevance: 0.765)
#
# [24/100] Processing: What happens if I fail 3 subjects in one semester?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (50 tokens):
# If you fail three subjects in one semester, you will be placed on probation for the succeeding semester and your academic load will be reduced by the Dean concerned as stipulated in Art. II Sec. 7.2.
#
# ✅ Completed in 4.53s (Relevance: 0.710)
#
# [25/100] Processing: My friend is on academic probation. How does he get out of i...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (50 tokens):
# If you fail three subjects in one semester, you will be placed on probation for the succeeding semester and your academic load will be reduced by the Dean concerned as stipulated in Art. II Sec. 7.2.
#
# ✅ Completed in 4.53s (Relevance: 0.710)
#
# [25/100] Processing: My friend is on academic probation. How does he get out of i...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (49 tokens):
# To get out of academic probation, your friend needs to pass all his courses in the semester that the probation is being served. If he fails in any course during this time, he will not be allowed to readmission.
#
# ✅ Completed in 4.41s (Relevance: 0.749)
#
# [26/100] Processing: I'm a freshman and I failed 2 subjects in my first sem. Am I...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (49 tokens):
# To get out of academic probation, your friend needs to pass all his courses in the semester that the probation is being served. If he fails in any course during this time, he will not be allowed to readmission.
#
# ✅ Completed in 4.41s (Relevance: 0.749)
#
# [26/100] Processing: I'm a freshman and I failed 2 subjects in my first sem. Am I...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (104 tokens):
# No, you are not getting kicked out. According to Section 7.1 of the Retention Policies, freshman students who incur failures corresponding to three (3) or more courses or the equivalent of one-half of their load in their first semester will be allowed to enroll under probation in the second semester. However, you should note that students on probation should not fail or drop even one subject nor be involved in any disciplinary case during the semester that immediately follows.
#
# ✅ Completed in 8.26s (Relevance: 0.683)
#
# [27/100] Processing: This is my third time taking the same subject. What happens ...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (104 tokens):
# No, you are not getting kicked out. According to Section 7.1 of the Retention Policies, freshman students who incur failures corresponding to three (3) or more courses or the equivalent of one-half of their load in their first semester will be allowed to enroll under probation in the second semester. However, you should note that students on probation should not fail or drop even one subject nor be involved in any disciplinary case during the semester that immediately follows.
#
# ✅ Completed in 8.26s (Relevance: 0.683)
#
# [27/100] Processing: This is my third time taking the same subject. What happens ...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (112 tokens):
# Based on the provided information, if you fail the same subject for the fourth time, you will be dropped from the rolls of the Institute. This is stated in Section 7.7 of the Handbook, which states that "A student who is due for dismissal but who has been enrolled before the dismissal status shall be permitted to remain up to the end of the semester or intercession in which it occurs." Since you have already failed the subject three times, failing it again would result in your dismissal from the Institute.
#
# ✅ Completed in 7.46s (Relevance: 0.627)
#
# [28/100] Processing: I failed 2 subjects, and I also have an INC. Does the INC co...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (112 tokens):
# Based on the provided information, if you fail the same subject for the fourth time, you will be dropped from the rolls of the Institute. This is stated in Section 7.7 of the Handbook, which states that "A student who is due for dismissal but who has been enrolled before the dismissal status shall be permitted to remain up to the end of the semester or intercession in which it occurs." Since you have already failed the subject three times, failing it again would result in your dismissal from the Institute.
#
# ✅ Completed in 7.46s (Relevance: 0.627)
#
# [28/100] Processing: I failed 2 subjects, and I also have an INC. Does the INC co...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (81 tokens):
# No, the INC grade does not count towards the 3-failure rule for dismissal. However, if you fail two subjects and the INC grade is not removed within the specified time frame, you may still be dismissed from the Institute. It's important to note that you should work with your academic advisor to address these issues and ensure that you are meeting the necessary requirements for graduation.
#
# ✅ Completed in 9.14s (Relevance: 0.697)
#
# [29/100] Processing: What's the maximum time I can take for a leave of absence (L...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (81 tokens):
# No, the INC grade does not count towards the 3-failure rule for dismissal. However, if you fail two subjects and the INC grade is not removed within the specified time frame, you may still be dismissed from the Institute. It's important to note that you should work with your academic advisor to address these issues and ensure that you are meeting the necessary requirements for graduation.
#
# ✅ Completed in 9.14s (Relevance: 0.697)
#
# [29/100] Processing: What's the maximum time I can take for a leave of absence (L...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (19 tokens):
# The maximum time for a leave of absence (LOA) is one academic year.
#
# ✅ Completed in 4.83s (Relevance: 0.644)
#
# [30/100] Processing: I'm in a 4-year degree program. What's the maximum number of...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (19 tokens):
# The maximum time for a leave of absence (LOA) is one academic year.
#
# ✅ Completed in 4.83s (Relevance: 0.644)
#
# [30/100] Processing: I'm in a 4-year degree program. What's the maximum number of...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (104 tokens):
# Based on Section 8.1 of the handbook, for a regular student in a 4-year degree program, the maximum number of years allowed to finish the academic program is five years. However, if you are an athletics scholar, you may have up to six years to complete your degree. If you are a working student, you may have up to one and one-half (11/2) times the normal length of the prescribed residence for a program to finish your degree.
#
# ✅ Completed in 48.31s (Relevance: 0.675)
#
# [31/100] Processing: I'm a working student in a 4-year course. Do I also have a 5...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (104 tokens):
# Based on Section 8.1 of the handbook, for a regular student in a 4-year degree program, the maximum number of years allowed to finish the academic program is five years. However, if you are an athletics scholar, you may have up to six years to complete your degree. If you are a working student, you may have up to one and one-half (11/2) times the normal length of the prescribed residence for a program to finish your degree.
#
# ✅ Completed in 48.31s (Relevance: 0.675)
#
# [31/100] Processing: I'm a working student in a 4-year course. Do I also have a 5...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (88 tokens):
# No, working students do not have a 5-year maximum tenure like regular students. According to Section 8.1.3 of the handbook, working students may finish the academic program within a period equivalent to one and one-half (11/2) times the normal length of the prescribed residence for a program. This means that working students have more flexibility in completing their academic program compared to regular students.
#
# ✅ Completed in 57.74s (Relevance: 0.725)
#
# [32/100] Processing: What's the GWA range to graduate Cum Laude?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (88 tokens):
# No, working students do not have a 5-year maximum tenure like regular students. According to Section 8.1.3 of the handbook, working students may finish the academic program within a period equivalent to one and one-half (11/2) times the normal length of the prescribed residence for a program. This means that working students have more flexibility in completing their academic program compared to regular students.
#
# ✅ Completed in 57.74s (Relevance: 0.725)
#
# [32/100] Processing: What's the GWA range to graduate Cum Laude?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (39 tokens):
# To graduate Cum Laude, a student must have a cumulative grade point average (GPA) between 1.7500 and 1.5001.
#
# ✅ Completed in 4.06s (Relevance: 0.660)
#
# [33/100] Processing: I'm a transferee. Can I still graduate with honors?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (39 tokens):
# To graduate Cum Laude, a student must have a cumulative grade point average (GPA) between 1.7500 and 1.5001.
#
# ✅ Completed in 4.06s (Relevance: 0.660)
#
# [33/100] Processing: I'm a transferee. Can I still graduate with honors?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (105 tokens):
# As a transferee, you may still be eligible to graduate with honors, provided that you meet all the academic and admission requirements set forth by the Institute and complete your program within the prescribed number of years. However, the specific requirements for graduating with honors may vary depending on your program and the cumulative grade point average (GPA) required. It is important to consult with the appropriate academic advisor or department chairperson to determine the specific requirements for graduating with honors in your program.
#
# ✅ Completed in 10.71s (Relevance: 0.698)
#
# [34/100] Processing: I'm aiming for Cum Laude and my GWA is 1.7. But I failed one...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (105 tokens):
# As a transferee, you may still be eligible to graduate with honors, provided that you meet all the academic and admission requirements set forth by the Institute and complete your program within the prescribed number of years. However, the specific requirements for graduating with honors may vary depending on your program and the cumulative grade point average (GPA) required. It is important to consult with the appropriate academic advisor or department chairperson to determine the specific requirements for graduating with honors in your program.
#
# ✅ Completed in 10.71s (Relevance: 0.698)
#
# [34/100] Processing: I'm aiming for Cum Laude and my GWA is 1.7. But I failed one...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (185 tokens):
# Based on the information provided, if you maintain a GWA of 1.7 and complete all other requirements, you may still be eligible for graduation with honors. However, you should refer to Section 10.2.4.4 in the Handbook which states that a candidate for graduation with honors must have no final grade lower than 2.25 in the curriculum in any academic and non-academic courses in the Institute or in any other recognized educational institution. Since you failed one subject in your first year, it is important to check if this subject is considered an academic course in the curriculum and if it meets the minimum passing grade requirement. If it does not, you may need to retake the subject or find an alternative way to fulfill the credit hours for that subject. It is also recommended to consult with the College Registrar and Dean for further guidance.
#
# ✅ Completed in 14.67s (Relevance: 0.650)
#
# [35/100] Processing: For graduating with honors, do they include PE and NSTP grad...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (185 tokens):
# Based on the information provided, if you maintain a GWA of 1.7 and complete all other requirements, you may still be eligible for graduation with honors. However, you should refer to Section 10.2.4.4 in the Handbook which states that a candidate for graduation with honors must have no final grade lower than 2.25 in the curriculum in any academic and non-academic courses in the Institute or in any other recognized educational institution. Since you failed one subject in your first year, it is important to check if this subject is considered an academic course in the curriculum and if it meets the minimum passing grade requirement. If it does not, you may need to retake the subject or find an alternative way to fulfill the credit hours for that subject. It is also recommended to consult with the College Registrar and Dean for further guidance.
#
# ✅ Completed in 14.67s (Relevance: 0.650)
#
# [35/100] Processing: For graduating with honors, do they include PE and NSTP grad...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (60 tokens):
# According to Section 10.2.1 in the Handbook, grades in all accredited academic courses in the curriculum, including P.E. and NSTP courses, are included in the computation of the final average of a candidate for graduation with honors.
#
# ✅ Completed in 62.11s (Relevance: 0.670)
#
# [36/100] Processing: What is the 'Student Assistance' program?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (60 tokens):
# According to Section 10.2.1 in the Handbook, grades in all accredited academic courses in the curriculum, including P.E. and NSTP courses, are included in the computation of the final average of a candidate for graduation with honors.
#
# ✅ Completed in 62.11s (Relevance: 0.670)
#
# [36/100] Processing: What is the 'Student Assistance' program?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (128 tokens):
# ...
#
# ✅ Completed in 4.22s (Relevance: 0.673)
#
# [89/100] Processing: Does the school have a swimming pool?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (29 tokens):
# The dean of the College of Arts and Sciences (CAS) is DR. MARLENE M. MONTERONA.
#
# ✅ Completed in 4.22s (Relevance: 0.673)
#
# [89/100] Processing: Does the school have a swimming pool?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (13 tokens):
# The provided information does not contain the answer to this question.
#
# ✅ Completed in 2.76s (Relevance: 0.570)
#
# [90/100] Processing: What are the library's opening and closing hours?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (13 tokens):
# The provided information does not contain the answer to this question.
#
# ✅ Completed in 2.76s (Relevance: 0.570)
#
# [90/100] Processing: What are the library's opening and closing hours?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (18 tokens):
# I apologize, but the provided information does not contain the answer to this question.
#
# ✅ Completed in 3.10s (Relevance: 0.528)
#
# [91/100] Processing: What is the official vision statement of EARIST?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (18 tokens):
# I apologize, but the provided information does not contain the answer to this question.
#
# ✅ Completed in 3.10s (Relevance: 0.528)
#
# [91/100] Processing: What is the official vision statement of EARIST?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (19 tokens):
# The official vision statement of EARIST is not provided in the given information sections.
#
# ✅ Completed in 4.28s (Relevance: 0.625)
#
# [92/100] Processing: What is EARIST's mission?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (19 tokens):
# The official vision statement of EARIST is not provided in the given information sections.
#
# ✅ Completed in 4.28s (Relevance: 0.625)
#
# [92/100] Processing: What is EARIST's mission?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (17 tokens):
# EARIST's mission is not explicitly stated in the provided information sections.
#
# ✅ Completed in 4.77s (Relevance: 0.645)
#
# [93/100] Processing: I'm currently enrolled in the Cavite campus. Is it possible ...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (17 tokens):
# EARIST's mission is not explicitly stated in the provided information sections.
#
# ✅ Completed in 4.77s (Relevance: 0.645)
#
# [93/100] Processing: I'm currently enrolled in the Cavite campus. Is it possible ...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (84 tokens):
# Yes, it is possible to transfer from the EARIST Cavite Campus to the Manila campus. According to Section 4.1.4.1 of the Handbook, students may be admitted as transferees upon the recommendation of the EARIST Cavite Campus (ECC) Administrator, depending on the availability of slots and have complied with all the requirements for admission.
#
# ✅ Completed in 9.17s (Relevance: 0.737)
#
# [94/100] Processing: I'm taking my OJT this semester. Can I also enroll in a majo...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (84 tokens):
# Yes, it is possible to transfer from the EARIST Cavite Campus to the Manila campus. According to Section 4.1.4.1 of the Handbook, students may be admitted as transferees upon the recommendation of the EARIST Cavite Campus (ECC) Administrator, depending on the availability of slots and have complied with all the requirements for admission.
#
# ✅ Completed in 9.17s (Relevance: 0.737)
#
# [94/100] Processing: I'm taking my OJT this semester. Can I also enroll in a majo...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (69 tokens):
# According to the provided information, you are allowed to enroll in a major subject you failed before if you are taking your On-the-Job Training (OJT) this semester. However, you should accomplish a SARRMS form before doing so. This is stated in Section 3 of the Handbook.
#
# ✅ Completed in 5.59s (Relevance: 0.632)
#
# [95/100] Processing: Is there free Wi-Fi for students on campus?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (69 tokens):
# According to the provided information, you are allowed to enroll in a major subject you failed before if you are taking your On-the-Job Training (OJT) this semester. However, you should accomplish a SARRMS form before doing so. This is stated in Section 3 of the Handbook.
#
# ✅ Completed in 5.59s (Relevance: 0.632)
#
# [95/100] Processing: Is there free Wi-Fi for students on campus?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (13 tokens):
# The provided information does not contain the answer to this question.
#
# ✅ Completed in 2.76s (Relevance: 0.564)
#
# [96/100] Processing: I want to run for ISG President. My GWA is 2.75 and I have n...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (13 tokens):
# The provided information does not contain the answer to this question.
#
# ✅ Completed in 2.76s (Relevance: 0.564)
#
# [96/100] Processing: I want to run for ISG President. My GWA is 2.75 and I have n...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (79 tokens):
# Based on the information provided in Section 3.2.4 of the Handbook, to be eligible for the position of ISG President, you must have a GPA of 2.50 or higher and not have a failing grade. Since you have a GWA of 2.75 and no failing grades, you are eligible to run for ISG President.
#
# ✅ Completed in 8.26s (Relevance: 0.676)
#
# [97/100] Processing: I want to run for student council. My GWA is excellent (2.0)...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (79 tokens):
# Based on the information provided in Section 3.2.4 of the Handbook, to be eligible for the position of ISG President, you must have a GPA of 2.50 or higher and not have a failing grade. Since you have a GWA of 2.75 and no failing grades, you are eligible to run for ISG President.
#
# ✅ Completed in 8.26s (Relevance: 0.676)
#
# [97/100] Processing: I want to run for student council. My GWA is excellent (2.0)...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (175 tokens):
# Based on the provided information sections, you can run for student council if you meet the qualifications for officers of ISG and CSG. Specifically, you must be a bonafide student, carry a minimum load, have at least one year residency, not have been found guilty of any offense, and have a GPA of 2.50 or higher.
#
# However, it is important to note that you did fail one class last year. While the information sections do not specifically address this scenario, it is possible that the disqualification for obtaining a failing grade may apply. It would be best to consult with the appropriate authorities, such as the Leadership Coordinator of SAS or the Director of Student Affairs and Services, to clarify your eligibility. They may consider your specific circumstances and provide guidance on how to proceed.
#
# ✅ Completed in 12.56s (Relevance: 0.674)
#
# [98/100] Processing: Can students bring a car to school? Is there a parking lot f...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (175 tokens):
# Based on the provided information sections, you can run for student council if you meet the qualifications for officers of ISG and CSG. Specifically, you must be a bonafide student, carry a minimum load, have at least one year residency, not have been found guilty of any offense, and have a GPA of 2.50 or higher.
#
# However, it is important to note that you did fail one class last year. While the information sections do not specifically address this scenario, it is possible that the disqualification for obtaining a failing grade may apply. It would be best to consult with the appropriate authorities, such as the Leadership Coordinator of SAS or the Director of Student Affairs and Services, to clarify your eligibility. They may consider your specific circumstances and provide guidance on how to proceed.
#
# ✅ Completed in 12.56s (Relevance: 0.674)
#
# [98/100] Processing: Can students bring a car to school? Is there a parking lot f...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (50 tokens):
# According to the provided information sections, there is no specific mention about students being allowed to bring a car to school or if there is a designated parking lot for students. Therefore, the provided information does not contain the answer to this question.
#
# ✅ Completed in 5.62s (Relevance: 0.609)
#
# [99/100] Processing: Does EARIST have a study abroad program?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (50 tokens):
# According to the provided information sections, there is no specific mention about students being allowed to bring a car to school or if there is a designated parking lot for students. Therefore, the provided information does not contain the answer to this question.
#
# ✅ Completed in 5.62s (Relevance: 0.609)
#
# [99/100] Processing: Does EARIST have a study abroad program?...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (64 tokens):
# Yes, EARIST has a study abroad program. According to Section 1.4 of Article XV in the Handbook of the Institute, "Study abroad is the term given to a program, usually run through a university, which allows a student to live in a foreign country and attend a foreign university."
#
# ✅ Completed in 6.59s (Relevance: 0.669)
#
# [100/100] Processing: My organization wants to sell t-shirts with the EARIST logo ...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (64 tokens):
# Yes, EARIST has a study abroad program. According to Section 1.4 of Article XV in the Handbook of the Institute, "Study abroad is the term given to a program, usually run through a university, which allows a student to live in a foreign country and attend a foreign university."
#
# ✅ Completed in 6.59s (Relevance: 0.669)
#
# [100/100] Processing: My organization wants to sell t-shirts with the EARIST logo ...
# ✅ Prompt fits token budget with 5 chunks.
#
# 📝 Generated answer (176 tokens):
# According to the provided information sections, in order to sell t-shirts with the EARIST logo on them, your organization would need to obtain permission from the Information and Public Affairs Services (InfoPAS) at EARIST. This is stated in Section 6 of the most relevant section, which states that "to seek approval on the use and/or selling of EARIST Logo and Trademarks at the Information and Public Affairs Services (InfoPAS) that will be used on products, merchandise or services that will be sold or distributed to the public," including institutional advertisements, namely posters, billboards, print ads, television ads, special supplements, electronic ads, and the like. Therefore, your organization should contact the InfoPAS office to request permission before proceeding with selling these t-shirts.
#
# ✅ Completed in 12.91s (Relevance: 0.721)
#
# ================================================================================
# ✅ Testing Complete!
# 📊 Total questions: 100
# 💾 Results saved to: rag_test_results_20251116_195113.csv
# ⏱️  Total time: 1589.45s
# 📈 Average processing time: 15.89s per question
#
# 📊 Summary by Category:
#               question  processing_time_sec  top_relevance_score
# category
# adversarial         17                21.15                 0.65
# direct              26                14.20                 0.69
# paraphrased         17                13.07                 0.67
# scenario            24                20.12                 0.66
# unanswerable        16                 9.73                 0.62
#
# 📊 Summary by Difficulty:
#             question  processing_time_sec  top_relevance_score
# difficulty
# easy              52                12.63                 0.66
# hard              12                18.74                 0.66
# medium            36                19.67                 0.67
#
# 📄 Preview of results:
#    question_number      category difficulty  top_relevance_score  \
# 0                1        direct       easy               0.6410
# 1                2   paraphrased       easy               0.6927
# 2                3      scenario     medium               0.5752
# 3                4   adversarial     medium               0.6419
# 4                5  unanswerable       easy               0.6457
# 5                6      scenario     medium               0.6866
# 6                7        direct       easy               0.7428
# 7                8      scenario     medium               0.6491
# 8                9   adversarial     medium               0.7366
# 9               10  unanswerable       easy               0.6701
#
#    processing_time_sec
# 0                10.19
# 1                15.21
# 2                 9.74
# 3                 9.68
# 4                43.81
# 5                69.60
# 6                20.12
# 7                14.16
# 8                 6.25
# 9                 3.11
#
# 📝 Generated answer (176 tokens):
# According to the provided information sections, in order to sell t-shirts with the EARIST logo on them, your organization would need to obtain permission from the Information and Public Affairs Services (InfoPAS) at EARIST. This is stated in Section 6 of the most relevant section, which states that "to seek approval on the use and/or selling of EARIST Logo and Trademarks at the Information and Public Affairs Services (InfoPAS) that will be used on products, merchandise or services that will be sold or distributed to the public," including institutional advertisements, namely posters, billboards, print ads, television ads, special supplements, electronic ads, and the like. Therefore, your organization should contact the InfoPAS office to request permission before proceeding with selling these t-shirts.
#
# ✅ Completed in 12.91s (Relevance: 0.721)
#
# ================================================================================
# ✅ Testing Complete!
# 📊 Total questions: 100
# 💾 Results saved to: rag_test_results_20251116_195113.csv
# ⏱️  Total time: 1589.45s
# 📈 Average processing time: 15.89s per question
#
# 📊 Summary by Category:
#               question  processing_time_sec  top_relevance_score
# category
# adversarial         17                21.15                 0.65
# direct              26                14.20                 0.69
# paraphrased         17                13.07                 0.67
# scenario            24                20.12                 0.66
# unanswerable        16                 9.73                 0.62
#
# 📊 Summary by Difficulty:
#             question  processing_time_sec  top_relevance_score
# difficulty
# easy              52                12.63                 0.66
# hard              12                18.74                 0.66
# medium            36                19.67                 0.67
#
# 📄 Preview of results:
#    question_number      category difficulty  top_relevance_score  \
# 0                1        direct       easy               0.6410
# 1                2   paraphrased       easy               0.6927
# 2                3      scenario     medium               0.5752
# 3                4   adversarial     medium               0.6419
# 4                5  unanswerable       easy               0.6457
# 5                6      scenario     medium               0.6866
# 6                7        direct       easy               0.7428
# 7                8      scenario     medium               0.6491
# 8                9   adversarial     medium               0.7366
# 9               10  unanswerable       easy               0.6701
#
#    processing_time_sec
# 0                10.19
# 1                15.21
# 2                 9.74
# 3                 9.68
# 4                43.81
# 5                69.60
# 6                20.12
# 7                14.16
# 8                 6.25
# 9                 3.11

# %% [markdown]
# ## Optional: View Individual Results
#
# You can examine specific questions and their generated answers:

# %%
# View a specific result
question_num = 3  # Change this to view different questions

result = results_df.iloc[question_num - 1]

print(f"Question #{result['question_number']}")
print(f"Category: {result['category']} | Difficulty: {result['difficulty']}")
print(f"Relevance Score: {result['top_relevance_score']}")
print("\n" + "=" * 80)
print(f"\n❓ QUESTION:\n{result['question']}")
print("\n" + "=" * 80)
print(f"\n📖 EXPECTED ANSWER:\n{result['expected_answer']}")
print("\n" + "=" * 80)
print(f"\n🤖 GENERATED ANSWER:\n{result['generated_answer']}")
print("\n" + "=" * 80)
